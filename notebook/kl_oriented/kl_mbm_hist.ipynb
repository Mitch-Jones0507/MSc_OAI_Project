# %%
from IPython.display import display
from scripts.mbm.kl_oriented.kl_mbm_hist import v00_v01_moaks_kl_metrics, v00_v01_moaks_kl_coefs_df

display(v00_v01_moaks_kl_coefs_df.sort_values(by='Importance', ascending=False))
display(v00_v01_moaks_kl_metrics['classification_report'])
print(v00_v01_moaks_kl_metrics['confusion_matrix'])
# Out:
#        Feature  Importance  Importance_std
# 17  V00MBMPFMC    0.032639        0.018582
# 28   V00MBMPPM    0.030556        0.013586
# 9   V00MBMSTMC    0.023611        0.011013
# 24  V00MBMPTMC    0.022743        0.010313
# 21   V00MBMPSS    0.022743        0.007261
# 13   V00MBMSPM    0.020312        0.006636
# 7   V00MBMSTMA    0.018056        0.006459
# 15  V00MBMPFMA    0.017708        0.004710
# 6    V00MBMSSS    0.016493        0.008689
# 22  V00MBMPTMA    0.012847        0.009515
# 1   V00MBMSFLA    0.011285        0.008620
# 0   V00MBMSFMA    0.009375        0.004406
# 30  V00MBMNFMA    0.007812        0.005612
# 34  V00MBMNFMP    0.007118        0.006517
# 19  V00MBMPFMP    0.006771        0.004557
# 44   V00MBMNPL    0.006076        0.003494
# 16  V00MBMPFLA    0.005729        0.006165
# 2   V00MBMSFMC    0.005729        0.004789
# 39  V00MBMNTMC    0.005208        0.007325
# 14   V00MBMSPL    0.005035        0.010573
# 26  V00MBMPTMP    0.004167        0.003740
# ...

# %%
from scripts.mbm.kl_oriented.kl_mbm_hist import v00_v03_moaks_kl_metrics, v00_v03_moaks_kl_coefs_df

display(v00_v03_moaks_kl_coefs_df.sort_values(by='Importance', ascending=False))
display(v00_v03_moaks_kl_metrics['classification_report'])
print(v00_v03_moaks_kl_metrics['confusion_matrix'])
# Out:
#        Feature  Importance  Importance_std
# 24  V00MBMPTMC    0.044965        0.006329
# 28   V00MBMPPM    0.040104        0.009865
# 2   V00MBMSFMC    0.030035        0.006771
# 4   V00MBMSFMP    0.023611        0.006024
# 14   V00MBMSPL    0.022743        0.010630
# 7   V00MBMSTMA    0.022222        0.009180
# 13   V00MBMSPM    0.019965        0.009325
# 16  V00MBMPFLA    0.019792        0.004406
# 9   V00MBMSTMC    0.017882        0.008578
# 1   V00MBMSFLA    0.015278        0.005424
# 21   V00MBMPSS    0.015104        0.007609
# 17  V00MBMPFMC    0.014757        0.006508
# 19  V00MBMPFMP    0.013889        0.005435
# 15  V00MBMPFMA    0.013368        0.004185
# 6    V00MBMSSS    0.012674        0.007244
# 31  V00MBMNFLA    0.011632        0.004531
# 26  V00MBMPTMP    0.010937        0.002910
# 5   V00MBMSFLP    0.010937        0.005547
# 43   V00MBMNPM    0.009028        0.002987
# 11  V00MBMSTMP    0.008333        0.003086
# 10  V00MBMSTLC    0.006424        0.005547
# ...

# %%
from scripts.mbm.kl_oriented.kl_mbm_hist import v01_v03_moaks_kl_metrics, v01_v03_moaks_kl_coefs_df

display(v01_v03_moaks_kl_coefs_df.sort_values(by='Importance', ascending=False))
display(v01_v03_moaks_kl_metrics['classification_report'])
print(v01_v03_moaks_kl_metrics['confusion_matrix'])
# Out:
#        Feature    Importance  Importance_std
# 1   V01MBMSFLA  5.069444e-02        0.007192
# 13   V01MBMSPM  5.034722e-02        0.010212
# 14   V01MBMSPL  3.437500e-02        0.014931
# 24  V01MBMPTMC  3.420139e-02        0.012079
# 21   V01MBMPSS  3.211806e-02        0.005337
# 28   V01MBMPPM  2.899306e-02        0.005153
# 9   V01MBMSTMC  2.534722e-02        0.011230
# 2   V01MBMSFMC  2.447917e-02        0.008123
# 29   V01MBMPPL  1.788194e-02        0.003963
# 17  V01MBMPFMC  1.701389e-02        0.006760
# 31  V01MBMNFLA  1.302083e-02        0.004987
# 6    V01MBMSSS  1.284722e-02        0.006172
# 10  V01MBMSTLC  1.128472e-02        0.005612
# 15  V01MBMPFMA  1.076389e-02        0.005851
# 4   V01MBMSFMP  1.024306e-02        0.004423
# 0   V01MBMSFMA  9.201389e-03        0.006214
# 43   V01MBMNPM  8.333333e-03        0.003944
# 19  V01MBMPFMP  7.638889e-03        0.007124
# 32  V01MBMNFMC  7.465278e-03        0.003562
# 7   V01MBMSTMA  7.465278e-03        0.006017
# ...

# %%
from scripts.mbm.kl_oriented.kl_mbm_hist import v00_moaks_kl_change_metrics, v00_moaks_kl_change_coefs_df

display(v00_moaks_kl_change_coefs_df.sort_values(by='Importance', ascending=False))
display(v00_moaks_kl_change_metrics['classification_report'])
print(v00_moaks_kl_change_metrics['confusion_matrix'])
# Out:
#        Feature  Importance  Importance_std
# 6    V00MBMSSS    0.017882        0.004914
# 21   V00MBMPSS    0.014757        0.003494
# 22  V00MBMPTMA    0.009201        0.001563
# 7   V00MBMSTMA    0.009028        0.002303
# 13   V00MBMSPM    0.008854        0.002387
# 24  V00MBMPTMC    0.008681        0.001902
# 28   V00MBMPPM    0.008160        0.005035
# 36   V00MBMNSS    0.007118        0.000935
# 1   V00MBMSFLA    0.006424        0.002461
# 2   V00MBMSFMC    0.006424        0.002336
# 12  V00MBMSTLP    0.005208        0.002196
# 31  V00MBMNFLA    0.003993        0.001562
# 29   V00MBMPPL    0.003472        0.002329
# 11  V00MBMSTMP    0.002604        0.002717
# 32  V00MBMNFMC    0.002431        0.003027
# 17  V00MBMPFMC    0.002083        0.002025
# 26  V00MBMPTMP    0.001910        0.001972
# 14   V00MBMSPL    0.001563        0.001638
# 4   V00MBMSFMP    0.001042        0.003027
# 25  V00MBMPTLC    0.000868        0.001779
# 30  V00MBMNFMA    0.000521        0.001745
# ...

# %%
from scripts.mbm.kl_oriented.kl_mbm_hist import v01_moaks_kl_change_metrics, v01_moaks_kl_change_coefs_df

display(v01_moaks_kl_change_coefs_df.sort_values(by='Importance', ascending=False))
display(v01_moaks_kl_change_metrics['classification_report'])
print(v01_moaks_kl_change_metrics['confusion_matrix'])
# Out:
#        Feature  Importance  Importance_std
# 1   V01MBMSFLA    0.017708        0.005079
# 6    V01MBMSSS    0.017188        0.004623
# 13   V01MBMSPM    0.012674        0.002695
# 2   V01MBMSFMC    0.012674        0.002581
# 9   V01MBMSTMC    0.009375        0.002083
# 10  V01MBMSTLC    0.008854        0.002510
# 36   V01MBMNSS    0.008681        0.001345
# 24  V01MBMPTMC    0.008160        0.003206
# 28   V01MBMPPM    0.006771        0.002740
# 18  V01MBMPFLC    0.006250        0.003312
# 29   V01MBMPPL    0.006076        0.003579
# 12  V01MBMSTLP    0.005382        0.003839
# 15  V01MBMPFMA    0.004514        0.002083
# 16  V01MBMPFLA    0.004340        0.001400
# 31  V01MBMNFLA    0.003993        0.001112
# 44   V01MBMNPL    0.003993        0.001112
# 17  V01MBMPFMC    0.003646        0.002257
# 4   V01MBMSFMP    0.003472        0.003201
# 14   V01MBMSPL    0.003299        0.004354
# 19  V01MBMPFMP    0.002604        0.002091
# 7   V01MBMSTMA    0.002431        0.003490
# ...
