# %%
from IPython.display import display
from scripts.mbm.kl_oriented.kl_mbm_logR import v00_v01_moaks_kl_metrics, v00_v01_moaks_kl_coefs_df

display(v00_v01_moaks_kl_coefs_df)
display(v00_v01_moaks_kl_metrics['classification_report'])
print(v00_v01_moaks_kl_metrics['confusion_matrix'])
# Out:
#      Class     Feature  Coefficient
# 0        0  V00MBMSFMA    -0.074315
# 1        1  V00MBMSFMA    -0.052305
# 2        2  V00MBMSFMA     0.275088
# 3        3  V00MBMSFMA     0.069329
# 4        0  V00MBMSFLA    -0.136295
# ..     ...         ...          ...
# 175      3   V00MBMNPM     0.050731
# 176      0   V00MBMNPL    -0.035563
# 177      1   V00MBMNPL     0.044988
# 178      2   V00MBMNPL    -0.031486
# 179      3   V00MBMNPL     0.050512
#
# [180 rows x 3 columns]
# {'0': {'precision': 0.4562043795620438,
#   'recall': 0.6830601092896175,
#   'f1-score': 0.5470459518599562,
#   'support': 183.0},
#  '1': {'precision': 0.42857142857142855,
#   'recall': 0.3707865168539326,
#   'f1-score': 0.39759036144578314,
#   'support': 178.0},
#  '2': {'precision': 0.4117647058823529,
#   'recall': 0.2413793103448276,
#   'f1-score': 0.30434782608695654,
#   'support': 116.0},
#  '3': {'precision': 0.775,
#   'recall': 0.6262626262626263,
#   'f1-score': 0.6927374301675978,
# ...

# %%
from scripts.mbm.kl_oriented.kl_mbm_logR import v00_v03_moaks_kl_metrics, v00_v03_moaks_kl_coefs_df

display(v00_v03_moaks_kl_coefs_df)
display(v00_v03_moaks_kl_metrics['classification_report'])
print(v00_v03_moaks_kl_metrics['confusion_matrix'])
# Out:
#      Class     Feature  Coefficient
# 0        0  V00MBMSFMA    -0.128046
# 1        1  V00MBMSFMA    -0.052347
# 2        2  V00MBMSFMA     0.147440
# 3        3  V00MBMSFMA     0.085701
# 4        0  V00MBMSFLA    -0.036285
# ..     ...         ...          ...
# 175      3   V00MBMNPM     0.057215
# 176      0   V00MBMNPL    -0.154263
# 177      1   V00MBMNPL    -0.019366
# 178      2   V00MBMNPL     0.052757
# 179      3   V00MBMNPL     0.073653
#
# [180 rows x 3 columns]
# {'0': {'precision': 0.4416058394160584,
#   'recall': 0.7034883720930233,
#   'f1-score': 0.5426008968609866,
#   'support': 172.0},
#  '1': {'precision': 0.3711340206185567,
#   'recall': 0.22784810126582278,
#   'f1-score': 0.2823529411764706,
#   'support': 158.0},
#  '2': {'precision': 0.45454545454545453,
#   'recall': 0.3787878787878788,
#   'f1-score': 0.4132231404958678,
#   'support': 132.0},
#  '3': {'precision': 0.7368421052631579,
#   'recall': 0.6140350877192983,
# ...

# %%
from scripts.mbm.kl_oriented.kl_mbm_logR import v01_v03_moaks_kl_metrics, v01_v03_moaks_kl_coefs_df

display(v01_v03_moaks_kl_coefs_df)
display(v01_v03_moaks_kl_metrics['classification_report'])
print(v01_v03_moaks_kl_metrics['confusion_matrix'])
# Out:
#      Class     Feature  Coefficient
# 0        0  V01MBMSFMA    -0.089251
# 1        1  V01MBMSFMA     0.006750
# 2        2  V01MBMSFMA     0.144582
# 3        3  V01MBMSFMA    -0.004748
# 4        0  V01MBMSFLA    -0.135392
# ..     ...         ...          ...
# 175      3   V01MBMNPM    -0.021315
# 176      0   V01MBMNPL    -0.128744
# 177      1   V01MBMNPL    -0.108662
# 178      2   V01MBMNPL     0.064099
# 179      3   V01MBMNPL     0.215760
#
# [180 rows x 3 columns]
# {'0': {'precision': 0.4431818181818182,
#   'recall': 0.6802325581395349,
#   'f1-score': 0.536697247706422,
#   'support': 172.0},
#  '1': {'precision': 0.32407407407407407,
#   'recall': 0.22151898734177214,
#   'f1-score': 0.2631578947368421,
#   'support': 158.0},
#  '2': {'precision': 0.4158415841584158,
#   'recall': 0.3181818181818182,
#   'f1-score': 0.3605150214592275,
#   'support': 132.0},
#  '3': {'precision': 0.7378640776699029,
#   'recall': 0.6666666666666666,
# ...

# %%
from scripts.mbm.kl_oriented.kl_mbm_logR import v00_moaks_kl_change_coefs_df, v00_moaks_kl_change_metrics

display(v00_moaks_kl_change_coefs_df)
display(v00_moaks_kl_change_metrics['classification_report'])
print(v00_moaks_kl_change_metrics['confusion_matrix'])
# Out:
#      Class     Feature  Coefficient
# 0        0  V00MBMSFMA    -0.938240
# 1        1  V00MBMSFMA     0.025142
# 2        2  V00MBMSFMA     0.278259
# 3        0  V00MBMSFLA    -0.122414
# 4        1  V00MBMSFLA     0.213115
# ..     ...         ...          ...
# 130      1   V00MBMNPM    -0.229139
# 131      2   V00MBMNPM     0.020370
# 132      0   V00MBMNPL    -0.316240
# 133      1   V00MBMNPL     0.000000
# 134      2   V00MBMNPL     0.234398
#
# [135 rows x 3 columns]
# {'0': {'precision': 0.25,
#   'recall': 0.14285714285714285,
#   'f1-score': 0.18181818181818182,
#   'support': 7.0},
#  '1': {'precision': 0.8998242530755711,
#   'recall': 0.9941747572815534,
#   'f1-score': 0.9446494464944649,
#   'support': 515.0},
#  '2': {'precision': 1.0,
#   'recall': 0.05555555555555555,
#   'f1-score': 0.10526315789473684,
#   'support': 54.0},
#  'accuracy': 0.8958333333333334,
#  'macro avg': {'precision': 0.7166080843585236,
#   'recall': 0.3975291518980839,
# ...

# %%
from scripts.mbm.kl_oriented.kl_mbm_logR import v00_v01_moaks_kl_lasso_metrics, v00_v01_moaks_kl_lasso_coefs_df

display(v00_v01_moaks_kl_lasso_coefs_df)
display(v00_v01_moaks_kl_lasso_metrics['classification_report'])
print(v00_v01_moaks_kl_lasso_metrics['confusion_matrix'])
# Out:
#      Class     Feature  Coefficient
# 0        0  V00MBMSFMA    -0.038502
# 1        1  V00MBMSFMA    -0.132485
# 2        2  V00MBMSFMA     0.145967
# 3        3  V00MBMSFMA     0.099179
# 4        0  V00MBMSFMC     0.199464
# ..     ...         ...          ...
# 107      3  V00MBMNTMC     0.081085
# 108      0   V00MBMNPL     0.000000
# 109      1   V00MBMNPL     0.000000
# 110      2   V00MBMNPL    -0.000497
# 111      3   V00MBMNPL     0.043323
#
# [112 rows x 3 columns]
# {'0': {'precision': 0.4679245283018868,
#   'recall': 0.6775956284153005,
#   'f1-score': 0.5535714285714286,
#   'support': 183.0},
#  '1': {'precision': 0.40119760479041916,
#   'recall': 0.37640449438202245,
#   'f1-score': 0.3884057971014493,
#   'support': 178.0},
#  '2': {'precision': 0.390625,
#   'recall': 0.21551724137931033,
#   'f1-score': 0.2777777777777778,
#   'support': 116.0},
#  '3': {'precision': 0.7875,
#   'recall': 0.6363636363636364,
#   'f1-score': 0.7039106145251397,
# ...

# %%
from scripts.mbm.kl_oriented.kl_mbm_logR import v00_v03_moaks_kl_lasso_metrics, v00_v03_moaks_kl_lasso_coefs_df

display(v00_v03_moaks_kl_lasso_coefs_df)
display(v00_v03_moaks_kl_lasso_metrics['classification_report'])
print(v00_v03_moaks_kl_lasso_metrics['confusion_matrix'])
# Out:
#      Class     Feature  Coefficient
# 0        0  V00MBMSFMA    -0.060384
# 1        1  V00MBMSFMA    -0.039657
# 2        2  V00MBMSFMA     0.165807
# 3        3  V00MBMSFMA     0.051163
# 4        0  V00MBMSFMC     0.000000
# ..     ...         ...          ...
# 135      3   V00MBMNPM     0.000000
# 136      0   V00MBMNPL    -0.116622
# 137      1   V00MBMNPL    -0.010487
# 138      2   V00MBMNPL     0.038327
# 139      3   V00MBMNPL     0.061880
#
# [140 rows x 3 columns]
# {'0': {'precision': 0.4409722222222222,
#   'recall': 0.7383720930232558,
#   'f1-score': 0.5521739130434783,
#   'support': 172.0},
#  '1': {'precision': 0.358974358974359,
#   'recall': 0.17721518987341772,
#   'f1-score': 0.23728813559322035,
#   'support': 158.0},
#  '2': {'precision': 0.40869565217391307,
#   'recall': 0.3560606060606061,
#   'f1-score': 0.3805668016194332,
#   'support': 132.0},
#  '3': {'precision': 0.7368421052631579,
#   'recall': 0.6140350877192983,
# ...

# %%
from scripts.mbm.kl_oriented.kl_mbm_logR import v01_v03_moaks_kl_lasso_metrics, v01_v03_moaks_kl_lasso_coefs_df

display(v01_v03_moaks_kl_lasso_coefs_df)
display(v01_v03_moaks_kl_lasso_metrics['classification_report'])
print(v01_v03_moaks_kl_lasso_metrics['confusion_matrix'])
# Out:
#      Class     Feature  Coefficient
# 0        0  V01MBMSFMC    -0.110212
# 1        1  V01MBMSFMC    -0.198122
# 2        2  V01MBMSFMC     0.168372
# 3        3  V01MBMSFMC     0.409820
# 4        0  V01MBMSFLC    -0.018968
# ..     ...         ...          ...
# 123      3   V01MBMNPM    -0.013899
# 124      0   V01MBMNPL    -0.134184
# 125      1   V01MBMNPL    -0.146648
# 126      2   V01MBMNPL     0.059155
# 127      3   V01MBMNPL     0.222349
#
# [128 rows x 3 columns]
# {'0': {'precision': 0.44150943396226416,
#   'recall': 0.6802325581395349,
#   'f1-score': 0.5354691075514875,
#   'support': 172.0},
#  '1': {'precision': 0.2897196261682243,
#   'recall': 0.1962025316455696,
#   'f1-score': 0.2339622641509434,
#   'support': 158.0},
#  '2': {'precision': 0.3917525773195876,
#   'recall': 0.2878787878787879,
#   'f1-score': 0.3318777292576419,
#   'support': 132.0},
#  '3': {'precision': 0.7476635514018691,
#   'recall': 0.7017543859649122,
# ...

# %%
from scripts.mbm.kl_oriented.kl_mbm_logR import v00_moaks_kl_change_lasso_metrics, v00_moaks_kl_change_lasso_coefs_df

display(v00_moaks_kl_change_lasso_coefs_df)
display(v00_moaks_kl_change_lasso_metrics['classification_report'])
print(v00_moaks_kl_change_lasso_metrics['confusion_matrix'])
# Out:
#     Class     Feature  Coefficient
# 0       0  V00MBMSFMA          0.0
# 1       1  V00MBMSFMA          0.0
# 2       2  V00MBMSFMA          0.0
# 3       0  V00MBMSFMC          0.0
# 4       1  V00MBMSFMC          0.0
# ..    ...         ...          ...
# 79      1  V00MBMNTMC          0.0
# 80      2  V00MBMNTMC          0.0
# 81      0   V00MBMNPL          0.0
# 82      1   V00MBMNPL          0.0
# 83      2   V00MBMNPL          0.0
#
# [84 rows x 3 columns]
# {'0': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 7.0},
#  '1': {'precision': 0.8940972222222222,
#   'recall': 1.0,
#   'f1-score': 0.9440879926672777,
#   'support': 515.0},
#  '2': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 54.0},
#  'accuracy': 0.8940972222222222,
#  'macro avg': {'precision': 0.2980324074074074,
#   'recall': 0.3333333333333333,
#   'f1-score': 0.3146959975557592,
#   'support': 576.0},
#  'weighted avg': {'precision': 0.7994098427854939,
# ...

# %%
from scripts.mbm.kl_oriented.kl_mbm_logR import v01_moaks_kl_change_lasso_metrics, v01_moaks_kl_change_lasso_coefs_df

display(v01_moaks_kl_change_lasso_coefs_df)
display(v01_moaks_kl_change_lasso_metrics['classification_report'])
print(v01_moaks_kl_change_lasso_metrics['confusion_matrix'])
# Out:
#      Class     Feature  Coefficient
# 0        0  V00MBMSFMA    -0.060525
# 1        1  V00MBMSFMA     0.000000
# 2        2  V00MBMSFMA     0.174096
# 3        0  V00MBMSFMC    -0.391060
# 4        1  V00MBMSFMC     0.764043
# ..     ...         ...          ...
# 100      1   V00MBMNPM    -0.182298
# 101      2   V00MBMNPM     0.029566
# 102      0   V00MBMNPL    -0.330579
# 103      1   V00MBMNPL    -0.087511
# 104      2   V00MBMNPL     0.101569
#
# [105 rows x 3 columns]
# {'0': {'precision': 0.3333333333333333,
#   'recall': 0.14285714285714285,
#   'f1-score': 0.2,
#   'support': 7.0},
#  '1': {'precision': 0.8996478873239436,
#   'recall': 0.9922330097087378,
#   'f1-score': 0.9436749769159741,
#   'support': 515.0},
#  '2': {'precision': 0.6,
#   'recall': 0.05555555555555555,
#   'f1-score': 0.1016949152542373,
#   'support': 54.0},
#  'accuracy': 0.8940972222222222,
#  'macro avg': {'precision': 0.6109937402190924,
#   'recall': 0.39688190270714546,
# ...
