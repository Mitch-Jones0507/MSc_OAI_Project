# %% [markdown]
# # K-L MBM Relationships

# %% [markdown]
# ### Objective:
# To explore the predictive capacity that MOAKS bone marrow lesion (MBM) variables at baseline, 12-months, and a change between baseline and 12-months, have on the K-L score (from the K-L drop dataset) at a 12-month time period, 24-month time period, and a change between 12 and 24-months.
#
# ### Results:

# %% [markdown]
# ## Baseline MBM Variables Linear Regression with 12-Month K-L Score on Drop Dataset

# %%
from IPython.display import display
from scripts.mbm.kl_oriented.kl_mbm_relationships import v00_v01_kl_drop_coef_df

display(v00_v01_kl_drop_coef_df.sort_values(by='p_value', ascending=True))
# Out:
# ...
#        Feature  Coefficient        p_value
# 1    Intercept     0.684502  5.198521e-157
# 5   V00MBMPTMC     0.261374   7.443128e-08
# 3   V00MBMSFMC     0.324357   5.336657e-06
# 10   V00MBMNSS     0.216739   4.818014e-05
# 2   V00MBMSFLC     0.438083   1.075904e-03
# 24   V00MBMSPL     0.099939   3.132457e-03
# 16  V00MBMPFMP     0.147481   1.277836e-02
# 13  V00MBMPTMP     0.194996   1.404123e-02
# 18  V00MBMNFLA     0.133320   1.735387e-02
# 0   V00MBMNFLC     0.693356   1.939781e-02
# 7   V00MBMNTMA     0.241656   9.654064e-02
# 15  V00MBMPFLC    -0.159368   1.081158e-01
# 27  V00MBMSFMA     0.066812   1.126051e-01
# 26  V00MBMPFLA     0.079161   1.328629e-01
# 17  V00MBMSTMA     0.140192   1.342573e-01
# 20  V00MBMSTLC     0.127777   1.369604e-01
# 19  V00MBMPFLP     0.131248   1.552559e-01
# 8   V00MBMNTLC    -0.229907   1.649543e-01
# 22  V00MBMNTMC     0.103856   1.943092e-01
# 14  V00MBMSFLP    -0.162328   1.997543e-01
# 12  V00MBMNFMP     0.195981   2.150538e-01
# ...

# %% [markdown]
# ## Baseline MBM Variables Linear Regression with 24-Month K-L Score on Drop Dataset

# %%
from scripts.mbm.kl_oriented.kl_mbm_relationships import v00_v03_kl_drop_coef_df

display(v00_v03_kl_drop_coef_df.sort_values(by='p_value', ascending=True))
# Out:
#        Feature  Coefficient        p_value
# 0    Intercept     0.792967  1.067750e-180
# 5   V00MBMPTMC     0.279530   7.251611e-08
# 21   V00MBMSPL     0.123420   9.344409e-05
# 4   V00MBMSFMC     0.304253   2.267976e-04
# 11  V00MBMNFLA     0.199898   3.313782e-04
# 12  V00MBMPFMP     0.180006   1.395556e-03
# 15   V00MBMNSS     0.157641   2.904844e-03
# 3   V00MBMSFLC     0.401643   4.166778e-03
# 2   V00MBMNTMA     0.465350   2.144379e-02
# 32   V00MBMPPL    -0.047134   2.358800e-02
# 13  V00MBMPTMP     0.164738   3.773792e-02
# 20  V00MBMSFMA     0.124490   4.283350e-02
# 10  V00MBMPFLP     0.215931   5.598832e-02
# 1   V00MBMNFLC     0.593929   7.505313e-02
# 9   V00MBMSFMP    -0.224759   1.171454e-01
# 24   V00MBMSSS     0.085044   1.206419e-01
# 34   V00MBMSPM     0.045172   1.524119e-01
# 7   V00MBMSFLP    -0.236400   1.638838e-01
# 31   V00MBMPPM    -0.050262   1.803260e-01
# 39  V00MBMPFMC     0.032449   1.901295e-01
# 17  V00MBMPFLC    -0.141381   2.131644e-01
# ...

# %% [markdown]
# ## 12-Month MBM Variables Linear Regression with 24-Month K-L Score on Drop Dataset

# %%
from scripts.mbm.kl_oriented.kl_mbm_relationships import v01_v03_kl_drop_coef_df

display(v01_v03_kl_drop_coef_df.sort_values(by='p_value', ascending=True))
# Out:
#        Feature  Coefficient        p_value
# 0    Intercept     0.762738  3.296100e-171
# 9   V01MBMNFLA     0.233169   6.929011e-07
# 14  V01MBMPTMC     0.186943   5.823055e-05
# 12   V01MBMNSS     0.190004   9.304265e-05
# 19  V01MBMPFMC     0.118115   2.574682e-04
# 15  V01MBMSFMC     0.186894   7.684767e-04
# 34   V01MBMPPL    -0.066273   6.813726e-03
# 23   V01MBMNPL     0.108667   9.533695e-03
# 24  V01MBMPFMP     0.101549   1.094904e-02
# 32   V01MBMPPM    -0.069642   1.419569e-02
# 7   V01MBMNTMC     0.253943   1.511188e-02
# 3   V01MBMNFLC     0.467998   2.425800e-02
# 2   V01MBMSTLA     0.489306   3.087092e-02
# 33  V01MBMPTMP     0.068241   4.435472e-02
# 29   V01MBMSPL     0.079486   4.601680e-02
# 1   V01MBMNTMP     0.515667   5.204514e-02
# 4   V01MBMNTMA     0.398415   7.029093e-02
# 35   V01MBMPSS     0.056653   7.039549e-02
# 5   V01MBMSFLC     0.341872   7.249253e-02
# 13  V01MBMSTMP    -0.189130   7.960237e-02
# 22  V01MBMSTMC     0.111919   1.168084e-01
# ...

# %% [markdown]
# ## Baseline MBM Variables Linear Regression with Change in K-L Score on Drop Dataset

# %%
from scripts.mbm.kl_oriented.kl_mbm_relationships import v00_kl_drop_change_coef_df

display(v00_kl_drop_change_coef_df.sort_values(by='p_value', ascending=True))
# Out:
#        Feature  Coefficient       p_value
# 6    Intercept     0.108464  2.882730e-17
# 0   V00MBMNTLC     0.483923  1.892728e-07
# 27   V00MBMPPL    -0.032312  2.210821e-03
# 5   V00MBMPTLC    -0.115340  3.623810e-03
# 13  V00MBMNFLA     0.066578  4.761620e-03
# 30   V00MBMSPL     0.023481  1.848071e-02
# 21  V00MBMPFLA    -0.039787  3.374049e-02
# 31   V00MBMPPM    -0.022977  5.362373e-02
# 16   V00MBMSSS     0.056837  5.378324e-02
# 10  V00MBMSTLC    -0.088905  5.383262e-02
# 9   V00MBMSTMA    -0.093873  6.116618e-02
# 26  V00MBMPFMP     0.032525  7.493119e-02
# 14   V00MBMNSS    -0.059097  7.516709e-02
# 1   V00MBMNTMA     0.223694  1.242641e-01
# 34  V00MBMSFMC    -0.020104  2.092829e-01
# 11  V00MBMPFLP     0.084683  2.311152e-01
# 2   V00MBMNTLP    -0.186063  2.550122e-01
# 38  V00MBMPFMC     0.015406  2.572477e-01
# 15  V00MBMSFMA     0.057678  2.666202e-01
# 20   V00MBMNPM     0.039792  2.788054e-01
# 33  V00MBMSFMP    -0.020113  3.255938e-01
# ...

# %% [markdown]
# ## 12-Month MBM Variables Linear Regression with Change in K-L Score on Drop Dataset

# %%
from scripts.mbm.kl_oriented.kl_mbm_relationships import v01_kl_drop_change_coef_df

display(v01_kl_drop_change_coef_df.sort_values(by='p_value', ascending=True))
# Out:
#        Feature  Coefficient       p_value
# 7    Intercept     0.093846  6.807484e-14
# 10   V01MBMSSS     0.084012  1.678078e-04
# 9   V01MBMPFMP     0.091540  2.054268e-04
# 13  V01MBMNFLA     0.063911  3.476383e-04
# 16  V01MBMPFMC     0.051360  1.002591e-03
# 3   V01MBMSFMP    -0.121583  1.081602e-03
# 8    V01MBMNSS    -0.093092  1.213178e-03
# 23   V01MBMPPL    -0.035445  2.976266e-03
# 22  V01MBMPFLA    -0.035983  1.443694e-02
# 34   V01MBMPPM    -0.016185  5.267604e-02
# 15  V01MBMPTMA    -0.062063  5.700265e-02
# 1   V01MBMNTLC     0.155665  7.639143e-02
# 5   V01MBMSTLC     0.118529  1.065651e-01
# 24  V01MBMSFMC    -0.035187  1.243462e-01
# 31  V01MBMSFMA     0.020966  1.368579e-01
# 20   V01MBMNPL     0.040537  1.504809e-01
# 44   V01MBMSPL     0.001834  1.836047e-01
# 29   V01MBMNPM     0.022215  2.057341e-01
# 14  V01MBMNTMC    -0.062541  2.064641e-01
# 2   V01MBMNTMA     0.153752  2.071706e-01
# 17  V01MBMSFLC    -0.046050  2.556488e-01
# ...

# %% [markdown]
# ## Baseline MBM PC1-10 Linear Regression with 12-Month K-L Score on Drop Dataset

# %%
from scripts.mbm.kl_oriented.kl_mbm_relationships import v00_v01_kl_drop_reduced_coef_df

display(v00_v01_kl_drop_reduced_coef_df.sort_values(by='p_value', ascending=True))
# Out:
# ...
#       Feature  Coefficient       p_value
# 0   Intercept     1.262253  0.000000e+00
# 1         PC1     0.283393  0.000000e+00
# 3         PC2    -0.053688  7.975999e-17
# 2         PC3     0.059225  8.766943e-15
# 6         PC4    -0.026411  1.232619e-02
# 4         PC8     0.036216  2.290836e-02
# 5        PC10     0.030686  2.355233e-02
# 7         PC7    -0.026406  2.551411e-02
# 8         PC5    -0.013805  4.458874e-02
# 9         PC6    -0.011251  8.895518e-02
# 10        PC9     0.005427  4.771324e-01

# %% [markdown]
# ## Baseline MBM PC1-10 Linear Regression with 24-Month K-L Score on Drop Dataset

# %%
from scripts.mbm.kl_oriented.kl_mbm_relationships import v00_v03_kl_drop_reduced_coef_df

display(v00_v03_kl_drop_reduced_coef_df.sort_values(by='p_value', ascending=True))
# Out:
#       Feature  Coefficient       p_value
# 0   Intercept     1.366416  0.000000e+00
# 1         PC1     0.278463  0.000000e+00
# 3         PC2    -0.057892  4.551223e-17
# 2         PC3     0.063912  2.165760e-15
# 4         PC7    -0.030110  2.748515e-02
# 5        PC10     0.028291  3.600393e-02
# 7         PC5    -0.014105  5.633651e-02
# 6         PC4    -0.020040  1.039647e-01
# 10        PC9     0.006442  3.553633e-01
# 9         PC6    -0.009500  4.602541e-01
# 8         PC8     0.011718  4.885285e-01

# %% [markdown]
# ## 12-Month MBM PC1-10 Linear Regression with 24-Month K-L Score on Drop Dataset

# %%
from scripts.mbm.kl_oriented.kl_mbm_relationships import v01_v03_kl_drop_reduced_coef_df

display(v01_v03_kl_drop_reduced_coef_df.sort_values(by='p_value', ascending=True))
# Out:
#       Feature  Coefficient       p_value
# 0   Intercept     1.362590  0.000000e+00
# 1         PC1     0.282032  0.000000e+00
# 3         PC2    -0.055238  7.610835e-15
# 2         PC3     0.059115  9.484688e-13
# 4         PC7    -0.027197  1.892331e-02
# 7         PC6    -0.020950  4.522243e-02
# 5         PC9     0.021833  4.732920e-02
# 6        PC10     0.021386  1.610008e-01
# 8         PC4    -0.010679  4.902492e-01
# 9         PC5     0.008015  6.216823e-01
# 10        PC8     0.003896  9.254447e-01

# %% [markdown]
# ## Baseline MBM PC1-10 Linear Regression with Change in K-L Score on Drop Dataset

# %%
from scripts.mbm.kl_oriented.kl_mbm_relationships import v00_kl_drop_reduced_change_coef_df

display(v00_kl_drop_reduced_change_coef_df.sort_values(by='p_value', ascending=True))
# Out:
#       Feature  Coefficient       p_value
# 0   Intercept     0.104163  4.343902e-39
# 1         PC8    -0.024498  2.322264e-03
# 8         PC6     0.001751  6.959142e-02
# 2         PC4     0.006371  1.240048e-01
# 4         PC3     0.004687  1.856703e-01
# 3         PC1    -0.004930  2.197958e-01
# 5         PC2    -0.004204  2.453190e-01
# 9         PC9     0.001015  5.929270e-01
# 6         PC7    -0.003703  8.328078e-01
# 7        PC10    -0.002395  9.391278e-01
# 10        PC5    -0.000301  9.727289e-01

# %% [markdown]
# ## 12-Month MBM PC1-10 Linear Regression with Change in K-L Score on Drop Dataset

# %%
from scripts.mbm.kl_oriented.kl_mbm_relationships import v01_kl_drop_reduced_change_coef_df

display(v01_kl_drop_reduced_change_coef_df.sort_values(by='p_value', ascending=True))
# Out:
#       Feature  Coefficient       p_value
# 0   Intercept     0.104340  1.954265e-39
# 1         PC8    -0.025539  2.565255e-04
# 2         PC9     0.019462  3.807787e-04
# 5         PC4     0.011910  8.559936e-03
# 3        PC10    -0.014151  2.167233e-02
# 4         PC7    -0.012990  2.596461e-02
# 6         PC6    -0.009759  1.489660e-01
# 7         PC2    -0.003140  2.829558e-01
# 9         PC3     0.002754  3.510962e-01
# 10        PC1     0.001515  6.477447e-01
# 8         PC5     0.003132  9.642284e-01
