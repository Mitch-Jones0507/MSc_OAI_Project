# %% [markdown]
# # WOMAC MBM Relationships

# %% [markdown]
# ## Baseline MBM Variables Multivariate Regression with 12-Month WOMAC Scores on Drop Dataset

# %%
import pandas as pd
from IPython.display import display
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_v01_womac_p_matrix
pd.set_option('display.max_rows', None)

display(v00_v01_womac_p_matrix)
# Out:
#         Feature  Coefficient       p_value      Target
# 0     Intercept     5.146553  1.506498e-28  V01WOMADLL
# 1    V00MBMSFMA     0.015830  7.809823e-01  V01WOMADLL
# 2    V00MBMSFLA     1.086155  4.770267e-01  V01WOMADLL
# 3    V00MBMSFMC    -1.311874  1.016062e-01  V01WOMADLL
# 4    V00MBMSFLC    -0.209315  7.045028e-01  V01WOMADLL
# 5    V00MBMSFMP    -2.174279  1.514050e-01  V01WOMADLL
# 6    V00MBMSFLP    -1.788579  3.446170e-01  V01WOMADLL
# 7     V00MBMSSS     1.177279  3.389110e-01  V01WOMADLL
# 8    V00MBMSTMA     0.579593  2.953689e-01  V01WOMADLL
# 9    V00MBMSTLA    -1.635290  8.417276e-01  V01WOMADLL
# 10   V00MBMSTMC     2.781427  3.720856e-02  V01WOMADLL
# 11   V00MBMSTLC    -1.887478  1.767192e-01  V01WOMADLL
# 12   V00MBMSTMP     1.659543  4.142943e-01  V01WOMADLL
# 13   V00MBMSTLP    -0.331027  9.492029e-01  V01WOMADLL
# 14    V00MBMSPM     0.241345  9.886245e-01  V01WOMADLL
# 15    V00MBMSPL     2.130996  2.048129e-02  V01WOMADLL
# ...

# %% [markdown]
# ## Baseline MBM Variables Multivariate Regression with 24-Month WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_v03_womac_p_matrix

display(v00_v03_womac_p_matrix)
# Out:
#         Feature  Coefficient       p_value      Target
# 0     Intercept     4.747964  5.205149e-25  V03WOMADLL
# 1    V00MBMSFMA     0.343224  2.149420e-01  V03WOMADLL
# 2    V00MBMSFLA     1.020309  1.340975e-01  V03WOMADLL
# 3    V00MBMSFMC     0.214436  4.532590e-01  V03WOMADLL
# 4    V00MBMSFLC    -1.081956  3.563357e-01  V03WOMADLL
# 5    V00MBMSFMP    -2.967642  2.533182e-02  V03WOMADLL
# 6    V00MBMSFLP     0.161815  8.876239e-01  V03WOMADLL
# 7     V00MBMSSS     1.022299  1.435811e-01  V03WOMADLL
# 8    V00MBMSTMA     0.631108  5.523107e-01  V03WOMADLL
# 9    V00MBMSTLA   -13.863964  1.178040e-01  V03WOMADLL
# 10   V00MBMSTMC     0.928283  5.356407e-01  V03WOMADLL
# 11   V00MBMSTLC    -1.578220  3.194194e-01  V03WOMADLL
# 12   V00MBMSTMP     0.621291  6.453103e-01  V03WOMADLL
# 13   V00MBMSTLP     3.586550  8.983611e-02  V03WOMADLL
# 14    V00MBMSPM    -0.325900  6.166601e-01  V03WOMADLL
# 15    V00MBMSPL     1.336014  1.252690e-02  V03WOMADLL
# ...

# %% [markdown]
# ## 12-Month MBM Variables Multivariate Regression with 24-Month WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v01_v03_womac_p_matrix

display(v01_v03_womac_p_matrix)
# Out:
#         Feature  Coefficient       p_value      Target
# 0     Intercept     4.675435  8.000721e-24  V03WOMADLL
# 1    V01MBMSFMA     0.368311  4.007963e-01  V03WOMADLL
# 2    V01MBMSFLA     0.387477  4.141754e-02  V03WOMADLL
# 3    V01MBMSFMC    -1.505759  8.511831e-01  V03WOMADLL
# 4    V01MBMSFLC    -0.702990  8.617015e-01  V03WOMADLL
# 5    V01MBMSFMP    -1.083567  9.962509e-02  V03WOMADLL
# 6    V01MBMSFLP     0.044087  6.494174e-01  V03WOMADLL
# 7     V01MBMSSS     0.929478  3.346815e-01  V03WOMADLL
# 8    V01MBMSTMA     1.194740  9.712333e-01  V03WOMADLL
# 9    V01MBMSTLA    -2.290312  8.699416e-01  V03WOMADLL
# 10   V01MBMSTMC    -0.910383  5.251473e-01  V03WOMADLL
# 11   V01MBMSTLC     0.809796  8.096123e-01  V03WOMADLL
# 12   V01MBMSTMP    -1.006306  6.148484e-01  V03WOMADLL
# 13   V01MBMSTLP     1.350029  7.537889e-01  V03WOMADLL
# 14    V01MBMSPM     0.576820  3.732294e-01  V03WOMADLL
# 15    V01MBMSPL     1.361727  3.495309e-03  V03WOMADLL
# ...
