# %% [markdown]
# # WOMAC MBM Relationships

# %% [markdown]
# ### Objective:
# To explore the predictive capacity that MOAKS bone marrow lesion (MBM) variables at baseline, 12-months, and a change between baseline and 12-months, have on the two-dimensional vector containing WOMAC functional disability and stiffness (WOMADL, WOMSTF) scores - as well as their principal components - at a 12-month time period, 24-month time period, and a change between 12 and 24-months.
#
# ### Results:

# %% [markdown]
# ## Baseline MBM Variables Multivariate Regression with 12-Month Left Knee WOMAC Scores on Drop Dataset

# %%
import pandas as pd
from IPython.display import display
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_v01_womac_left_p_matrix
pd.set_option('display.max_rows', None)

display(v00_v01_womac_left_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient       p_value      Target
# 46   Intercept     1.163353  1.043926e-52  V01WOMSTFL
# 0    Intercept     5.424109  1.506498e-28  V01WOMADLL
# 41  V00MBMNTLC     9.362955  1.646413e-03  V01WOMADLL
# 35  V00MBMNFMP     4.183698  2.041177e-02  V01WOMADLL
# 15   V00MBMSPL     1.058034  2.048129e-02  V01WOMADLL
# 81  V00MBMNFMP     0.660984  2.274876e-02  V01WOMSTFL
# 10  V00MBMSTMC     3.198874  3.720856e-02  V01WOMADLL
# 32  V00MBMNFLA     1.413051  4.237201e-02  V01WOMADLL
# 26  V00MBMPTLC    -2.384774  4.249770e-02  V01WOMADLL
# 87  V00MBMNTLC     0.814116  6.283933e-02  V01WOMSTFL

# %% [markdown]
# ## Baseline MBM Variables Multivariate Regression with 24-Month Left Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_v03_womac_left_p_matrix

display(v00_v03_womac_left_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient       p_value      Target
# 46   Intercept     0.980764  5.300974e-42  V03WOMSTFL
# 0    Intercept     4.846190  5.205149e-25  V03WOMADLL
# 15   V00MBMSPL     1.684209  1.252690e-02  V03WOMADLL
# 35  V00MBMNFMP     5.127557  1.292114e-02  V03WOMADLL
# 89  V00MBMNTLP    -1.623224  1.385405e-02  V03WOMSTFL
# 74  V00MBMPTLP     0.461839  1.829147e-02  V03WOMSTFL
# 5   V00MBMSFMP    -2.703549  2.533182e-02  V03WOMADLL
# 51  V00MBMSFMP    -0.308751  3.313287e-02  V03WOMSTFL
# 81  V00MBMNFMP     0.713406  4.186934e-02  V03WOMSTFL
# 67  V00MBMPFLP     0.306498  5.950834e-02  V03WOMSTFL

# %% [markdown]
# ## 12-Month MBM Variables Multivariate Regression with 24-Month Left Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v01_v03_womac_left_p_matrix

display(v01_v03_womac_left_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient       p_value      Target
# 46   Intercept     1.003413  3.402170e-41  V03WOMSTFL
# 0    Intercept     4.874700  8.000721e-24  V03WOMADLL
# 15   V01MBMSPL     1.949470  3.495309e-03  V03WOMADLL
# 56  V01MBMSTMC    -0.324349  1.418567e-02  V03WOMSTFL
# 52  V01MBMSFLP    -0.384875  1.937380e-02  V03WOMSTFL
# 62  V01MBMPFMA    -0.190157  2.650307e-02  V03WOMSTFL
# 61   V01MBMSPL     0.268745  3.439280e-02  V03WOMSTFL
# 2   V01MBMSFLA     0.800235  4.141754e-02  V03WOMADLL
# 51  V01MBMSFMP    -0.279952  4.151402e-02  V03WOMSTFL
# 77  V01MBMNFMA     0.366370  4.567297e-02  V03WOMSTFL

# %% [markdown]
# ## Baseline MBM Variables Multivariate Regression with Change in Left Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_womac_left_change_p_matrix

display(v00_womac_left_change_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient   p_value    Target
# 89  V00MBMNTLP    -1.982350  0.000899  ΔWOMSTFL
# 43  V00MBMNTLP   -10.974459  0.001212  ΔWOMADLL
# 3   V00MBMSFMC     3.410574  0.002649  ΔWOMADLL
# 46   Intercept    -0.182589  0.005019  ΔWOMSTFL
# 24  V00MBMPTLA    10.712489  0.008860  ΔWOMADLL
# 28  V00MBMPTLP     2.735922  0.010391  ΔWOMADLL
# 70  V00MBMPTLA     1.987903  0.014998  ΔWOMSTFL
# 74  V00MBMPTLP     0.447824  0.019748  ΔWOMSTFL
# 86  V00MBMNTMC     0.368495  0.027376  ΔWOMSTFL
# 47  V00MBMSFMA     0.319245  0.033471  ΔWOMSTFL

# %% [markdown]
# ## 12-Month MBM Variables Multivariate Regression with Change in Left Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v01_womac_left_change_p_matrix

display(v01_womac_left_change_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient   p_value    Target
# 46   Intercept    -0.180853  0.005853  ΔWOMSTFL
# 89  V01MBMNTLP    -1.400582  0.008997  ΔWOMSTFL
# 41  V01MBMNTLC    -5.648922  0.009716  ΔWOMADLL
# 43  V01MBMNTLP    -6.750505  0.016106  ΔWOMADLL
# 45   V01MBMNPL    -2.179843  0.019782  ΔWOMADLL
# 11  V01MBMSTLC     3.574899  0.027520  ΔWOMADLL
# 37   V01MBMNSS    -2.282156  0.040773  ΔWOMADLL
# 13  V01MBMSTLP     1.943932  0.052949  ΔWOMADLL
# 25  V01MBMPTMC     1.435156  0.069538  ΔWOMADLL
# 60   V01MBMSPM     0.281213  0.070840  ΔWOMSTFL

# %% [markdown]
# ## Baseline MBM Variables Multivariate Regression with PC1, PC2 of 12-Month Left Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_v01_womac_left_pc_p_matrix

display(v00_v01_womac_left_pc_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient   p_value   Target
# 0    Intercept    -0.208636  0.000035  V01LPC1
# 41  V00MBMNTLC     1.262226  0.005909  V01LPC1
# 35  V00MBMNFMP     0.778196  0.009238  V01LPC1
# 15   V00MBMSPL     0.112165  0.053217  V01LPC1
# 22   V00MBMPSS    -0.160903  0.068940  V01LPC1
# 3   V00MBMSFMC    -0.577148  0.072325  V01LPC1
# 32  V00MBMNFLA     0.203825  0.076379  V01LPC1
# 73  V00MBMPTMP     0.081277  0.078521  V01LPC2
# 21  V00MBMPFLP     0.371067  0.080274  V01LPC1
# 74  V00MBMPTLP     0.105176  0.081223  V01LPC2

# %% [markdown]
# ## Baseline MBM Variables Multivariate Regression with PC1, PC2 of 24-Month Left Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_v03_womac_left_pc_p_matrix

display(v00_v03_womac_left_pc_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient       p_value   Target
# 0    Intercept    -0.319260  3.349426e-08  V03LPC1
# 35  V00MBMNFMP     0.888130  1.042885e-02  V03LPC1
# 5   V00MBMSFMP    -0.437163  1.523324e-02  V03LPC1
# 87  V00MBMNTLC    -0.363429  2.053112e-02  V03LPC2
# 72  V00MBMPTLC     0.127279  2.916176e-02  V03LPC2
# 43  V00MBMNTLP    -1.460558  3.712981e-02  V03LPC1
# 44   V00MBMNPM    -0.413556  3.984828e-02  V03LPC1
# 1   V00MBMSFMA     0.205932  5.601759e-02  V03LPC1
# 15   V00MBMSPL     0.199654  5.695082e-02  V03LPC1
# 67  V00MBMPFLP     0.101867  8.165742e-02  V03LPC2

# %% [markdown]
# ## 12-Month MBM Variables Multivariate Regression with PC1, PC2 of 24-Month Left Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v01_v03_womac_left_pc_p_matrix

display(v01_v03_womac_left_pc_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient       p_value   Target
# 0    Intercept    -0.293782  1.486048e-07  V03LPC1
# 52  V01MBMSFLP    -0.304435  9.859318e-04  V03LPC2
# 87  V01MBMNTLC    -0.436711  1.014430e-02  V03LPC2
# 15   V01MBMSPL     0.273500  1.679683e-02  V03LPC1
# 56  V01MBMSTMC    -0.124803  1.713559e-02  V03LPC2
# 67  V01MBMPFLP     0.133392  2.206798e-02  V03LPC2
# 16  V01MBMPFMA    -0.168865  2.805587e-02  V03LPC1
# 74  V01MBMPTLP     0.121822  3.483809e-02  V03LPC2
# 5   V01MBMSFMP    -0.332788  3.657645e-02  V03LPC1
# 54  V01MBMSTMA    -0.141962  6.015619e-02  V03LPC2

# %% [markdown]
# ## Baseline MBM Variables Multivariate Regression with PC1, PC2 of Change in Left Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_womac_left_change_pc_p_matrix

display(v00_womac_left_change_pc_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient   p_value Target
# 43  V00MBMNTLP    -2.515200  0.000063  ΔLPC1
# 28  V00MBMPTLP     0.604605  0.002854  ΔLPC1
# 3   V00MBMSFMC     0.507209  0.003439  ΔLPC1
# 73  V00MBMPTMP    -0.139313  0.008004  ΔLPC2
# 13  V00MBMSTLP     0.614537  0.010080  ΔLPC1
# 24  V00MBMPTLA     2.058230  0.011128  ΔLPC1
# 49  V00MBMSFMC    -0.217823  0.055288  ΔLPC2
# 1   V00MBMSFMA     0.282289  0.059902  ΔLPC1
# 10  V00MBMSTMC    -0.278230  0.064729  ΔLPC1
# 9   V00MBMSTLA    -2.195454  0.071191  ΔLPC1

# %% [markdown]
# ## 12-Month MBM Variables Multivariate Regression with PC1, PC2 of Change in Left Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v01_womac_left_change_pc_p_matrix

display(v01_womac_left_change_pc_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient   p_value Target
# 43  V01MBMNTLP    -1.745849  0.001532  ΔLPC1
# 73  V01MBMPTMP    -0.135781  0.004203  ΔLPC2
# 13  V01MBMSTLP     0.516997  0.014659  ΔLPC1
# 41  V01MBMNTLC    -0.853661  0.040382  ΔLPC1
# 45   V01MBMNPL    -0.378559  0.042593  ΔLPC1
# 91   V01MBMNPL     0.111691  0.052237  ΔLPC2
# 88  V01MBMNTMP     0.262324  0.058864  ΔLPC2
# 1   V01MBMSFMA     0.323643  0.066091  ΔLPC1
# 54  V01MBMSTMA    -0.109313  0.072570  ΔLPC2
# 69  V01MBMPTMA     0.044567  0.073795  ΔLPC2

# %% [markdown]
# ## Baseline MBM Variables Multivariate Regression with 12-Month Right Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_v01_womac_right_p_matrix

display(v00_v01_womac_right_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient       p_value      Target
# 46   Intercept     1.123023  4.659962e-52  V01WOMSTFR
# 0    Intercept     4.128809  1.515918e-26  V01WOMADLR
# 28  V00MBMPTLP    -4.421108  7.259736e-03  V01WOMADLR
# 23  V00MBMPTMA     3.596551  8.012196e-03  V01WOMADLR
# 22   V00MBMPSS    -0.991407  2.521138e-02  V01WOMADLR
# 47  V00MBMSFMA     0.447013  2.688428e-02  V01WOMSTFR
# 15   V00MBMSPL     1.602796  2.987463e-02  V01WOMADLR
# 7    V00MBMSSS     1.268396  3.846320e-02  V01WOMADLR
# 69  V00MBMPTMA     0.440075  4.386912e-02  V01WOMSTFR
# 65  V00MBMPFLC    -1.028478  5.421016e-02  V01WOMSTFR

# %% [markdown]
# ## Baseline MBM Variables Multivariate Regression with 24-Month Right Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_v03_womac_right_p_matrix

display(v00_v03_womac_right_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient       p_value      Target
# 46   Intercept     1.135805  8.960741e-51  V03WOMSTFR
# 0    Intercept     4.972418  3.721314e-29  V03WOMADLR
# 42  V00MBMNTMP     9.789229  5.282214e-03  V03WOMADLR
# 15   V00MBMSPL     1.478368  7.207904e-03  V03WOMADLR
# 35  V00MBMNFMP    -0.007238  1.230368e-02  V03WOMADLR
# 81  V00MBMNFMP     0.369426  1.981892e-02  V03WOMSTFR
# 73  V00MBMPTMP    -0.410668  3.310204e-02  V03WOMSTFR
# 88  V00MBMNTMP     1.188895  4.215452e-02  V03WOMSTFR
# 27  V00MBMPTMP    -2.135539  5.502951e-02  V03WOMADLR
# 90   V00MBMNPM     0.253901  5.692354e-02  V03WOMSTFR

# %% [markdown]
# ## 12-Month MBM Variables Multivariate Regression with 24-Month Right Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v01_v03_womac_right_p_matrix

display(v01_v03_womac_right_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient       p_value      Target
# 46   Intercept     1.151033  3.042293e-50  V03WOMSTFR
# 0    Intercept     5.019926  1.892110e-28  V03WOMADLR
# 42  V01MBMNTMP    10.836920  2.123750e-03  V03WOMADLR
# 88  V01MBMNTMP     1.244255  8.961834e-03  V03WOMSTFR
# 31  V01MBMNFMA     3.031032  9.818966e-03  V03WOMADLR
# 27  V01MBMPTMP    -3.295543  1.779078e-02  V03WOMADLR
# 90   V01MBMNPM     0.399568  1.794087e-02  V03WOMSTFR
# 73  V01MBMPTMP    -0.535317  1.831352e-02  V03WOMSTFR
# 13  V01MBMSTLP     5.608660  2.442922e-02  V03WOMADLR
# 15   V01MBMSPL     1.236015  2.856185e-02  V03WOMADLR

# %% [markdown]
# ## Baseline MBM Variables Multivariate Regression with Change in Right Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_womac_right_change_p_matrix

display(v00_womac_right_change_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient   p_value    Target
# 42  V00MBMNTMP     8.437397  0.003592  ΔWOMADLR
# 25  V00MBMPTMC     1.842324  0.007710  ΔWOMADLR
# 30   V00MBMPPL    -0.612622  0.026156  ΔWOMADLR
# 71  V00MBMPTMC     0.272310  0.038521  ΔWOMSTFR
# 28  V00MBMPTLP     3.265378  0.041143  ΔWOMADLR
# 88  V00MBMNTMP     1.083273  0.050959  ΔWOMSTFR
# 70  V00MBMPTLA     2.486986  0.052924  ΔWOMSTFR
# 27  V00MBMPTMP    -1.049367  0.054904  ΔWOMADLR
# 43  V00MBMNTLP    -9.792631  0.085266  ΔWOMADLR
# 40  V00MBMNTMC    -4.089503  0.101587  ΔWOMADLR

# %% [markdown]
# ## 12-Month MBM Variables Multivariate Regression with Change in Right Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v01_womac_right_change_p_matrix

display(v01_womac_right_change_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient   p_value    Target
# 42  V01MBMNTMP     7.798548  0.006785  ΔWOMADLR
# 47  V01MBMSFMA    -0.476809  0.007957  ΔWOMSTFR
# 2   V01MBMSFLA    -1.884587  0.016298  ΔWOMADLR
# 25  V01MBMPTMC     1.476692  0.018994  ΔWOMADLR
# 21  V01MBMPFLP     2.988510  0.020322  ΔWOMADLR
# 28  V01MBMPTLP     4.549452  0.021981  ΔWOMADLR
# 30   V01MBMPPL    -0.669920  0.023415  ΔWOMADLR
# 27  V01MBMPTMP    -1.551360  0.029820  ΔWOMADLR
# 86  V01MBMNTMC    -0.722461  0.035371  ΔWOMSTFR
# 9   V01MBMSTLA    -9.243706  0.042024  ΔWOMADLR

# %% [markdown]
# ## Baseline MBM Variables Multivariate Regression with PC1, PC2 of 12-Month Right Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_v01_womac_right_pc_p_matrix

display(v00_v01_womac_right_pc_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient   p_value   Target
# 0    Intercept    -0.412391  0.000045  V01RPC1
# 23  V00MBMPTMA     0.563327  0.010971  V01RPC1
# 8   V00MBMSTMA    -0.319686  0.032615  V01RPC1
# 66  V00MBMPFMP    -0.127732  0.033149  V01RPC2
# 28  V00MBMPTLP    -0.505545  0.036161  V01RPC1
# 15   V00MBMSPL     0.239360  0.066793  V01RPC1
# 51  V00MBMSFMP     0.150530  0.068804  V01RPC2
# 68   V00MBMPSS     0.059501  0.072098  V01RPC2
# 1   V00MBMSFMA     0.367899  0.077910  V01RPC1
# 65  V00MBMPFLC    -0.313760  0.085084  V01RPC2

# %% [markdown]
# ## Baseline MBM Variables Multivariate Regression with PC1, PC2 of 24-Month Right Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_v03_womac_right_pc_p_matrix

display(v00_v03_womac_right_pc_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient   p_value   Target
# 0    Intercept    -0.351634  0.000194  V03RPC1
# 35  V00MBMNFMP     0.063258  0.012248  V03RPC1
# 77  V00MBMNFMA    -0.198914  0.012484  V03RPC2
# 42  V00MBMNTMP     1.396550  0.013392  V03RPC1
# 15   V00MBMSPL     0.187626  0.031856  V03RPC1
# 27  V00MBMPTMP    -0.361358  0.045421  V03RPC1
# 65  V00MBMPFLC    -0.329128  0.057922  V03RPC2
# 18  V00MBMPFMC     0.289971  0.068217  V03RPC1
# 22   V00MBMPSS    -0.187658  0.076318  V03RPC1
# 52  V00MBMSFLP     0.352708  0.089207  V03RPC2

# %% [markdown]
# ## 12-Month MBM Variables Multivariate Regression with PC1, PC2 of 24-Month Right Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v01_v03_womac_right_pc_p_matrix

display(v01_v03_womac_right_pc_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient   p_value   Target
# 0    Intercept    -0.340737  0.000443  V03RPC1
# 42  V01MBMNTMP     1.573409  0.004284  V03RPC1
# 31  V01MBMNFMA     0.513929  0.012988  V03RPC1
# 27  V01MBMPTMP    -0.529945  0.016832  V03RPC1
# 57  V01MBMSTLC     0.322108  0.020952  V03RPC2
# 90   V01MBMNPM     0.148077  0.035017  V03RPC2
# 29   V01MBMPPM    -0.170430  0.045335  V03RPC1
# 35  V01MBMNFMP     0.184594  0.050084  V03RPC1
# 64  V01MBMPFMC    -0.057256  0.052336  V03RPC2
# 15   V01MBMSPL     0.175294  0.057496  V03RPC1

# %% [markdown]
# ## Baseline MBM Variables Multivariate Regression with PC1, PC2 of Change in Right Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_womac_right_change_pc_p_matrix

display(v00_womac_right_change_pc_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient   p_value Target
# 90   V00MBMNPM     0.297357  0.002660  ΔRPC2
# 25  V00MBMPTMC     0.397483  0.003952  ΔRPC1
# 77  V00MBMNFMA    -0.329849  0.004390  ΔRPC2
# 42  V00MBMNTMP     1.435537  0.009928  ΔRPC1
# 83   V00MBMNSS    -0.368812  0.023555  ΔRPC2
# 8   V00MBMSTMA     0.513839  0.030329  ΔRPC1
# 56  V00MBMSTMC    -0.097885  0.036719  ΔRPC2
# 75   V00MBMPPM    -0.091048  0.037356  ΔRPC2
# 72  V00MBMPTLC    -0.357202  0.043036  ΔRPC2
# 28  V00MBMPTLP     0.616186  0.046586  ΔRPC1

# %% [markdown]
# ## 12-Month MBM Variables Multivariate Regression with PC1, PC2 of Change in Right Knee WOMAC Scores on Drop Dataset

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v01_womac_right_change_pc_p_matrix

display(v01_womac_right_change_pc_p_matrix.sort_values(by='p_value').head(10))
# Out:
#        Feature  Coefficient   p_value Target
# 75   V01MBMPPM    -0.129182  0.009896  ΔRPC2
# 57  V01MBMSTLC     0.519222  0.015895  ΔRPC2
# 30   V01MBMPPL    -0.115994  0.018166  ΔRPC1
# 25  V01MBMPTMC     0.293585  0.019063  ΔRPC1
# 21  V01MBMPFLP     0.560630  0.020809  ΔRPC1
# 28  V01MBMPTLP     0.899321  0.022548  ΔRPC1
# 42  V01MBMNTMP     1.186634  0.025218  ΔRPC1
# 2   V01MBMSFLA    -0.317738  0.027917  ΔRPC1
# 90   V01MBMNPM     0.189341  0.035938  ΔRPC2
# 40  V01MBMNTMC    -0.767704  0.037543  ΔRPC1

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_v01_womac_left_pls_coef_matrix, v00_v01_womac_left_pls_constructs

display(v00_v01_womac_left_pls_coef_matrix.sort_values(by='Coefficient',ascending=False).head(10))
display(v00_v01_womac_left_pls_constructs.head(10))
# Out:
#        Feature  Coefficient      Target
# 0    Intercept     5.472096  V01WOMADLL
# 46   Intercept     1.120199  V01WOMSTFL
# 32  V00MBMNFLA     0.795433  V01WOMADLL
# 2   V00MBMSFLA     0.638960  V01WOMADLL
# 31  V00MBMNFMA     0.591049  V01WOMADLL
# 45   V00MBMNPL     0.587594  V01WOMADLL
# 15   V00MBMSPL     0.523907  V01WOMADLL
# 43  V00MBMNTLP     0.471528  V01WOMADLL
# 38  V00MBMNTMA     0.469815  V01WOMADLL
# 17  V00MBMPFLA     0.432460  V01WOMADLL
#       PLS Component 1  PLS Component 2
# 584         -1.106804        -0.300397
# 1057        -2.886119        -3.474312
# 10          -1.106804        -0.300397
# 514         -0.763848        -2.662955
# 424          0.201856         2.078012
# 1211        -1.106804        -0.300397
# 59          -1.106804        -0.300397
# 1079        -1.106804        -0.300397
# 63           4.987665         1.562725
# 478         -0.971748        -0.349691

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_v03_womac_left_pls_coef_matrix, v00_v03_womac_left_pls_constructs

display(v00_v03_womac_left_pls_coef_matrix.sort_values(by='Coefficient',ascending=False).head(10))
display(v00_v03_womac_left_pls_constructs.head(10))
# Out:
#        Feature  Coefficient      Target
# 0    Intercept     4.638187  V03WOMADLL
# 39  V00MBMNTLA     3.133218  V03WOMADLL
# 24  V00MBMPTLA     1.383663  V03WOMADLL
# 9   V00MBMSTLA     0.996910  V03WOMADLL
# 46   Intercept     0.959936  V03WOMSTFL
# 15   V00MBMSPL     0.668011  V03WOMADLL
# 2   V00MBMSFLA     0.638051  V03WOMADLL
# 32  V00MBMNFLA     0.637881  V03WOMADLL
# 45   V00MBMNPL     0.614792  V03WOMADLL
# 85  V00MBMNTLA     0.549881  V03WOMSTFL
#       PLS Component 1  PLS Component 2
# 584         -1.606544        -1.053609
# 1057        -0.139768         6.876965
# 10          -1.606544        -1.053609
# 514         -1.492746         0.204019
# 424          0.311395        -0.730075
# 1211        -1.606544        -1.053609
# 59          -1.606544        -1.053609
# 1079        -1.606544        -1.053609
# 63           5.122661         0.632719
# 478         -1.467928        -0.222756

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v01_v03_womac_left_pls_coef_matrix, v01_v03_womac_left_pls_constructs

display(v01_v03_womac_left_pls_coef_matrix.sort_values(by='Coefficient',ascending=False).head(10))
display(v01_v03_womac_left_pls_constructs.head(10))
# Out:
#        Feature  Coefficient      Target
# 0    Intercept     4.738787  V03WOMADLL
# 39  V01MBMNTLA     1.301496  V03WOMADLL
# 46   Intercept     0.969538  V03WOMSTFL
# 15   V01MBMSPL     0.692047  V03WOMADLL
# 24  V01MBMPTLA     0.661431  V03WOMADLL
# 2   V01MBMSFLA     0.625157  V03WOMADLL
# 32  V01MBMNFLA     0.612695  V03WOMADLL
# 45   V01MBMNPL     0.611460  V03WOMADLL
# 17  V01MBMPFLA     0.467108  V03WOMADLL
# 9   V01MBMSTLA     0.458802  V03WOMADLL
#       PLS Component 1  PLS Component 2
# 584         -1.596517        -1.017697
# 1057         0.050283         5.570169
# 10          -1.596517        -1.017697
# 514         -1.058062        -0.071486
# 424         -0.721079         2.426504
# 1211        -1.596517        -1.017697
# 59           0.305946        -1.668972
# 1079        -1.596517        -1.017697
# 63           4.582120         1.120993
# 478         -1.366269        -0.386924

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_womac_left_change_pls_coef_matrix, v00_womac_left_change_pls_constructs

display(v00_womac_left_change_pls_coef_matrix.sort_values(by='Coefficient',ascending=False).head(10))
display(v00_womac_left_change_pls_constructs.head(10))
# Out:
#        Feature  Coefficient    Target
# 39  V00MBMNTLA     4.307724  ΔWOMADLL
# 24  V00MBMPTLA     1.819262  ΔWOMADLL
# 9   V00MBMSTLA     1.645247  ΔWOMADLL
# 85  V00MBMNTLA     1.107846  ΔWOMSTFL
# 70  V00MBMPTLA     0.481908  ΔWOMSTFL
# 40  V00MBMNTMC     0.434426  ΔWOMADLL
# 55  V00MBMSTLA     0.402656  ΔWOMSTFL
# 6   V00MBMSFLP     0.247286  ΔWOMADLL
# 4   V00MBMSFLC     0.238320  ΔWOMADLL
# 14   V00MBMSPM     0.197863  ΔWOMADLL
#       PLS Component 1  PLS Component 2
# 584         -1.074264        -0.520484
# 1057         3.615668         7.244968
# 10          -1.074264        -0.520484
# 514         -1.502852         2.292233
# 424          0.258121        -2.167679
# 1211        -1.074264        -0.520484
# 59          -1.074264        -0.520484
# 1079        -1.074264        -0.520484
# 63           1.430759        -0.471582
# 478         -1.024370         0.314360

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_v01_womac_right_pls_coef_matrix, v00_v01_womac_right_pls_constructs

display(v00_v01_womac_right_pls_coef_matrix.sort_values(by='Coefficient',ascending=False).head(10))
display(v00_v01_womac_right_pls_constructs.head(10))
# Out:
#        Feature  Coefficient      Target
# 0    Intercept     4.145418  V01WOMADLR
# 38  V00MBMNTMA     1.177517  V01WOMADLR
# 46   Intercept     1.153495  V01WOMSTFR
# 1   V00MBMSFMA     0.717057  V01WOMADLR
# 2   V00MBMSFLA     0.684968  V01WOMADLR
# 32  V00MBMNFLA     0.653693  V01WOMADLR
# 41  V00MBMNTLC     0.586831  V01WOMADLR
# 31  V00MBMNFMA     0.567761  V01WOMADLR
# 23  V00MBMPTMA     0.492479  V01WOMADLR
# 42  V00MBMNTMP     0.483398  V01WOMADLR
#       PLS Component 1  PLS Component 2
# 1009        -2.292760         0.274145
# 628         -0.601173         1.015338
# 644         -1.224600        -0.880945
# 884         -1.440458         0.910654
# 591         -0.383695        -1.678143
# 342         -1.117638         0.580581
# 853         -1.803743        -0.202240
# 312         -0.413652        -0.132212
# 308         -0.840973        -0.008184
# 736         -1.451855        -0.523054

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_v03_womac_right_pls_coef_matrix, v00_v03_womac_right_pls_constructs

display(v00_v03_womac_right_pls_coef_matrix.sort_values(by='Coefficient',ascending=False).head(10))
display(v00_v03_womac_right_pls_constructs.head(10))
# Out:
#        Feature  Coefficient      Target
# 0    Intercept     4.960304  V03WOMADLR
# 42  V00MBMNTMP     1.353041  V03WOMADLR
# 46   Intercept     1.105043  V03WOMSTFR
# 35  V00MBMNFMP     0.705423  V03WOMADLR
# 38  V00MBMNTMA     0.653382  V03WOMADLR
# 36  V00MBMNFLP     0.608485  V03WOMADLR
# 44   V00MBMNPM     0.514421  V03WOMADLR
# 5   V00MBMSFMP     0.503578  V03WOMADLR
# 6   V00MBMSFLP     0.487239  V03WOMADLR
# 32  V00MBMNFLA     0.467132  V03WOMADLR
#       PLS Component 1  PLS Component 2
# 1009        -2.282658         0.340381
# 628         -0.490716         0.737644
# 644         -1.468490        -0.428505
# 884         -1.305156         0.627592
# 591         -0.347138        -1.659604
# 342         -1.210221         0.805108
# 853         -1.621967        -0.414892
# 312         -0.309480        -0.180313
# 308          0.008310        -1.151082
# 736         -1.161306        -0.890718

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v01_v03_womac_right_pls_coef_matrix, v01_v03_womac_right_pls_constructs

display(v01_v03_womac_right_pls_coef_matrix.sort_values(by='Coefficient',ascending=False).head(10))
display(v01_v03_womac_right_pls_constructs.head(10))
# Out:
#        Feature  Coefficient      Target
# 0    Intercept     4.814971  V03WOMADLR
# 42  V01MBMNTMP     1.310768  V03WOMADLR
# 46   Intercept     1.101206  V03WOMSTFR
# 31  V01MBMNFMA     0.552054  V03WOMADLR
# 32  V01MBMNFLA     0.540649  V03WOMADLR
# 13  V01MBMSTLP     0.490540  V03WOMADLR
# 44   V01MBMNPM     0.462265  V03WOMADLR
# 35  V01MBMNFMP     0.440889  V03WOMADLR
# 5   V01MBMSFMP     0.432135  V03WOMADLR
# 15   V01MBMSPL     0.424408  V03WOMADLR
#       PLS Component 1  PLS Component 2
# 1009        -2.391226         0.386000
# 628         -0.598832         1.088952
# 644         -1.659273        -0.562594
# 884         -1.609381         0.583493
# 591         -0.628563        -1.642673
# 342         -2.391226         0.386000
# 853          0.077559        -1.904287
# 312         -0.534107         0.162390
# 308         -0.904070        -0.257773
# 736         -1.360516        -0.694079

# %%
from scripts.mbm.womac_oriented.womac_mbm_relationships import v00_womac_right_change_pls_coef_matrix, v00_womac_right_change_pls_constructs

display(v00_womac_right_change_pls_coef_matrix.sort_values(by='Coefficient', ascending=False).head(10))
display(v00_womac_right_change_pls_constructs.head(10))
# Out:
#        Feature  Coefficient    Target
# 39  V00MBMNTLA     1.709565  ΔWOMADLR
# 42  V00MBMNTMP     1.123803  ΔWOMADLR
# 0    Intercept     0.828295  ΔWOMADLR
# 24  V00MBMPTLA     0.681393  ΔWOMADLR
# 9   V00MBMSTLA     0.664349  ΔWOMADLR
# 34  V00MBMNFLC     0.611650  ΔWOMADLR
# 35  V00MBMNFMP     0.485998  ΔWOMADLR
# 4   V00MBMSFLC     0.472124  ΔWOMADLR
# 19  V00MBMPFLC     0.338955  ΔWOMADLR
# 36  V00MBMNFLP     0.291960  ΔWOMADLR
#       PLS Component 1  PLS Component 2
# 1009        -1.377828        -0.901673
# 628         -0.399469         0.619484
# 644         -0.553405        -1.664987
# 884         -0.936357         0.252580
# 591         -0.597261        -1.009992
# 342         -0.495153        -0.565568
# 853         -1.416981        -0.482753
# 312         -0.470697        -0.174510
# 308         -2.638042         1.517116
# 736         -1.421684        -0.246678
