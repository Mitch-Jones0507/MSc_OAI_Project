# %% [markdown]
# # WOMAC Relationships

# %% [markdown]
# ### Objective:
# To highlight the dependency that WOMAC subvariables (in both drop and median datasets), functional disability score, pain score, and stiffness score (WOMADL, WOMKPR, WOMSTF) have on one another using PCA and linear/poly/interaction regression to reduce dimensionality of the three-dimensional vector for further analyses.
#
# ### Results:
# From PCA and multiple linear/polynomial/interaction regression, WOMADL and WOMKPR seem nearly perfectly colinear.

# %% [markdown]
# ## 12-Month WOMAC Left Knee Variables PCA on Drop Dataset

# %%
import pandas as pd
from scripts.womac.womac_relationships import v01_womac_left_drop_pc_variance, v01_womac_left_drop_pc_variance_ratio, \
    v01_womac_left_drop_pc_loadings, v01_womac_left_drop_df

pc_df = pd.DataFrame({
    'PC': [f'PC{i+1}' for i in range(len(v01_womac_left_drop_pc_variance))],
    'Variance': v01_womac_left_drop_pc_variance,
    'Proportion of Total': v01_womac_left_drop_pc_variance_ratio
})

loadings_df = pd.DataFrame(v01_womac_left_drop_pc_loadings,index=v01_womac_left_drop_df.columns.to_list(),columns=[f'PC{i+1}' for i in range(len(v01_womac_left_drop_pc_variance))])

display(pc_df)
display(loadings_df)
# Out:
# Warning: column count mismatch (101 + 255 != 779)
#     PC  Variance  Proportion of Total
# 0  PC1  2.611029             0.869965
# 1  PC2  0.271454             0.090445
# 2  PC3  0.118819             0.039589
#                  PC1       PC2       PC3
# V01WOMADLL  0.954882 -0.141811  0.261770
# V01WOMKPL   0.939256 -0.265242 -0.218812
# V01WOMSTFL  0.903895  0.425429 -0.049165

# %% [markdown]
# ## 24-Month WOMAC Left Knee Variables PCA on Drop Dataset

# %%
from scripts.womac.womac_relationships import v03_womac_left_drop_pc_variance, v03_womac_left_drop_pc_variance_ratio, v03_womac_left_drop_pc_loadings, v03_womac_left_drop_df

pc_df = pd.DataFrame({
    'PC': [f'PC{i+1}' for i in range(len(v03_womac_left_drop_pc_variance))],
    'Variance': v03_womac_left_drop_pc_variance,
    'Proportion of Total': v03_womac_left_drop_pc_variance_ratio
})

loadings_df = pd.DataFrame(v03_womac_left_drop_pc_loadings, index=v03_womac_left_drop_df.columns.to_list(), columns=[f'PC{i + 1}' for i in range(len(v03_womac_left_drop_pc_variance))])

display(pc_df)
display(loadings_df)
# Out:
#     PC  Variance  Proportion of Total
# 0  PC1  2.583156             0.860678
# 1  PC2  0.296540             0.098804
# 2  PC3  0.121606             0.040518
#                  PC1       PC2       PC3
# V03WOMADLL  0.953547 -0.144872  0.264943
# V03WOMKPL   0.935088 -0.278031 -0.220777
# V03WOMSTFL  0.894156  0.445254 -0.051656

# %% [markdown]
# ## Change in WOMAC Left Knee Variables PCA on Drop Dataset

# %%
from scripts.womac.womac_relationships import womac_left_drop_change_pc_variance, womac_left_drop_change_pc_variance_ratio, womac_left_drop_change_pc_loadings, womac_left_drop_change_df

pc_df = pd.DataFrame({
    'PC': [f'PC{i+1}' for i in range(len(womac_left_drop_change_pc_variance))],
    'Variance': womac_left_drop_change_pc_variance,
    'Proportion of Total': womac_left_drop_change_pc_variance_ratio
})

loadings_df = pd.DataFrame(womac_left_drop_change_pc_loadings, index=womac_left_drop_change_df.columns.to_list(), columns=[f'PC{i + 1}' for i in range(len(womac_left_drop_change_pc_variance))])

display(pc_df)
display(loadings_df)
# Out:
#     PC  Variance  Proportion of Total
# 0  PC1  2.290857             0.763288
# 1  PC2  0.475773             0.158522
# 2  PC3  0.234672             0.078190
#                PC1       PC2       PC3
# ΔWOMADLL  0.913533 -0.181581  0.364582
# ΔWOMKPL   0.887635 -0.339990 -0.311361
# ΔWOMSTFL  0.817569  0.572021 -0.069330

# %% [markdown]
# ## 12-Month WOMAC Right Knee Variables PCA on Drop Dataset

# %%
from scripts.womac.womac_relationships import v01_womac_right_drop_pc_variance, v01_womac_right_drop_pc_variance_ratio, v01_womac_right_drop_pc_loadings, v01_womac_right_drop_df

pc_df = pd.DataFrame({
    'PC': [f'PC{i+1}' for i in range(len(v01_womac_right_drop_pc_variance))],
    'Variance': v01_womac_right_drop_pc_variance,
    'Proportion of Total': v01_womac_right_drop_pc_variance_ratio
})

loadings_df = pd.DataFrame(v01_womac_right_drop_pc_loadings,index=v01_womac_right_drop_df.columns.to_list(),columns=[f'PC{i+1}' for i in range(len(v01_womac_right_drop_pc_variance))])

display(pc_df)
display(loadings_df)
# Out:
#     PC  Variance  Proportion of Total
# 0  PC1  2.504212             0.834375
# 1  PC2  0.346919             0.115589
# 2  PC3  0.150173             0.050036
#                  PC1       PC2       PC3
# V01WOMADLR  0.943877 -0.150136  0.294940
# V01WOMKPR   0.921374 -0.303504 -0.243700
# V01WOMSTFR  0.874287  0.481937 -0.061591

# %% [markdown]
# ## 24-Month WOMAC Right Knee Variables PCA on Drop Dataset

# %%
from scripts.womac.womac_relationships import v03_womac_right_drop_pc_variance, v03_womac_right_drop_pc_variance_ratio, v03_womac_right_drop_pc_loadings, v03_womac_right_drop_df

pc_df = pd.DataFrame({
    'PC': [f'PC{i+1}' for i in range(len(v03_womac_right_drop_pc_variance))],
    'Variance': v03_womac_right_drop_pc_variance,
    'Proportion of Total': v03_womac_right_drop_pc_variance_ratio
})

loadings_df = pd.DataFrame(v03_womac_right_drop_pc_loadings,index=v03_womac_right_drop_df.columns.to_list(),columns=[f'PC{i+1}' for i in range(len(v03_womac_right_drop_pc_variance))])

display(pc_df)
display(loadings_df)
# Out:
#     PC  Variance  Proportion of Total
# 0  PC1  2.542652             0.847183
# 1  PC2  0.306955             0.102274
# 2  PC3  0.151696             0.050543
#                  PC1       PC2       PC3
# V03WOMADLR  0.945340 -0.128768  0.300308
# V03WOMKPR   0.924207 -0.300056 -0.237154
# V03WOMSTFR  0.891529  0.447594 -0.072587

# %% [markdown]
# ## Change in WOMAC Right Knee Variables PCA on Drop Dataset

# %%
from scripts.womac.womac_relationships import womac_right_drop_change_pc_variance, womac_right_drop_change_pc_variance_ratio, womac_right_drop_change_pc_loadings, womac_right_drop_change_df

pc_df = pd.DataFrame({
    'PC': [f'PC{i+1}' for i in range(len(womac_right_drop_change_pc_variance))],
    'Variance': womac_right_drop_change_pc_variance,
    'Proportion of Total': womac_right_drop_change_pc_variance_ratio
})

loadings_df = pd.DataFrame(womac_right_drop_change_pc_loadings, index=womac_right_drop_change_df.columns.to_list(), columns=[f'PC{i + 1}' for i in range(len(womac_right_drop_change_pc_variance))])

display(pc_df)
display(loadings_df)
# Out:
#     PC  Variance  Proportion of Total
# 0  PC1  1.746444             0.581895
# 1  PC2  0.924208             0.307935
# 2  PC3  0.330651             0.110169
#                PC1       PC2       PC3
# ΔWOMADLR  0.899766 -0.144875  0.412148
# ΔWOMKPR   0.872749 -0.285374 -0.396618
# ΔWOMSTFR  0.418538  0.906521 -0.058988

# %% [markdown]
# ## 12-Month WOMAC Left Knee Variables PCA on Median Dataset

# %%
from scripts.womac.womac_relationships import v01_womac_left_median_pc_variance, v01_womac_left_median_pc_variance_ratio, v01_womac_left_median_pc_loadings, v01_womac_left_median_df

pc_df = pd.DataFrame({
    'PC': [f'PC{i+1}' for i in range(len(v01_womac_left_median_pc_variance))],
    'Variance': v01_womac_left_median_pc_variance,
    'Proportion of Total': v01_womac_left_median_pc_variance_ratio
})

loadings_df = pd.DataFrame(v01_womac_left_median_pc_loadings,index=v01_womac_left_median_df.columns.to_list(),columns=[f'PC{i+1}' for i in range(len(v01_womac_left_median_pc_variance))])

display(pc_df)
display(loadings_df)
# Out:
#     PC  Variance  Proportion of Total
# 0  PC1  2.596255             0.865137
# 1  PC2  0.276820             0.092243
# 2  PC3  0.127900             0.042620
#                  PC1       PC2       PC3
# V01WOMADLL  0.950413 -0.159219  0.267747
# V01WOMKPL   0.938701 -0.253879 -0.233904
# V01WOMSTFL  0.901005  0.432452 -0.038739

# %% [markdown]
# ## 24-Month WOMAC Left Knee Variables PCA on Median Dataset

# %%
from scripts.womac.womac_relationships import v03_womac_left_median_pc_variance, v03_womac_left_median_pc_variance_ratio, v03_womac_left_median_pc_loadings, v03_womac_left_median_df

pc_df = pd.DataFrame({
    'PC': [f'PC{i+1}' for i in range(len(v03_womac_left_median_pc_variance))],
    'Variance': v03_womac_left_median_pc_variance,
    'Proportion of Total': v03_womac_left_median_pc_variance_ratio
})

loadings_df = pd.DataFrame(v03_womac_left_median_pc_loadings, index=v03_womac_left_median_df.columns.to_list(), columns=[f'PC{i + 1}' for i in range(len(v03_womac_left_median_pc_variance))])

display(pc_df)
display(loadings_df)
# Out:
#     PC  Variance  Proportion of Total
# 0  PC1  2.590779             0.863312
# 1  PC2  0.290948             0.096951
# 2  PC3  0.119248             0.039737
#                  PC1       PC2       PC3
# V03WOMADLL  0.953297 -0.154739  0.260011
# V03WOMKPL   0.938018 -0.265818 -0.223134
# V03WOMSTFL  0.895615  0.443108 -0.043058

# %% [markdown]
# ## 12-Month WOMAC Right Knee Variables PCA on Median Dataset

# %%
from scripts.womac.womac_relationships import v01_womac_right_median_pc_variance, v01_womac_right_median_pc_variance_ratio,v01_womac_right_median_pc_loadings, v01_womac_right_median_df

pc_df = pd.DataFrame({
    'PC': [f'PC{i + 1}' for i in range(len(v01_womac_right_median_pc_variance))],
    'Variance': v01_womac_right_median_pc_variance,
    'Proportion of Total': v01_womac_right_median_pc_variance_ratio
})

loadings_df = pd.DataFrame(v01_womac_right_median_pc_loadings, index=v01_womac_right_median_df.columns.to_list(),
columns=[f'PC{i + 1}' for i in range(len(v01_womac_right_median_pc_variance))])

display(pc_df)
display(loadings_df)
# Out:
#     PC  Variance  Proportion of Total
# 0  PC1  2.500882             0.833356
# 1  PC2  0.345453             0.115114
# 2  PC3  0.154640             0.051530
#                  PC1       PC2       PC3
# V01WOMADLR  0.942157 -0.152899  0.298810
# V01WOMKPR   0.920973 -0.300691 -0.248433
# V01WOMSTFR  0.874661  0.481310 -0.060281

# %% [markdown]
# ## 24-Month WOMAC Right Knee Variables PCA on Median Dataset

# %%
from scripts.womac.womac_relationships import v03_womac_right_median_pc_variance, v03_womac_right_median_pc_variance_ratio, v03_womac_right_median_pc_loadings, v03_womac_right_median_df

pc_df = pd.DataFrame({
    'PC': [f'PC{i+1}' for i in range(len(v03_womac_right_median_pc_variance))],
    'Variance': v03_womac_right_median_pc_variance,
    'Proportion of Total': v03_womac_right_median_pc_variance_ratio
})

loadings_df = pd.DataFrame(v03_womac_right_median_pc_loadings, index=v03_womac_right_median_df.columns.to_list(), columns=[f'PC{i + 1}' for i in range(len(v03_womac_right_median_pc_variance))])

display(pc_df)
display(loadings_df)
# Out:
#     PC  Variance  Proportion of Total
# 0  PC1  2.523764             0.840981
# 1  PC2  0.309264             0.103055
# 2  PC3  0.167947             0.055964
#                  PC1       PC2       PC3
# V03WOMADLR  0.938254 -0.152595  0.310998
# V03WOMKPR   0.923419 -0.282318 -0.260614
# V03WOMSTFR  0.889237  0.454176 -0.057509

# %% [markdown]
# ## 12-Month WOMAC Left Knee Variables Regression on Drop Dataset

# %%
from scripts.womac.womac_relationships import v01_womac_left_drop_regression_summary, v01_womac_left_drop_p_matrix

display(v01_womac_left_drop_regression_summary)
display(v01_womac_left_drop_p_matrix)
# Out:
#            type                                            formula  \
# 0        linear                             V01WOMADLL ~ V01WOMKPL
# 1        linear                V01WOMADLL ~ V01WOMKPL + V01WOMSTFL
# 2        linear                             V01WOMKPL ~ V01WOMADLL
# 3        linear                V01WOMKPL ~ V01WOMADLL + V01WOMSTFL
# 4        linear                            V01WOMSTFL ~ V01WOMADLL
# 5        linear                V01WOMSTFL ~ V01WOMADLL + V01WOMKPL
# 6     quadratic                       V01WOMADLL ~ I(V01WOMKPL**2)
# 7     quadratic           V01WOMADLL ~ V01WOMKPL + I(V01WOMKPL**2)
# 8     quadratic  V01WOMADLL ~ V01WOMKPL + V01WOMSTFL + I(V01WOM...
# 9     quadratic          V01WOMADLL ~ V01WOMKPL + I(V01WOMSTFL**2)
# 10    quadratic                       V01WOMKPL ~ I(V01WOMADLL**2)
# 11    quadratic          V01WOMKPL ~ V01WOMADLL + I(V01WOMADLL**2)
# 12    quadratic  V01WOMKPL ~ V01WOMADLL + V01WOMSTFL + I(V01WOM...
# 13    quadratic          V01WOMKPL ~ V01WOMADLL + I(V01WOMSTFL**2)
# 14    quadratic                      V01WOMSTFL ~ I(V01WOMADLL**2)
# 15    quadratic         V01WOMSTFL ~ V01WOMADLL + I(V01WOMADLL**2)
# 16    quadratic  V01WOMSTFL ~ V01WOMADLL + V01WOMKPL + I(V01WOM...
# 17    quadratic          V01WOMSTFL ~ V01WOMADLL + I(V01WOMKPL**2)
# 18        cubic                       V01WOMADLL ~ I(V01WOMKPL**3)
# 19        cubic  V01WOMADLL ~ V01WOMKPL + I(V01WOMKPL**2) + I(V...
# 20        cubic  V01WOMADLL ~ V01WOMKPL + V01WOMSTFL + I(V01WOM...
# 21        cubic  V01WOMADLL ~ V01WOMKPL + I(V01WOMSTFL**2) + I(...
# 22        cubic                       V01WOMKPL ~ I(V01WOMADLL**3)
# 23        cubic  V01WOMKPL ~ V01WOMADLL + I(V01WOMADLL**2) + I(...
# 24        cubic  V01WOMKPL ~ V01WOMADLL + V01WOMSTFL + I(V01WOM...
# 25        cubic  V01WOMKPL ~ V01WOMADLL + I(V01WOMSTFL**2) + I(...
# 26        cubic                      V01WOMSTFL ~ I(V01WOMADLL**3)
# 27        cubic  V01WOMSTFL ~ V01WOMADLL + I(V01WOMADLL**2) + I...
# 28        cubic  V01WOMSTFL ~ V01WOMADLL + V01WOMKPL + I(V01WOM...
# 29        cubic  V01WOMSTFL ~ V01WOMADLL + I(V01WOMKPL**2) + I(...
# 30  interaction                  V01WOMADLL ~ V01WOMKPL:V01WOMSTFL
# 31  interaction                  V01WOMADLL ~ V01WOMKPL*V01WOMSTFL
# 32  interaction            V01WOMADLL ~ V01WOMKPL*I(V01WOMSTFL**2)
# 33  interaction            V01WOMADLL ~ V01WOMKPL*I(V01WOMSTFL**3)
# 34  interaction                  V01WOMKPL ~ V01WOMADLL:V01WOMSTFL
# 35  interaction                  V01WOMKPL ~ V01WOMADLL*V01WOMSTFL
# 36  interaction            V01WOMKPL ~ V01WOMADLL*I(V01WOMSTFL**2)
# 37  interaction            V01WOMKPL ~ V01WOMADLL*I(V01WOMSTFL**3)
# 38  interaction                  V01WOMSTFL ~ V01WOMADLL:V01WOMKPL
# 39  interaction                  V01WOMSTFL ~ V01WOMADLL*V01WOMKPL
# 40  interaction            V01WOMSTFL ~ V01WOMADLL*I(V01WOMKPL**2)
# 41  interaction            V01WOMSTFL ~ V01WOMADLL*I(V01WOMKPL**3)
#
#                                                params  \
# 0   Intercept    0.008070
# V01WOMKPL    2.943267
# dt...
# 1   Intercept    -0.012116
# V01WOMKPL     2.611212
# ...
# 2   Intercept     0.004846
# V01WOMADLL    0.259230
# ...
# 3   Intercept     0.001956
# V01WOMADLL    0.248768
# ...
# 4   Intercept     0.026587
# V01WOMADLL    0.152547
# ...
# 5   Intercept     0.018389
# V01WOMADLL    0.114888
# ...
# 6   Intercept            0.055168
# I(V01WOMKPL ** 2...
# 7   Intercept            0.013404
# V01WOMKPL       ...
# 8   Intercept            -0.004299
# V01WOMKPL      ...
# 9   Intercept            -0.002561
# V01WOMKPL      ...
# 10  Intercept             0.017973
# I(V01WOMADLL **...
# 11  Intercept             0.005636
# V01WOMADLL     ...
# 12  Intercept             0.003314
# V01WOMADLL     ...
# 13  Intercept             0.002524
# V01WOMADLL     ...
# 14  Intercept             0.038336
# I(V01WOMADLL **...
# 15  Intercept             0.023354
# V01WOMADLL     ...
# 16  Intercept             0.016810
# V01WOMADLL     ...
# 17  Intercept            0.018664
# V01WOMADLL      ...
# 18  Intercept            0.073904
# I(V01WOMKPL ** 3...
# 19  Intercept            0.016921
# V01WOMKPL       ...
# 20  Intercept            -0.000926
# V01WOMKPL      ...
# 21  Intercept            -0.005639
# V01WOMKPL      ...
# 22  Intercept             0.023096
# I(V01WOMADLL **...
# 23  Intercept             0.005762
# V01WOMADLL     ...
# 24  Intercept             0.003614
# V01WOMADLL     ...
# 25  Intercept             0.002545
# V01WOMADLL     ...
# 26  Intercept             0.042746
# I(V01WOMADLL **...
# 27  Intercept             0.021624
# V01WOMADLL     ...
# 28  Intercept             0.015893
# V01WOMADLL     ...
# 29  Intercept            0.018556
# V01WOMADLL      ...
# 30  Intercept               0.056246
# V01WOMKPL:V01...
# 31  Intercept              -0.004498
# V01WOMKPL    ...
# 32  Intercept                      -0.003695
# V01WO...
# 33  Intercept                       0.001933
# V01WO...
# 34  Intercept                0.035411
# V01WOMADLL:V...
# 35  Intercept                0.002908
# V01WOMADLL  ...
# 36  Intercept                        0.002649
# V01W...
# 37  Intercept                        0.003245
# V01W...
# 38  Intercept               0.069119
# V01WOMADLL:V0...
# 39  Intercept               0.016788
# V01WOMADLL   ...
# 40  Intercept                       0.018230
# V01WO...
# 41  Intercept                       0.018529
# V01WO...
#
#                                              p_values  r_squared
# 0   Intercept    0.487098
# V01WOMKPL    0.000000
# dt...   0.762984
# 1   Intercept     2.253080e-01
# V01WOMKPL     0.000...   0.807864
# 2   Intercept     0.15966
# V01WOMADLL    0.00000
# dt...   0.762984
# 3   Intercept     0.526042
# V01WOMADLL    0.000000
# ...   0.788677
# 4   Intercept     4.182867e-09
# V01WOMADLL    0.000...   0.488799
# 5   Intercept     3.919158e-07
# V01WOMADLL    1.618...   0.457098
# 6   Intercept            0.000137
# I(V01WOMKPL ** 2...   0.631280
# 7   Intercept             2.442345e-01
# V01WOMKPL  ...   0.768229
# 8   Intercept              6.582352e-01
# V01WOMKPL ...   0.819153
# 9   Intercept             7.908434e-01
# V01WOMKPL  ...   0.818784
# 10  Intercept             0.000033
# I(V01WOMADLL **...   0.625633
# 11  Intercept              1.019381e-01
# V01WOMADLL...   0.764183
# 12  Intercept              2.776604e-01
# V01WOMADLL...   0.793974
# 13  Intercept             4.054406e-01
# V01WOMADLL ...   0.793484
# 14  Intercept              2.899506e-13
# I(V01WOMAD...   0.309134
# 15  Intercept              1.452684e-07
# V01WOMADLL...   0.509529
# 16  Intercept             2.436574e-06
# V01WOMADLL ...   0.476218
# 17  Intercept             2.973290e-07
# V01WOMADLL ...   0.452228
# 18  Intercept             3.371585e-05
# I(V01WOMKPL...   0.440057
# 19  Intercept            1.377224e-01
# V01WOMKPL   ...   0.773254
# 20  Intercept             9.234027e-01
# V01WOMKPL  ...   0.822886
# 21  Intercept             5.590421e-01
# V01WOMKPL  ...   0.820131
# 22  Intercept              1.257558e-05
# I(V01WOMAD...   0.440497
# 23  Intercept             9.506166e-02
# V01WOMADLL ...   0.764226
# 24  Intercept             2.357624e-01
# V01WOMADLL ...   0.795103
# 25  Intercept             0.402981
# V01WOMADLL     ...   0.793485
# 26  Intercept              6.040231e-14
# I(V01WOMAD...   0.187274
# 27  Intercept              9.488082e-07
# V01WOMADLL...   0.517829
# 28  Intercept             7.091116e-06
# V01WOMADLL ...   0.485664
# 29  Intercept            3.232566e-07
# V01WOMADLL  ...   0.455449
# 30  Intercept               0.000003
# V01WOMKPL:V01...   0.637959
# 31  Intercept                6.426297e-01
# V01WOMKP...   0.819961
# 32  Intercept                       7.025625e-01
# V...   0.819018
# 33  Intercept                       8.443741e-01
# V...   0.811824
# 34  Intercept                 1.244283e-11
# V01WOMA...   0.413885
# 35  Intercept                 3.427262e-01
# V01WOMA...   0.792040
# 36  Intercept                        3.836741e-01
# ...   0.793519
# 37  Intercept                        2.854915e-01
# ...   0.792999
# 38  Intercept               6.690628e-25
# V01WOMADL...   0.099122
# 39  Intercept               2.731829e-06
# V01WOMADL...   0.472051
# 40  Intercept                        4.493892e-07
# ...   0.461365
# 41  Intercept                        3.306356e-07
# ...   0.456117
#                                  V01WOMADLL     V01WOMKPL     V01WOMSTFL
# V01WOMADLL                              NaN  0.000000e+00  1.257015e-109
# V01WOMKPL                      0.000000e+00           NaN   1.162093e-02
# V01WOMSTFL                     2.030359e-02  3.784599e-05            NaN
# I(V01WOMADLL ** 2)                      NaN  1.509497e-01   8.070540e-18
# I(V01WOMADLL ** 3)                      NaN  1.788804e-01   7.837199e-10
# I(V01WOMKPL ** 2)              1.709466e-12           NaN   1.652860e-01
# I(V01WOMKPL ** 3)              2.793003e-12           NaN   2.361813e-02
# I(V01WOMSTFL ** 2)             7.887697e-38  4.050554e-11            NaN
# I(V01WOMSTFL ** 3)             3.929314e-05  5.986794e-04            NaN
# V01WOMADLL:I(V01WOMKPL ** 2)            NaN           NaN   1.033468e-09
# V01WOMADLL:I(V01WOMKPL ** 3)            NaN           NaN   8.020237e-04
# V01WOMADLL:I(V01WOMSTFL ** 2)           NaN  5.658401e-01            NaN
# V01WOMADLL:I(V01WOMSTFL ** 3)           NaN  7.862685e-04            NaN
# V01WOMADLL:V01WOMKPL                    NaN           NaN   1.457688e-15
# V01WOMADLL:V01WOMSTFL                   NaN  1.279909e-09            NaN
# V01WOMKPL:I(V01WOMSTFL ** 2)   1.112985e-01           NaN            NaN
# V01WOMKPL:I(V01WOMSTFL ** 3)   3.724324e-15           NaN            NaN
# V01WOMKPL:V01WOMSTFL           3.283212e-34           NaN            NaN

# %% [markdown]
# ## 24-Month WOMAC Left Knee Variables Regression on Drop Dataset

# %%
from scripts.womac.womac_relationships import v03_womac_left_drop_regression_summary, v03_womac_left_drop_p_matrix

display(v03_womac_left_drop_regression_summary)
display(v03_womac_left_drop_p_matrix)
# Out:
#            type                                            formula  \
# 0        linear                             V03WOMADLL ~ V03WOMKPL
# 1        linear                V03WOMADLL ~ V03WOMKPL + V03WOMSTFL
# 2        linear                             V03WOMKPL ~ V03WOMADLL
# 3        linear                V03WOMKPL ~ V03WOMADLL + V03WOMSTFL
# 4        linear                            V03WOMSTFL ~ V03WOMADLL
# 5        linear                V03WOMSTFL ~ V03WOMADLL + V03WOMKPL
# 6     quadratic                       V03WOMADLL ~ I(V03WOMKPL**2)
# 7     quadratic           V03WOMADLL ~ V03WOMKPL + I(V03WOMKPL**2)
# 8     quadratic  V03WOMADLL ~ V03WOMKPL + V03WOMSTFL + I(V03WOM...
# 9     quadratic          V03WOMADLL ~ V03WOMKPL + I(V03WOMSTFL**2)
# 10    quadratic                       V03WOMKPL ~ I(V03WOMADLL**2)
# 11    quadratic          V03WOMKPL ~ V03WOMADLL + I(V03WOMADLL**2)
# 12    quadratic  V03WOMKPL ~ V03WOMADLL + V03WOMSTFL + I(V03WOM...
# 13    quadratic          V03WOMKPL ~ V03WOMADLL + I(V03WOMSTFL**2)
# 14    quadratic                      V03WOMSTFL ~ I(V03WOMADLL**2)
# 15    quadratic         V03WOMSTFL ~ V03WOMADLL + I(V03WOMADLL**2)
# 16    quadratic  V03WOMSTFL ~ V03WOMADLL + V03WOMKPL + I(V03WOM...
# 17    quadratic          V03WOMSTFL ~ V03WOMADLL + I(V03WOMKPL**2)
# 18        cubic                       V03WOMADLL ~ I(V03WOMKPL**3)
# 19        cubic  V03WOMADLL ~ V03WOMKPL + I(V03WOMKPL**2) + I(V...
# 20        cubic  V03WOMADLL ~ V03WOMKPL + V03WOMSTFL + I(V03WOM...
# 21        cubic  V03WOMADLL ~ V03WOMKPL + I(V03WOMSTFL**2) + I(...
# 22        cubic                       V03WOMKPL ~ I(V03WOMADLL**3)
# 23        cubic  V03WOMKPL ~ V03WOMADLL + I(V03WOMADLL**2) + I(...
# 24        cubic  V03WOMKPL ~ V03WOMADLL + V03WOMSTFL + I(V03WOM...
# 25        cubic  V03WOMKPL ~ V03WOMADLL + I(V03WOMSTFL**2) + I(...
# 26        cubic                      V03WOMSTFL ~ I(V03WOMADLL**3)
# 27        cubic  V03WOMSTFL ~ V03WOMADLL + I(V03WOMADLL**2) + I...
# 28        cubic  V03WOMSTFL ~ V03WOMADLL + V03WOMKPL + I(V03WOM...
# 29        cubic  V03WOMSTFL ~ V03WOMADLL + I(V03WOMKPL**2) + I(...
# 30  interaction                  V03WOMADLL ~ V03WOMKPL:V03WOMSTFL
# 31  interaction                  V03WOMADLL ~ V03WOMKPL*V03WOMSTFL
# 32  interaction            V03WOMADLL ~ V03WOMKPL*I(V03WOMSTFL**2)
# 33  interaction            V03WOMADLL ~ V03WOMKPL*I(V03WOMSTFL**3)
# 34  interaction                  V03WOMKPL ~ V03WOMADLL:V03WOMSTFL
# 35  interaction                  V03WOMKPL ~ V03WOMADLL*V03WOMSTFL
# 36  interaction            V03WOMKPL ~ V03WOMADLL*I(V03WOMSTFL**2)
# 37  interaction            V03WOMKPL ~ V03WOMADLL*I(V03WOMSTFL**3)
# 38  interaction                  V03WOMSTFL ~ V03WOMADLL:V03WOMKPL
# 39  interaction                  V03WOMSTFL ~ V03WOMADLL*V03WOMKPL
# 40  interaction            V03WOMSTFL ~ V03WOMADLL*I(V03WOMKPL**2)
# 41  interaction            V03WOMSTFL ~ V03WOMADLL*I(V03WOMKPL**3)
#
#                                                params  \
# 0   Intercept    0.001918
# V03WOMKPL    2.728173
# dt...
# 1   Intercept    -0.011589
# V03WOMKPL     2.459349
# ...
# 2   Intercept     0.005966
# V03WOMADLL    0.277420
# ...
# 3   Intercept     0.002773
# V03WOMADLL    0.275566
# ...
# 4   Intercept     0.023059
# V03WOMADLL    0.143808
# ...
# 5   Intercept     0.015186
# V03WOMADLL    0.113251
# ...
# 6   Intercept            0.041030
# I(V03WOMKPL ** 2...
# 7   Intercept            0.004635
# V03WOMKPL       ...
# 8   Intercept            -0.005156
# V03WOMKPL      ...
# 9   Intercept            -0.006053
# V03WOMKPL      ...
# 10  Intercept             0.016335
# I(V03WOMADLL **...
# 11  Intercept             0.006040
# V03WOMADLL     ...
# 12  Intercept             0.003303
# V03WOMADLL     ...
# 13  Intercept             0.003229
# V03WOMADLL     ...
# 14  Intercept             0.031283
# I(V03WOMADLL **...
# 15  Intercept             0.021456
# V03WOMADLL     ...
# 16  Intercept             0.014221
# V03WOMADLL     ...
# 17  Intercept            0.015502
# V03WOMADLL      ...
# 18  Intercept            0.057256
# I(V03WOMKPL ** 3...
# 19  Intercept            0.007581
# V03WOMKPL       ...
# 20  Intercept            -0.002391
# V03WOMKPL      ...
# 21  Intercept            -0.007159
# V03WOMKPL      ...
# 22  Intercept             0.021209
# I(V03WOMADLL **...
# 23  Intercept             0.006156
# V03WOMADLL     ...
# 24  Intercept             0.003313
# V03WOMADLL     ...
# 25  Intercept             3.229128e-03
# V03WOMADLL ...
# 26  Intercept             0.035582
# I(V03WOMADLL **...
# 27  Intercept             0.020602
# V03WOMADLL     ...
# 28  Intercept             0.013855
# V03WOMADLL     ...
# 29  Intercept            0.015342
# V03WOMADLL      ...
# 30  Intercept               0.040504
# V03WOMKPL:V03...
# 31  Intercept              -0.004740
# V03WOMKPL    ...
# 32  Intercept                      -0.006226
# V03WO...
# 33  Intercept                      -0.002818
# V03WO...
# 34  Intercept                0.038596
# V03WOMADLL:V...
# 35  Intercept                0.002813
# V03WOMADLL  ...
# 36  Intercept                        0.002715
# V03W...
# 37  Intercept                        0.003222
# V03W...
# 38  Intercept               0.050397
# V03WOMADLL:V0...
# 39  Intercept               0.014122
# V03WOMADLL   ...
# 40  Intercept                       0.015095
# V03WO...
# 41  Intercept                       0.015319
# V03WO...
#
#                                              p_values  r_squared
# 0   Intercept    0.857777
# V03WOMKPL    0.000000
# dt...   0.756849
# 1   Intercept     2.011939e-01
# V03WOMKPL     0.000...   0.815809
# 2   Intercept     0.080366
# V03WOMADLL    0.000000
# ...   0.756849
# 3   Intercept     0.360833
# V03WOMADLL    0.000000
# ...   0.799132
# 4   Intercept      1.137556e-07
# V03WOMADLL    1.20...   0.455982
# 5   Intercept     8.992977e-06
# V03WOMADLL    5.537...   0.432696
# 6   Intercept            0.002421
# I(V03WOMKPL ** 2...   0.610438
# 7   Intercept             6.642794e-01
# V03WOMKPL  ...   0.758805
# 8   Intercept              5.552611e-01
# V03WOMKPL ...   0.829497
# 9   Intercept             4.865042e-01
# V03WOMKPL  ...   0.829303
# 10  Intercept             0.000175
# I(V03WOMADLL **...   0.603697
# 11  Intercept              7.710973e-02
# V03WOMADLL...   0.756868
# 12  Intercept              2.742906e-01
# V03WOMADLL...   0.801633
# 13  Intercept             2.840474e-01
# V03WOMADLL ...   0.800484
# 14  Intercept              1.212641e-10
# I(V03WOMAD...   0.319178
# 15  Intercept              6.681771e-07
# V03WOMADLL...   0.465430
# 16  Intercept             2.750692e-05
# V03WOMADLL ...   0.443692
# 17  Intercept             6.250047e-06
# V03WOMADLL ...   0.428853
# 18  Intercept             5.448706e-04
# I(V03WOMKPL...   0.416039
# 19  Intercept            4.738043e-01
# V03WOMKPL   ...   0.763639
# 20  Intercept             7.823744e-01
# V03WOMKPL  ...   0.833262
# 21  Intercept             4.113712e-01
# V03WOMKPL  ...   0.829557
# 22  Intercept              7.062951e-05
# I(V03WOMAD...   0.403996
# 23  Intercept             7.191323e-02
# V03WOMADLL ...   0.756929
# 24  Intercept             2.733266e-01
# V03WOMADLL ...   0.801697
# 25  Intercept             0.285297
# V03WOMADLL     ...   0.800484
# 26  Intercept              1.949404e-11
# I(V03WOMAD...   0.188401
# 27  Intercept             1.742800e-06
# V03WOMADLL ...   0.468807
# 28  Intercept             4.202133e-05
# V03WOMADLL ...   0.447849
# 29  Intercept            7.259175e-06
# V03WOMADLL  ...   0.432882
# 30  Intercept               0.000279
# V03WOMKPL:V03...   0.655913
# 31  Intercept                5.869521e-01
# V03WOMKP...   0.829994
# 32  Intercept                       4.751423e-01
# V...   0.829310
# 33  Intercept                       7.485057e-01
# V...   0.825876
# 34  Intercept                 4.496520e-11
# V03WOMA...   0.358948
# 35  Intercept                 3.546137e-01
# V03WOMA...   0.799140
# 36  Intercept                        3.678618e-01
# ...   0.801197
# 37  Intercept                        2.825787e-01
# ...   0.802583
# 38  Intercept               2.856243e-17
# V03WOMADL...   0.111400
# 39  Intercept               3.091760e-05
# V03WOMADL...   0.444021
# 40  Intercept                        9.526240e-06
# ...   0.436565
# 41  Intercept                        7.499955e-06
# ...   0.432837
#                                  V03WOMADLL     V03WOMKPL    V03WOMSTFL
# V03WOMADLL                              NaN  0.000000e+00  7.621712e-71
# V03WOMKPL                      0.000000e+00           NaN  5.166371e-04
# V03WOMSTFL                     3.139768e-06  3.787274e-02           NaN
# I(V03WOMADLL ** 2)                      NaN  4.604554e-01  1.164919e-07
# I(V03WOMADLL ** 3)                      NaN  4.869350e-01  1.152100e-04
# I(V03WOMKPL ** 2)              2.957610e-05           NaN  2.531768e-01
# I(V03WOMKPL ** 3)              2.344920e-11           NaN  3.403511e-02
# I(V03WOMSTFL ** 2)             5.476119e-37  6.173481e-07           NaN
# I(V03WOMSTFL ** 3)             7.039132e-06  6.416016e-01           NaN
# V03WOMADLL:I(V03WOMKPL ** 2)            NaN           NaN  5.016061e-08
# V03WOMADLL:I(V03WOMKPL ** 3)            NaN           NaN  8.782268e-04
# V03WOMADLL:I(V03WOMSTFL ** 2)           NaN  5.858770e-03           NaN
# V03WOMADLL:I(V03WOMSTFL ** 3)           NaN  3.392604e-08           NaN
# V03WOMADLL:V03WOMKPL                    NaN           NaN  1.261492e-11
# V03WOMADLL:V03WOMSTFL                   NaN  3.916130e-01           NaN
# V03WOMKPL:I(V03WOMSTFL ** 2)   7.832260e-01           NaN           NaN
# V03WOMKPL:I(V03WOMSTFL ** 3)   4.739654e-17           NaN           NaN
# V03WOMKPL:V03WOMSTFL           9.230238e-42           NaN           NaN

# %% [markdown]
# ## Change in WOMAC Left Knee Variables Regression on Drop Dataset

# %%
from scripts.womac.womac_relationships import womac_left_drop_change_regression_summary, womac_left_drop_change_p_matrix

display(womac_left_drop_change_regression_summary)
display(womac_left_drop_change_p_matrix)
# Out:
#            type                                            formula  \
# 0        linear                                 ΔWOMADLL ~ ΔWOMKPL
# 1        linear                      ΔWOMADLL ~ ΔWOMKPL + ΔWOMSTFL
# 2        linear                                 ΔWOMKPL ~ ΔWOMADLL
# 3        linear                      ΔWOMKPL ~ ΔWOMADLL + ΔWOMSTFL
# 4        linear                                ΔWOMSTFL ~ ΔWOMADLL
# 5        linear                      ΔWOMSTFL ~ ΔWOMADLL + ΔWOMKPL
# 6     quadratic                           ΔWOMADLL ~ I(ΔWOMKPL**2)
# 7     quadratic                 ΔWOMADLL ~ ΔWOMKPL + I(ΔWOMKPL**2)
# 8     quadratic  ΔWOMADLL ~ ΔWOMKPL + ΔWOMSTFL + I(ΔWOMKPL**2) ...
# 9     quadratic                ΔWOMADLL ~ ΔWOMKPL + I(ΔWOMSTFL**2)
# 10    quadratic                           ΔWOMKPL ~ I(ΔWOMADLL**2)
# 11    quadratic                ΔWOMKPL ~ ΔWOMADLL + I(ΔWOMADLL**2)
# 12    quadratic  ΔWOMKPL ~ ΔWOMADLL + ΔWOMSTFL + I(ΔWOMADLL**2)...
# 13    quadratic                ΔWOMKPL ~ ΔWOMADLL + I(ΔWOMSTFL**2)
# 14    quadratic                          ΔWOMSTFL ~ I(ΔWOMADLL**2)
# 15    quadratic               ΔWOMSTFL ~ ΔWOMADLL + I(ΔWOMADLL**2)
# 16    quadratic  ΔWOMSTFL ~ ΔWOMADLL + ΔWOMKPL + I(ΔWOMADLL**2)...
# 17    quadratic                ΔWOMSTFL ~ ΔWOMADLL + I(ΔWOMKPL**2)
# 18        cubic                           ΔWOMADLL ~ I(ΔWOMKPL**3)
# 19        cubic  ΔWOMADLL ~ ΔWOMKPL + I(ΔWOMKPL**2) + I(ΔWOMKPL...
# 20        cubic  ΔWOMADLL ~ ΔWOMKPL + ΔWOMSTFL + I(ΔWOMKPL**2) ...
# 21        cubic  ΔWOMADLL ~ ΔWOMKPL + I(ΔWOMSTFL**2) + I(ΔWOMST...
# 22        cubic                           ΔWOMKPL ~ I(ΔWOMADLL**3)
# 23        cubic  ΔWOMKPL ~ ΔWOMADLL + I(ΔWOMADLL**2) + I(ΔWOMAD...
# 24        cubic  ΔWOMKPL ~ ΔWOMADLL + ΔWOMSTFL + I(ΔWOMADLL**2)...
# 25        cubic  ΔWOMKPL ~ ΔWOMADLL + I(ΔWOMSTFL**2) + I(ΔWOMST...
# 26        cubic                          ΔWOMSTFL ~ I(ΔWOMADLL**3)
# 27        cubic  ΔWOMSTFL ~ ΔWOMADLL + I(ΔWOMADLL**2) + I(ΔWOMA...
# 28        cubic  ΔWOMSTFL ~ ΔWOMADLL + ΔWOMKPL + I(ΔWOMADLL**2)...
# 29        cubic  ΔWOMSTFL ~ ΔWOMADLL + I(ΔWOMKPL**2) + I(ΔWOMKP...
# 30  interaction                        ΔWOMADLL ~ ΔWOMKPL:ΔWOMSTFL
# 31  interaction                        ΔWOMADLL ~ ΔWOMKPL*ΔWOMSTFL
# 32  interaction                  ΔWOMADLL ~ ΔWOMKPL*I(ΔWOMSTFL**2)
# 33  interaction                  ΔWOMADLL ~ ΔWOMKPL*I(ΔWOMSTFL**3)
# 34  interaction                        ΔWOMKPL ~ ΔWOMADLL:ΔWOMSTFL
# 35  interaction                        ΔWOMKPL ~ ΔWOMADLL*ΔWOMSTFL
# 36  interaction                  ΔWOMKPL ~ ΔWOMADLL*I(ΔWOMSTFL**2)
# 37  interaction                  ΔWOMKPL ~ ΔWOMADLL*I(ΔWOMSTFL**3)
# 38  interaction                        ΔWOMSTFL ~ ΔWOMADLL:ΔWOMKPL
# 39  interaction                        ΔWOMSTFL ~ ΔWOMADLL*ΔWOMKPL
# 40  interaction                  ΔWOMSTFL ~ ΔWOMADLL*I(ΔWOMKPL**2)
# 41  interaction                  ΔWOMSTFL ~ ΔWOMADLL*I(ΔWOMKPL**3)
#
#                                                params  \
# 0   Intercept   -0.006691
# ΔWOMKPL      2.058129
# dt...
# 1   Intercept   -0.001869
# ΔWOMKPL      1.969470
# ΔW...
# 2   Intercept    0.001896
# ΔWOMADLL     0.250640
# dt...
# 3   Intercept    0.003465
# ΔWOMADLL     0.244658
# ΔW...
# 4   Intercept   -0.006252
# ΔWOMADLL     0.103228
# dt...
# 5   Intercept   -0.005026
# ΔWOMADLL     0.081708
# ΔW...
# 6   Intercept         -0.015315
# I(ΔWOMKPL ** 2)   ...
# 7   Intercept         -0.005342
# ΔWOMKPL           ...
# 8   Intercept           0.002381
# ΔWOMKPL          ...
# 9   Intercept           0.001982
# ΔWOMKPL          ...
# 10  Intercept          -0.000083
# I(ΔWOMADLL ** 2) ...
# 11  Intercept           0.000513
# ΔWOMADLL         ...
# 12  Intercept           0.001066
# ΔWOMADLL         ...
# 13  Intercept          -0.000113
# ΔWOMADLL         ...
# 14  Intercept          -0.006505
# I(ΔWOMADLL ** 2) ...
# 15  Intercept          -0.005978
# ΔWOMADLL         ...
# 16  Intercept          -0.004710
# ΔWOMADLL         ...
# 17  Intercept         -0.004612
# ΔWOMADLL          ...
# 18  Intercept         -0.010687
# I(ΔWOMKPL ** 3)   ...
# 19  Intercept         -0.004676
# ΔWOMKPL           ...
# 20  Intercept           0.002877
# ΔWOMKPL          ...
# 21  Intercept           0.001185
# ΔWOMKPL          ...
# 22  Intercept           0.000438
# I(ΔWOMADLL ** 3) ...
# 23  Intercept           0.000488
# ΔWOMADLL         ...
# 24  Intercept           0.000974
# ΔWOMADLL         ...
# 25  Intercept           0.000951
# ΔWOMADLL         ...
# 26  Intercept          -0.005958
# I(ΔWOMADLL ** 3) ...
# 27  Intercept          -0.006001
# ΔWOMADLL         ...
# 28  Intercept          -0.004748
# ΔWOMADLL         ...
# 29  Intercept         -0.004669
# ΔWOMADLL          ...
# 30  Intercept          -0.001757
# ΔWOMKPL:ΔWOMSTFL ...
# 31  Intercept          -0.001046
# ΔWOMKPL          ...
# 32  Intercept                   0.003571
# ΔWOMKPL  ...
# 33  Intercept                  -0.003173
# ΔWOMKPL  ...
# 34  Intercept            0.008612
# ΔWOMADLL:ΔWOMSTF...
# 35  Intercept            0.002133
# ΔWOMADLL        ...
# 36  Intercept                   -0.000098
# ΔWOMADLL...
# 37  Intercept                    0.002849
# ΔWOMADLL...
# 38  Intercept          -0.002655
# ΔWOMADLL:ΔWOMKPL ...
# 39  Intercept          -0.004817
# ΔWOMADLL         ...
# 40  Intercept                  -0.004619
# ΔWOMADLL ...
# 41  Intercept                  -0.004795
# ΔWOMADLL ...
#
#                                              p_values  r_squared
# 0   Intercept    0.609965
# ΔWOMKPL      0.000000
# dt...   0.515850
# 1   Intercept    8.878273e-01
# ΔWOMKPL      0.00000...   0.593224
# 2   Intercept    0.678727
# ΔWOMADLL     0.000000
# dt...   0.515850
# 3   Intercept    0.458065
# ΔWOMADLL     0.000000
# ΔW...   0.567315
# 4   Intercept     2.089541e-01
# ΔWOMADLL     9.6895...   0.177386
# 5   Intercept    2.219762e-01
# ΔWOMADLL     9.47416...   0.222718
# 6   Intercept          4.207970e-01
# I(ΔWOMKPL ** 2...   0.020836
# 7   Intercept          0.683967
# ΔWOMKPL           ...   0.516720
# 8   Intercept            8.574918e-01
# ΔWOMKPL     ...   0.596173
# 9   Intercept           8.860308e-01
# ΔWOMKPL      ...   0.559796
# 10  Intercept           0.990117
# I(ΔWOMADLL ** 2) ...   0.009827
# 11  Intercept           9.100001e-01
# ΔWOMADLL     ...   0.525443
# 12  Intercept           8.176187e-01
# ΔWOMADLL     ...   0.579520
# 13  Intercept           0.981020
# ΔWOMADLL         ...   0.559316
# 14  Intercept           0.254566
# I(ΔWOMADLL ** 2) ...   0.000096
# 15  Intercept            2.302575e-01
# ΔWOMADLL    ...   0.177748
# 16  Intercept           2.528922e-01
# ΔWOMADLL     ...   0.223561
# 17  Intercept           2.727174e-01
# ΔWOMADLL     ...   0.210247
# 18  Intercept           4.781402e-01
# I(ΔWOMKPL ** ...   0.361185
# 19  Intercept           7.166671e-01
# ΔWOMKPL      ...   0.534466
# 20  Intercept            8.255643e-01
# ΔWOMKPL     ...   0.608899
# 21  Intercept            9.291021e-01
# ΔWOMKPL     ...   0.592141
# 22  Intercept            9.388205e-01
# I(ΔWOMADLL *...   0.247924
# 23  Intercept            9.143990e-01
# ΔWOMADLL    ...   0.525776
# 24  Intercept            8.312362e-01
# ΔWOMADLL    ...   0.589672
# 25  Intercept            8.363196e-01
# ΔWOMADLL    ...   0.582578
# 26  Intercept           2.601537e-01
# I(ΔWOMADLL **...   0.069750
# 27  Intercept           2.284932e-01
# ΔWOMADLL     ...   0.178112
# 28  Intercept           2.488428e-01
# ΔWOMADLL     ...   0.225036
# 29  Intercept          2.593504e-01
# ΔWOMADLL      ...   0.215722
# 30  Intercept           0.923028
# ΔWOMKPL:ΔWOMSTFL ...   0.002276
# 31  Intercept           9.370994e-01
# ΔWOMKPL      ...   0.593733
# 32  Intercept                    7.927361e-01
# ΔWOM...   0.575285
# 33  Intercept                    8.112115e-01
# ΔWOM...   0.591306
# 34  Intercept            0.271028
# ΔWOMADLL:ΔWOMSTF...   0.001431
# 35  Intercept            6.445560e-01
# ΔWOMADLL    ...   0.576559
# 36  Intercept                     9.834280e-01
# ΔWO...   0.563918
# 37  Intercept                     5.358807e-01
# ΔWO...   0.579785
# 38  Intercept           0.688975
# ΔWOMADLL:ΔWOMKPL ...   0.000412
# 39  Intercept           2.421115e-01
# ΔWOMADLL     ...   0.223286
# 40  Intercept                   2.720529e-01
# ΔWOMA...   0.210292
# 41  Intercept                   2.463490e-01
# ΔWOMA...   0.215544
#                                 ΔWOMADLL       ΔWOMKPL      ΔWOMSTFL
# ΔWOMADLL                             NaN  0.000000e+00  2.914044e-65
# ΔWOMKPL                    4.357659e-321           NaN  2.956216e-06
# ΔWOMSTFL                    3.205222e-34  2.447020e-06           NaN
# I(ΔWOMADLL ** 2)                     NaN  4.176683e-09  8.018392e-01
# I(ΔWOMADLL ** 3)                     NaN  1.418930e-01  3.719749e-01
# I(ΔWOMKPL ** 2)             3.423749e-04           NaN  8.328495e-01
# I(ΔWOMKPL ** 3)             6.199647e-20           NaN  3.202548e-01
# I(ΔWOMSTFL ** 2)            4.533277e-06  3.790118e-06           NaN
# I(ΔWOMSTFL ** 3)            2.023674e-29  2.270565e-17           NaN
# ΔWOMADLL:I(ΔWOMKPL ** 2)             NaN           NaN  8.361116e-01
# ΔWOMADLL:I(ΔWOMKPL ** 3)             NaN           NaN  7.915978e-01
# ΔWOMADLL:I(ΔWOMSTFL ** 2)            NaN  2.122315e-06           NaN
# ΔWOMADLL:I(ΔWOMSTFL ** 3)            NaN  1.838314e-04           NaN
# ΔWOMADLL:ΔWOMKPL                     NaN           NaN  3.937199e-01
# ΔWOMADLL:ΔWOMSTFL                    NaN  6.299632e-02           NaN
# ΔWOMKPL:I(ΔWOMSTFL ** 2)    3.861899e-19           NaN           NaN
# ΔWOMKPL:I(ΔWOMSTFL ** 3)    5.161343e-05           NaN           NaN
# ΔWOMKPL:ΔWOMSTFL            1.002374e-01           NaN           NaN

# %% [markdown]
# ## 12-Month WOMAC Right Knee Variables Regression on Drop Dataset

# %%
from scripts.womac.womac_relationships import v01_womac_right_drop_regression_summary, v01_womac_right_drop_p_matrix

display(v01_womac_right_drop_regression_summary)
display(v01_womac_right_drop_p_matrix)
# Out:
#            type                                            formula  \
# 0        linear                             V01WOMADLR ~ V01WOMKPR
# 1        linear                V01WOMADLR ~ V01WOMKPR + V01WOMSTFR
# 2        linear                             V01WOMKPR ~ V01WOMADLR
# 3        linear                V01WOMKPR ~ V01WOMADLR + V01WOMSTFR
# 4        linear                            V01WOMSTFR ~ V01WOMADLR
# 5        linear                V01WOMSTFR ~ V01WOMADLR + V01WOMKPR
# 6     quadratic                       V01WOMADLR ~ I(V01WOMKPR**2)
# 7     quadratic           V01WOMADLR ~ V01WOMKPR + I(V01WOMKPR**2)
# 8     quadratic  V01WOMADLR ~ V01WOMKPR + V01WOMSTFR + I(V01WOM...
# 9     quadratic          V01WOMADLR ~ V01WOMKPR + I(V01WOMSTFR**2)
# 10    quadratic                       V01WOMKPR ~ I(V01WOMADLR**2)
# 11    quadratic          V01WOMKPR ~ V01WOMADLR + I(V01WOMADLR**2)
# 12    quadratic  V01WOMKPR ~ V01WOMADLR + V01WOMSTFR + I(V01WOM...
# 13    quadratic          V01WOMKPR ~ V01WOMADLR + I(V01WOMSTFR**2)
# 14    quadratic                      V01WOMSTFR ~ I(V01WOMADLR**2)
# 15    quadratic         V01WOMSTFR ~ V01WOMADLR + I(V01WOMADLR**2)
# 16    quadratic  V01WOMSTFR ~ V01WOMADLR + V01WOMKPR + I(V01WOM...
# 17    quadratic          V01WOMSTFR ~ V01WOMADLR + I(V01WOMKPR**2)
# 18        cubic                       V01WOMADLR ~ I(V01WOMKPR**3)
# 19        cubic  V01WOMADLR ~ V01WOMKPR + I(V01WOMKPR**2) + I(V...
# 20        cubic  V01WOMADLR ~ V01WOMKPR + V01WOMSTFR + I(V01WOM...
# 21        cubic  V01WOMADLR ~ V01WOMKPR + I(V01WOMSTFR**2) + I(...
# 22        cubic                       V01WOMKPR ~ I(V01WOMADLR**3)
# 23        cubic  V01WOMKPR ~ V01WOMADLR + I(V01WOMADLR**2) + I(...
# 24        cubic  V01WOMKPR ~ V01WOMADLR + V01WOMSTFR + I(V01WOM...
# 25        cubic  V01WOMKPR ~ V01WOMADLR + I(V01WOMSTFR**2) + I(...
# 26        cubic                      V01WOMSTFR ~ I(V01WOMADLR**3)
# 27        cubic  V01WOMSTFR ~ V01WOMADLR + I(V01WOMADLR**2) + I...
# 28        cubic  V01WOMSTFR ~ V01WOMADLR + V01WOMKPR + I(V01WOM...
# 29        cubic  V01WOMSTFR ~ V01WOMADLR + I(V01WOMKPR**2) + I(...
# 30  interaction                  V01WOMADLR ~ V01WOMKPR:V01WOMSTFR
# 31  interaction                  V01WOMADLR ~ V01WOMKPR*V01WOMSTFR
# 32  interaction            V01WOMADLR ~ V01WOMKPR*I(V01WOMSTFR**2)
# 33  interaction            V01WOMADLR ~ V01WOMKPR*I(V01WOMSTFR**3)
# 34  interaction                  V01WOMKPR ~ V01WOMADLR:V01WOMSTFR
# 35  interaction                  V01WOMKPR ~ V01WOMADLR*V01WOMSTFR
# 36  interaction            V01WOMKPR ~ V01WOMADLR*I(V01WOMSTFR**2)
# 37  interaction            V01WOMKPR ~ V01WOMADLR*I(V01WOMSTFR**3)
# 38  interaction                  V01WOMSTFR ~ V01WOMADLR:V01WOMKPR
# 39  interaction                  V01WOMSTFR ~ V01WOMADLR*V01WOMKPR
# 40  interaction            V01WOMSTFR ~ V01WOMADLR*I(V01WOMKPR**2)
# 41  interaction            V01WOMSTFR ~ V01WOMADLR*I(V01WOMKPR**3)
#
#                                                params  \
# 0   Intercept   -0.003545
# V01WOMKPR    2.375437
# dt...
# 1   Intercept    -0.033155
# V01WOMKPR     2.280968
# ...
# 2   Intercept     0.016544
# V01WOMADLR    0.276803
# ...
# 3   Intercept     0.008002
# V01WOMADLR    0.263582
# ...
# 4   Intercept     0.065044
# V01WOMADLR    0.163661
# ...
# 5   Intercept     0.043142
# V01WOMADLR    0.117483
# ...
# 6   Intercept            0.055569
# I(V01WOMKPR ** 2...
# 7   Intercept            0.010576
# V01WOMKPR       ...
# 8   Intercept            -0.009988
# V01WOMKPR      ...
# 9   Intercept            -0.024014
# V01WOMKPR      ...
# 10  Intercept             0.032677
# I(V01WOMADLR **...
# 11  Intercept             0.016067
# V01WOMADLR     ...
# 12  Intercept             0.008684
# V01WOMADLR     ...
# 13  Intercept             0.009846
# V01WOMADLR     ...
# 14  Intercept             0.079664
# I(V01WOMADLR **...
# 15  Intercept             0.060570
# V01WOMADLR     ...
# 16  Intercept             0.040845
# V01WOMADLR     ...
# 17  Intercept            0.044597
# V01WOMADLR      ...
# 18  Intercept            0.079948
# I(V01WOMKPR ** 3...
# 19  Intercept            0.015386
# V01WOMKPR       ...
# 20  Intercept            -0.004020
# V01WOMKPR      ...
# 21  Intercept            -0.020366
# V01WOMKPR      ...
# 22  Intercept             0.039113
# I(V01WOMADLR **...
# 23  Intercept             0.016280
# V01WOMADLR     ...
# 24  Intercept             0.008919
# V01WOMADLR     ...
# 25  Intercept             0.008509
# V01WOMADLR     ...
# 26  Intercept             0.085627
# I(V01WOMADLR **...
# 27  Intercept             0.058055
# V01WOMADLR     ...
# 28  Intercept             0.039677
# V01WOMADLR     ...
# 29  Intercept            0.043870
# V01WOMADLR      ...
# 30  Intercept               0.056044
# V01WOMKPR:V01...
# 31  Intercept              -0.012063
# V01WOMKPR    ...
# 32  Intercept                      -0.017916
# V01WO...
# 33  Intercept                      -0.010408
# V01WO...
# 34  Intercept                0.065917
# V01WOMADLR:V...
# 35  Intercept                0.007784
# V01WOMADLR  ...
# 36  Intercept                        0.008288
# V01W...
# 37  Intercept                        0.010082
# V01W...
# 38  Intercept               0.139296
# V01WOMADLR:V0...
# 39  Intercept               0.040440
# V01WOMADLR   ...
# 40  Intercept                       0.043262
# V01WO...
# 41  Intercept                       0.044033
# V01WO...
#
#                                              p_values  r_squared
# 0   Intercept    0.803252
# V01WOMKPR    0.000000
# dt...   0.657528
# 1   Intercept     1.106552e-02
# V01WOMKPR     0.000...   0.731884
# 2   Intercept     0.000649
# V01WOMADLR    0.000000
# ...   0.657528
# 3   Intercept     7.136761e-02
# V01WOMADLR    0.000...   0.712569
# 4   Intercept      8.056428e-22
# V01WOMADLR    1.01...   0.359164
# 5   Intercept     3.336689e-15
# V01WOMADLR    3.190...   0.335032
# 6   Intercept            0.000335
# I(V01WOMKPR ** 2...   0.591011
# 7   Intercept             4.444841e-01
# V01WOMKPR  ...   0.678805
# 8   Intercept              4.099255e-01
# V01WOMKPR ...   0.770779
# 9   Intercept              4.736963e-02
# V01WOMKPR ...   0.764406
# 10  Intercept             2.779076e-08
# I(V01WOMADL...   0.495492
# 11  Intercept              9.492004e-04
# V01WOMADLR...   0.657828
# 12  Intercept              5.035390e-02
# V01WOMADLR...   0.714509
# 13  Intercept             2.489692e-02
# V01WOMADLR ...   0.712767
# 14  Intercept              1.399387e-26
# I(V01WOMAD...   0.219492
# 15  Intercept              1.259472e-19
# V01WOMADLR...   0.379421
# 16  Intercept             4.580977e-14
# V01WOMADLR ...   0.352933
# 17  Intercept            5.133560e-16
# V01WOMADLR  ...   0.327902
# 18  Intercept             1.422081e-05
# I(V01WOMKPR...   0.421512
# 19  Intercept            2.618415e-01
# V01WOMKPR   ...   0.685289
# 20  Intercept             7.379839e-01
# V01WOMKPR  ...   0.775981
# 21  Intercept             9.423104e-02
# V01WOMKPR  ...   0.765129
# 22  Intercept              1.131523e-08
# I(V01WOMAD...   0.315263
# 23  Intercept             8.294719e-04
# V01WOMADLR ...   0.657910
# 24  Intercept             4.472721e-02
# V01WOMADLR ...   0.714811
# 25  Intercept             5.372889e-02
# V01WOMADLR ...   0.713662
# 26  Intercept             2.507713e-27
# I(V01WOMADL...   0.123227
# 27  Intercept             2.523229e-18
# V01WOMADLR ...   0.387873
# 28  Intercept             1.688010e-13
# V01WOMADLR ...   0.362654
# 29  Intercept            1.142937e-15
# V01WOMADLR  ...   0.334252
# 30  Intercept               0.00001
# V01WOMKPR:V01W...   0.611370
# 31  Intercept                3.201648e-01
# V01WOMKP...   0.769857
# 32  Intercept                        1.387744e-01
# ...   0.767026
# 33  Intercept                       3.940061e-01
# V...   0.760216
# 34  Intercept                 5.530696e-19
# V01WOMA...   0.283708
# 35  Intercept                 7.988553e-02
# V01WOMA...   0.712666
# 36  Intercept                         5.906666e-02...   0.714824
# 37  Intercept                        2.098455e-02
# ...   0.714759
# 38  Intercept               2.133394e-44
# V01WOMADL...   0.058181
# 39  Intercept               7.834064e-14
# V01WOMADL...   0.352752
# 40  Intercept                       2.010641e-15
# V...   0.341298
# 41  Intercept                        8.789415e-16
# ...   0.334540
#                                   V01WOMADLR      V01WOMKPR    V01WOMSTFR
# V01WOMADLR                               NaN  1.234670e-319  3.533681e-75
# V01WOMKPR                      3.465695e-284            NaN  3.961904e-04
# V01WOMSTFR                      8.809830e-09   1.617407e-01           NaN
# I(V01WOMADLR ** 2)                       NaN   1.249166e-01  8.956959e-15
# I(V01WOMADLR ** 3)                       NaN   4.154476e-01  3.515083e-08
# I(V01WOMKPR ** 2)               7.432552e-23            NaN  3.935854e-01
# I(V01WOMKPR ** 3)               1.484923e-11            NaN  6.288256e-03
# I(V01WOMSTFR ** 2)              1.225492e-52   1.018332e-06           NaN
# I(V01WOMSTFR ** 3)              7.567904e-05   9.697689e-03           NaN
# V01WOMADLR:I(V01WOMKPR ** 2)             NaN            NaN  1.991904e-11
# V01WOMADLR:I(V01WOMKPR ** 3)             NaN            NaN  4.231147e-05
# V01WOMADLR:I(V01WOMSTFR ** 2)            NaN   6.935647e-05           NaN
# V01WOMADLR:I(V01WOMSTFR ** 3)            NaN   1.254460e-08           NaN
# V01WOMADLR:V01WOMKPR                     NaN            NaN  3.618129e-15
# V01WOMADLR:V01WOMSTFR                    NaN   2.053856e-01           NaN
# V01WOMKPR:I(V01WOMSTFR ** 2)    6.479417e-07            NaN           NaN
# V01WOMKPR:I(V01WOMSTFR ** 3)    6.007588e-07            NaN           NaN
# V01WOMKPR:V01WOMSTFR            5.233450e-78            NaN           NaN

# %% [markdown]
# ## 24-Month WOMAC Right Knee Variables Regression on Drop Dataset

# %%
from scripts.womac.womac_relationships import v03_womac_right_drop_regression_summary, v03_womac_right_drop_p_matrix

display(v03_womac_right_drop_regression_summary)
display(v03_womac_right_drop_p_matrix)
# Out:
#            type                                            formula  \
# 0        linear                             V03WOMADLR ~ V03WOMKPR
# 1        linear                V03WOMADLR ~ V03WOMKPR + V03WOMSTFR
# 2        linear                             V03WOMKPR ~ V03WOMADLR
# 3        linear                V03WOMKPR ~ V03WOMADLR + V03WOMSTFR
# 4        linear                            V03WOMSTFR ~ V03WOMADLR
# 5        linear                V03WOMSTFR ~ V03WOMADLR + V03WOMKPR
# 6     quadratic                       V03WOMADLR ~ I(V03WOMKPR**2)
# 7     quadratic           V03WOMADLR ~ V03WOMKPR + I(V03WOMKPR**2)
# 8     quadratic  V03WOMADLR ~ V03WOMKPR + V03WOMSTFR + I(V03WOM...
# 9     quadratic          V03WOMADLR ~ V03WOMKPR + I(V03WOMSTFR**2)
# 10    quadratic                       V03WOMKPR ~ I(V03WOMADLR**2)
# 11    quadratic          V03WOMKPR ~ V03WOMADLR + I(V03WOMADLR**2)
# 12    quadratic  V03WOMKPR ~ V03WOMADLR + V03WOMSTFR + I(V03WOM...
# 13    quadratic          V03WOMKPR ~ V03WOMADLR + I(V03WOMSTFR**2)
# 14    quadratic                      V03WOMSTFR ~ I(V03WOMADLR**2)
# 15    quadratic         V03WOMSTFR ~ V03WOMADLR + I(V03WOMADLR**2)
# 16    quadratic  V03WOMSTFR ~ V03WOMADLR + V03WOMKPR + I(V03WOM...
# 17    quadratic          V03WOMSTFR ~ V03WOMADLR + I(V03WOMKPR**2)
# 18        cubic                       V03WOMADLR ~ I(V03WOMKPR**3)
# 19        cubic  V03WOMADLR ~ V03WOMKPR + I(V03WOMKPR**2) + I(V...
# 20        cubic  V03WOMADLR ~ V03WOMKPR + V03WOMSTFR + I(V03WOM...
# 21        cubic  V03WOMADLR ~ V03WOMKPR + I(V03WOMSTFR**2) + I(...
# 22        cubic                       V03WOMKPR ~ I(V03WOMADLR**3)
# 23        cubic  V03WOMKPR ~ V03WOMADLR + I(V03WOMADLR**2) + I(...
# 24        cubic  V03WOMKPR ~ V03WOMADLR + V03WOMSTFR + I(V03WOM...
# 25        cubic  V03WOMKPR ~ V03WOMADLR + I(V03WOMSTFR**2) + I(...
# 26        cubic                      V03WOMSTFR ~ I(V03WOMADLR**3)
# 27        cubic  V03WOMSTFR ~ V03WOMADLR + I(V03WOMADLR**2) + I...
# 28        cubic  V03WOMSTFR ~ V03WOMADLR + V03WOMKPR + I(V03WOM...
# 29        cubic  V03WOMSTFR ~ V03WOMADLR + I(V03WOMKPR**2) + I(...
# 30  interaction                  V03WOMADLR ~ V03WOMKPR:V03WOMSTFR
# 31  interaction                  V03WOMADLR ~ V03WOMKPR*V03WOMSTFR
# 32  interaction            V03WOMADLR ~ V03WOMKPR*I(V03WOMSTFR**2)
# 33  interaction            V03WOMADLR ~ V03WOMKPR*I(V03WOMSTFR**3)
# 34  interaction                  V03WOMKPR ~ V03WOMADLR:V03WOMSTFR
# 35  interaction                  V03WOMKPR ~ V03WOMADLR*V03WOMSTFR
# 36  interaction            V03WOMKPR ~ V03WOMADLR*I(V03WOMSTFR**2)
# 37  interaction            V03WOMKPR ~ V03WOMADLR*I(V03WOMSTFR**3)
# 38  interaction                  V03WOMSTFR ~ V03WOMADLR:V03WOMKPR
# 39  interaction                  V03WOMSTFR ~ V03WOMADLR*V03WOMKPR
# 40  interaction            V03WOMSTFR ~ V03WOMADLR*I(V03WOMKPR**2)
# 41  interaction            V03WOMSTFR ~ V03WOMADLR*I(V03WOMKPR**3)
#
#                                                params  \
# 0   Intercept    0.004707
# V03WOMKPR    2.452337
# dt...
# 1   Intercept    -0.019510
# V03WOMKPR     2.346312
# ...
# 2   Intercept     0.012404
# V03WOMADLR    0.279195
# ...
# 3   Intercept     0.003516
# V03WOMADLR    0.260601
# ...
# 4   Intercept     0.059154
# V03WOMADLR    0.160958
# ...
# 5   Intercept     0.028516
# V03WOMADLR    0.107195
# ...
# 6   Intercept            0.057368
# I(V03WOMKPR ** 2...
# 7   Intercept            0.014658
# V03WOMKPR       ...
# 8   Intercept            -0.004355
# V03WOMKPR      ...
# 9   Intercept            -0.011536
# V03WOMKPR      ...
# 10  Intercept             0.029524
# I(V03WOMADLR **...
# 11  Intercept             0.011287
# V03WOMADLR     ...
# 12  Intercept             0.004154
# V03WOMADLR     ...
# 13  Intercept             0.005690
# V03WOMADLR     ...
# 14  Intercept             0.075465
# I(V03WOMADLR **...
# 15  Intercept             0.054461
# V03WOMADLR     ...
# 16  Intercept             0.026707
# V03WOMADLR     ...
# 17  Intercept            0.029803
# V03WOMADLR      ...
# 18  Intercept            0.085927
# I(V03WOMKPR ** 3...
# 19  Intercept            0.018589
# V03WOMKPR       ...
# 20  Intercept             0.000381
# V03WOMKPR      ...
# 21  Intercept            -0.011503
# V03WOMKPR      ...
# 22  Intercept             0.036415
# I(V03WOMADLR **...
# 23  Intercept             0.010894
# V03WOMADLR     ...
# 24  Intercept             0.003492
# V03WOMADLR     ...
# 25  Intercept             0.004941
# V03WOMADLR     ...
# 26  Intercept             0.081764
# I(V03WOMADLR **...
# 27  Intercept             0.052089
# V03WOMADLR     ...
# 28  Intercept             0.025685
# V03WOMADLR     ...
# 29  Intercept            0.029449
# V03WOMADLR      ...
# 30  Intercept               0.065679
# V03WOMKPR:V03...
# 31  Intercept              -0.006523
# V03WOMKPR    ...
# 32  Intercept                      -0.010851
# V03WO...
# 33  Intercept                      -0.004138
# V03WO...
# 34  Intercept                0.062081
# V03WOMADLR:V...
# 35  Intercept                0.003156
# V03WOMADLR  ...
# 36  Intercept                        0.004195
# V03W...
# 37  Intercept                        0.006158
# V03W...
# 38  Intercept               0.123633
# V03WOMADLR:V0...
# 39  Intercept               0.026562
# V03WOMADLR   ...
# 40  Intercept                       0.028888
# V03WO...
# 41  Intercept                       0.029528
# V03WO...
#
#                                              p_values  r_squared
# 0   Intercept    0.741634
# V03WOMKPR    0.000000
# dt...   0.684681
# 1   Intercept     1.056063e-01
# V03WOMKPR     0.000...   0.772269
# 2   Intercept     0.009978
# V03WOMADLR    0.000000
# ...   0.684681
# 3   Intercept     3.815670e-01
# V03WOMADLR    0.000...   0.758481
# 4   Intercept      4.609220e-19
# V03WOMADLR    2.59...   0.387466
# 5   Intercept     5.893995e-10
# V03WOMADLR    1.265...   0.426997
# 6   Intercept            0.000344
# I(V03WOMKPR ** 2...   0.600637
# 7   Intercept             2.942145e-01
# V03WOMKPR  ...   0.699480
# 8   Intercept              6.992020e-01
# V03WOMKPR ...   0.802114
# 9   Intercept              3.037894e-01
# V03WOMKPR ...   0.800156
# 10  Intercept             8.715172e-07
# I(V03WOMADL...   0.508633
# 11  Intercept              1.907907e-02
# V03WOMADLR...   0.686157
# 12  Intercept              2.974171e-01
# V03WOMADLR...   0.763492
# 13  Intercept             1.539179e-01
# V03WOMADLR ...   0.758427
# 14  Intercept              1.361044e-24
# I(V03WOMAD...   0.240022
# 15  Intercept              8.746718e-17
# V03WOMADLR...   0.406333
# 16  Intercept             4.442550e-09
# V03WOMADLR ...   0.441651
# 17  Intercept             1.531150e-10
# V03WOMADLR ...   0.413906
# 18  Intercept             1.308862e-05
# I(V03WOMKPR...   0.395183
# 19  Intercept            1.797476e-01
# V03WOMKPR   ...   0.705226
# 20  Intercept             9.725899e-01
# V03WOMKPR  ...   0.809411
# 21  Intercept             3.073622e-01
# V03WOMKPR  ...   0.800157
# 22  Intercept              2.167717e-07
# I(V03WOMAD...   0.326646
# 23  Intercept              2.386574e-02
# V03WOMADLR...   0.686438
# 24  Intercept              3.798630e-01
# V03WOMADLR...   0.765322
# 25  Intercept             2.173824e-01
# V03WOMADLR ...   0.758840
# 26  Intercept             1.630331e-25
# I(V03WOMADL...   0.141059
# 27  Intercept             1.324140e-15
# V03WOMADLR ...   0.413684
# 28  Intercept             1.437799e-08
# V03WOMADLR ...   0.448138
# 29  Intercept            2.233792e-10
# V03WOMADLR  ...   0.417680
# 30  Intercept               0.000001
# V03WOMKPR:V03...   0.621278
# 31  Intercept                5.666271e-01
# V03WOMKP...   0.797867
# 32  Intercept                       3.351215e-01
# V...   0.800204
# 33  Intercept                       7.125601e-01
# V...   0.799715
# 34  Intercept                 1.293642e-14
# V03WOMA...   0.275759
# 35  Intercept                 4.327639e-01
# V03WOMA...   0.758783
# 36  Intercept                        2.927225e-01
# ...   0.760579
# 37  Intercept                        1.221990e-01
# ...   0.759204
# 38  Intercept               5.459050e-41
# V03WOMADL...   0.085016
# 39  Intercept               5.288732e-09
# V03WOMADL...   0.441868
# 40  Intercept                        3.852242e-10
# ...   0.424613
# 41  Intercept                        1.990000e-10
# ...   0.417788
#                                  V03WOMADLR     V03WOMKPR    V03WOMSTFR
# V03WOMADLR                              NaN  0.000000e+00  7.443900e-81
# V03WOMKPR                      0.000000e+00           NaN  1.605953e-06
# V03WOMSTFR                     2.541737e-11  1.540533e-01           NaN
# I(V03WOMADLR ** 2)                      NaN  4.487692e-07  8.022663e-14
# I(V03WOMADLR ** 3)                      NaN  2.713508e-03  1.464256e-07
# I(V03WOMKPR ** 2)              1.007133e-20           NaN  3.640963e-02
# I(V03WOMKPR ** 3)              5.420874e-11           NaN  5.401047e-03
# I(V03WOMSTFR ** 2)             1.669125e-57  9.826124e-08           NaN
# I(V03WOMSTFR ** 3)             4.919806e-07  5.955228e-02           NaN
# V03WOMADLR:I(V03WOMKPR ** 2)            NaN           NaN  1.479915e-10
# V03WOMADLR:I(V03WOMKPR ** 3)            NaN           NaN  2.698286e-04
# V03WOMADLR:I(V03WOMSTFR ** 2)           NaN  8.499528e-06           NaN
# V03WOMADLR:I(V03WOMSTFR ** 3)           NaN  1.688351e-08           NaN
# V03WOMADLR:V03WOMKPR                    NaN           NaN  8.592118e-15
# V03WOMADLR:V03WOMSTFR                   NaN  5.535619e-02           NaN
# V03WOMKPR:I(V03WOMSTFR ** 2)   4.952838e-01           NaN           NaN
# V03WOMKPR:I(V03WOMSTFR ** 3)   8.322261e-27           NaN           NaN
# V03WOMKPR:V03WOMSTFR           2.612530e-61           NaN           NaN

# %% [markdown]
# ## Change in WOMAC Right Knee Variables Regression on Drop Dataset

# %%
from scripts.womac.womac_relationships import womac_right_drop_change_regression_summary, womac_right_drop_change_p_matrix

display(womac_right_drop_change_regression_summary)
display(womac_right_drop_change_p_matrix)
# Out:
#            type                                            formula  \
# 0        linear                                 ΔWOMADLR ~ ΔWOMKPR
# 1        linear                      ΔWOMADLR ~ ΔWOMKPR + ΔWOMSTFR
# 2        linear                                 ΔWOMKPR ~ ΔWOMADLR
# 3        linear                      ΔWOMKPR ~ ΔWOMADLR + ΔWOMSTFR
# 4        linear                                ΔWOMSTFR ~ ΔWOMADLR
# 5        linear                      ΔWOMSTFR ~ ΔWOMADLR + ΔWOMKPR
# 6     quadratic                           ΔWOMADLR ~ I(ΔWOMKPR**2)
# 7     quadratic                 ΔWOMADLR ~ ΔWOMKPR + I(ΔWOMKPR**2)
# 8     quadratic  ΔWOMADLR ~ ΔWOMKPR + ΔWOMSTFR + I(ΔWOMKPR**2) ...
# 9     quadratic                ΔWOMADLR ~ ΔWOMKPR + I(ΔWOMSTFR**2)
# 10    quadratic                           ΔWOMKPR ~ I(ΔWOMADLR**2)
# 11    quadratic                ΔWOMKPR ~ ΔWOMADLR + I(ΔWOMADLR**2)
# 12    quadratic  ΔWOMKPR ~ ΔWOMADLR + ΔWOMSTFR + I(ΔWOMADLR**2)...
# 13    quadratic                ΔWOMKPR ~ ΔWOMADLR + I(ΔWOMSTFR**2)
# 14    quadratic                          ΔWOMSTFR ~ I(ΔWOMADLR**2)
# 15    quadratic               ΔWOMSTFR ~ ΔWOMADLR + I(ΔWOMADLR**2)
# 16    quadratic  ΔWOMSTFR ~ ΔWOMADLR + ΔWOMKPR + I(ΔWOMADLR**2)...
# 17    quadratic                ΔWOMSTFR ~ ΔWOMADLR + I(ΔWOMKPR**2)
# 18        cubic                           ΔWOMADLR ~ I(ΔWOMKPR**3)
# 19        cubic  ΔWOMADLR ~ ΔWOMKPR + I(ΔWOMKPR**2) + I(ΔWOMKPR...
# 20        cubic  ΔWOMADLR ~ ΔWOMKPR + ΔWOMSTFR + I(ΔWOMKPR**2) ...
# 21        cubic  ΔWOMADLR ~ ΔWOMKPR + I(ΔWOMSTFR**2) + I(ΔWOMST...
# 22        cubic                           ΔWOMKPR ~ I(ΔWOMADLR**3)
# 23        cubic  ΔWOMKPR ~ ΔWOMADLR + I(ΔWOMADLR**2) + I(ΔWOMAD...
# 24        cubic  ΔWOMKPR ~ ΔWOMADLR + ΔWOMSTFR + I(ΔWOMADLR**2)...
# 25        cubic  ΔWOMKPR ~ ΔWOMADLR + I(ΔWOMSTFR**2) + I(ΔWOMST...
# 26        cubic                          ΔWOMSTFR ~ I(ΔWOMADLR**3)
# 27        cubic  ΔWOMSTFR ~ ΔWOMADLR + I(ΔWOMADLR**2) + I(ΔWOMA...
# 28        cubic  ΔWOMSTFR ~ ΔWOMADLR + ΔWOMKPR + I(ΔWOMADLR**2)...
# 29        cubic  ΔWOMSTFR ~ ΔWOMADLR + I(ΔWOMKPR**2) + I(ΔWOMKP...
# 30  interaction                        ΔWOMADLR ~ ΔWOMKPR:ΔWOMSTFR
# 31  interaction                        ΔWOMADLR ~ ΔWOMKPR*ΔWOMSTFR
# 32  interaction                  ΔWOMADLR ~ ΔWOMKPR*I(ΔWOMSTFR**2)
# 33  interaction                  ΔWOMADLR ~ ΔWOMKPR*I(ΔWOMSTFR**3)
# 34  interaction                        ΔWOMKPR ~ ΔWOMADLR:ΔWOMSTFR
# 35  interaction                        ΔWOMKPR ~ ΔWOMADLR*ΔWOMSTFR
# 36  interaction                  ΔWOMKPR ~ ΔWOMADLR*I(ΔWOMSTFR**2)
# 37  interaction                  ΔWOMKPR ~ ΔWOMADLR*I(ΔWOMSTFR**3)
# 38  interaction                        ΔWOMSTFR ~ ΔWOMADLR:ΔWOMKPR
# 39  interaction                        ΔWOMSTFR ~ ΔWOMADLR*ΔWOMKPR
# 40  interaction                  ΔWOMSTFR ~ ΔWOMADLR*I(ΔWOMKPR**2)
# 41  interaction                  ΔWOMSTFR ~ ΔWOMADLR*I(ΔWOMKPR**3)
#
#                                                params  \
# 0   Intercept    0.014047
# ΔWOMKPR      1.460803
# dt...
# 1   Intercept    0.009484
# ΔWOMKPR      1.692996
# ΔW...
# 2   Intercept   -0.000611
# ΔWOMADLR     0.223821
# dt...
# 3   Intercept    0.001756
# ΔWOMADLR     0.234203
# ΔW...
# 4   Intercept   -0.009767
# ΔWOMADLR     0.036094
# dt...
# 5   Intercept   -0.004732
# ΔWOMADLR     0.043099
# ΔW...
# 6   Intercept          0.017285
# I(ΔWOMKPR ** 2)   ...
# 7   Intercept          0.014496
# ΔWOMKPR           ...
# 8   Intercept           0.006910
# ΔWOMKPR          ...
# 9   Intercept           0.007608
# ΔWOMKPR          ...
# 10  Intercept           0.004466
# I(ΔWOMADLR ** 2) ...
# 11  Intercept          -0.000070
# ΔWOMADLR         ...
# 12  Intercept           0.002854
# ΔWOMADLR         ...
# 13  Intercept           0.001450
# ΔWOMADLR         ...
# 14  Intercept          -0.008170
# I(ΔWOMADLR ** 2) ...
# 15  Intercept          -0.008745
# ΔWOMADLR         ...
# 16  Intercept          -0.003903
# ΔWOMADLR         ...
# 17  Intercept         -0.004565
# ΔWOMADLR          ...
# 18  Intercept          0.019685
# I(ΔWOMKPR ** 3)   ...
# 19  Intercept          0.014066
# ΔWOMKPR           ...
# 20  Intercept           0.006676
# ΔWOMKPR          ...
# 21  Intercept           0.006622
# ΔWOMKPR          ...
# 22  Intercept           0.003185
# I(ΔWOMADLR ** 3) ...
# 23  Intercept           0.000141
# ΔWOMADLR         ...
# 24  Intercept           0.002941
# ΔWOMADLR         ...
# 25  Intercept           0.002284
# ΔWOMADLR         ...
# 26  Intercept          -0.008842
# I(ΔWOMADLR ** 3) ...
# 27  Intercept          -0.008974
# ΔWOMADLR         ...
# 28  Intercept          -0.004058
# ΔWOMADLR         ...
# 29  Intercept         -0.004116
# ΔWOMADLR          ...
# 30  Intercept           0.025645
# ΔWOMKPR:ΔWOMSTFR ...
# 31  Intercept           0.009550
# ΔWOMKPR          ...
# 32  Intercept                   0.008625
# ΔWOMKPR  ...
# 33  Intercept                   0.009020
# ΔWOMKPR  ...
# 34  Intercept            0.039092
# ΔWOMADLR:ΔWOMSTF...
# 35  Intercept            0.001453
# ΔWOMADLR        ...
# 36  Intercept                    0.001314
# ΔWOMADLR...
# 37  Intercept                    0.002041
# ΔWOMADLR...
# 38  Intercept          -0.024416
# ΔWOMADLR:ΔWOMKPR ...
# 39  Intercept          -0.004244
# ΔWOMADLR         ...
# 40  Intercept                  -0.004515
# ΔWOMADLR ...
# 41  Intercept                  -0.004728
# ΔWOMADLR ...
#
#                                              p_values  r_squared
# 0   Intercept     4.174801e-01
# ΔWOMKPR      3.4589...   0.326959
# 1   Intercept     6.548524e-01
# ΔWOMKPR      1.2196...   0.409461
# 2   Intercept     9.281883e-01
# ΔWOMADLR     3.4589...   0.326959
# 3   Intercept     8.238747e-01
# ΔWOMADLR     1.2196...   0.401395
# 4   Intercept    2.346992e-01
# ΔWOMADLR     2.49081...   0.013409
# 5   Intercept    5.478073e-01
# ΔWOMADLR     2.28133...   0.021480
# 6   Intercept          0.423356
# I(ΔWOMKPR ** 2)   ...   0.000131
# 7   Intercept           4.040074e-01
# ΔWOMKPR      ...   0.326999
# 8   Intercept            7.480909e-01
# ΔWOMKPR     ...   0.409738
# 9   Intercept            7.252284e-01
# ΔWOMKPR     ...   0.394893
# 10  Intercept           0.601401
# I(ΔWOMADLR ** 2) ...   0.001732
# 11  Intercept            9.917737e-01
# ΔWOMADLR    ...   0.327702
# 12  Intercept            7.209638e-01
# ΔWOMADLR    ...   0.402722
# 13  Intercept            8.570742e-01
# ΔWOMADLR    ...   0.394855
# 14  Intercept           0.335018
# I(ΔWOMADLR ** 2) ...   0.000444
# 15  Intercept           2.881187e-01
# ΔWOMADLR     ...   0.014902
# 16  Intercept           6.208541e-01
# ΔWOMADLR     ...   0.023667
# 17  Intercept          5.674629e-01
# ΔWOMADLR      ...   0.021425
# 18  Intercept           2.908139e-01
# I(ΔWOMKPR ** ...   0.221271
# 19  Intercept          4.084950e-01
# ΔWOMKPR       ...   0.354363
# 20  Intercept            7.524011e-01
# ΔWOMKPR     ...   0.429534
# 21  Intercept            7.572108e-01
# ΔWOMKPR     ...   0.413197
# 22  Intercept           6.777400e-01
# I(ΔWOMADLR **...   0.139827
# 23  Intercept            9.833821e-01
# ΔWOMADLR    ...   0.328908
# 24  Intercept            7.127916e-01
# ΔWOMADLR    ...   0.403287
# 25  Intercept            7.750492e-01
# ΔWOMADLR    ...   0.401474
# 26  Intercept           0.284808
# I(ΔWOMADLR ** 3) ...   0.001462
# 27  Intercept           2.755635e-01
# ΔWOMADLR     ...   0.016126
# 28  Intercept           6.064654e-01
# ΔWOMADLR     ...   0.028020
# 29  Intercept          6.018577e-01
# ΔWOMADLR      ...   0.023718
# 30  Intercept           0.221529
# ΔWOMKPR:ΔWOMSTFR ...   0.001261
# 31  Intercept            6.527976e-01
# ΔWOMKPR     ...   0.409464
# 32  Intercept                    6.885059e-01
# ΔWOM...   0.402439
# 33  Intercept                    6.698931e-01
# ΔWOM...   0.413081
# 34  Intercept            0.002793
# ΔWOMADLR:ΔWOMSTF...   0.000393
# 35  Intercept             8.539860e-01
# ΔWOMADLR   ...   0.401703
# 36  Intercept                     8.703646e-01
# ΔWO...   0.395136
# 37  Intercept                     7.959058e-01
# ΔWO...   0.401945
# 38  Intercept           0.017015
# ΔWOMADLR:ΔWOMKPR ...   0.000036
# 39  Intercept           5.903155e-01
# ΔWOMADLR     ...   0.022078
# 40  Intercept                   5.710602e-01
# ΔWOMA...   0.025039
# 41  Intercept                   5.479425e-01
# ΔWOMA...   0.023364
#                                 ΔWOMADLR        ΔWOMKPR      ΔWOMSTFR
# ΔWOMADLR                             NaN  6.520040e-251  2.334549e-08
# ΔWOMKPR                    1.831446e-250            NaN  8.875077e-01
# ΔWOMSTFR                    8.190065e-08   9.094886e-01           NaN
# I(ΔWOMADLR ** 2)                     NaN   1.222779e-01  2.241596e-01
# I(ΔWOMADLR ** 3)                     NaN   1.169846e-01  1.714346e-01
# I(ΔWOMKPR ** 2)             8.572155e-01            NaN  5.480724e-01
# I(ΔWOMKPR ** 3)             8.920121e-22            NaN  1.169846e-01
# I(ΔWOMSTFR ** 2)            7.379312e-01   8.803228e-01           NaN
# I(ΔWOMSTFR ** 3)            8.272288e-11   8.852395e-01           NaN
# ΔWOMADLR:I(ΔWOMKPR ** 2)             NaN            NaN  1.131254e-02
# ΔWOMADLR:I(ΔWOMKPR ** 3)             NaN            NaN  6.220605e-01
# ΔWOMADLR:I(ΔWOMSTFR ** 2)            NaN   5.600132e-01           NaN
# ΔWOMADLR:I(ΔWOMSTFR ** 3)            NaN   3.469748e-01           NaN
# ΔWOMADLR:ΔWOMKPR                     NaN            NaN  6.868363e-01
# ΔWOMADLR:ΔWOMSTFR                    NaN   5.727675e-01           NaN
# ΔWOMKPR:I(ΔWOMSTFR ** 2)    2.664189e-07            NaN           NaN
# ΔWOMKPR:I(ΔWOMSTFR ** 3)    8.852395e-01            NaN           NaN
# ΔWOMKPR:ΔWOMSTFR            5.799739e-01            NaN           NaN

# %% [markdown]
# ## 12-Month WOMAC Left Knee Variables Regression on Median Dataset

# %%
from scripts.womac.womac_relationships import v01_womac_left_median_regression_summary, v01_womac_left_median_p_matrix

display(v01_womac_left_median_regression_summary)
display(v01_womac_left_median_p_matrix)
# Out:
#            type                                            formula  \
# 0        linear                             V01WOMADLL ~ V01WOMKPL
# 1        linear                V01WOMADLL ~ V01WOMKPL + V01WOMSTFL
# 2        linear                             V01WOMKPL ~ V01WOMADLL
# 3        linear                V01WOMKPL ~ V01WOMADLL + V01WOMSTFL
# 4        linear                            V01WOMSTFL ~ V01WOMADLL
# 5        linear                V01WOMSTFL ~ V01WOMADLL + V01WOMKPL
# 6     quadratic                       V01WOMADLL ~ I(V01WOMKPL**2)
# 7     quadratic           V01WOMADLL ~ V01WOMKPL + I(V01WOMKPL**2)
# 8     quadratic  V01WOMADLL ~ V01WOMKPL + V01WOMSTFL + I(V01WOM...
# 9     quadratic          V01WOMADLL ~ V01WOMKPL + I(V01WOMSTFL**2)
# 10    quadratic                       V01WOMKPL ~ I(V01WOMADLL**2)
# 11    quadratic          V01WOMKPL ~ V01WOMADLL + I(V01WOMADLL**2)
# 12    quadratic  V01WOMKPL ~ V01WOMADLL + V01WOMSTFL + I(V01WOM...
# 13    quadratic          V01WOMKPL ~ V01WOMADLL + I(V01WOMSTFL**2)
# 14    quadratic                      V01WOMSTFL ~ I(V01WOMADLL**2)
# 15    quadratic         V01WOMSTFL ~ V01WOMADLL + I(V01WOMADLL**2)
# 16    quadratic  V01WOMSTFL ~ V01WOMADLL + V01WOMKPL + I(V01WOM...
# 17    quadratic          V01WOMSTFL ~ V01WOMADLL + I(V01WOMKPL**2)
# 18        cubic                       V01WOMADLL ~ I(V01WOMKPL**3)
# 19        cubic  V01WOMADLL ~ V01WOMKPL + I(V01WOMKPL**2) + I(V...
# 20        cubic  V01WOMADLL ~ V01WOMKPL + V01WOMSTFL + I(V01WOM...
# 21        cubic  V01WOMADLL ~ V01WOMKPL + I(V01WOMSTFL**2) + I(...
# 22        cubic                       V01WOMKPL ~ I(V01WOMADLL**3)
# 23        cubic  V01WOMKPL ~ V01WOMADLL + I(V01WOMADLL**2) + I(...
# 24        cubic  V01WOMKPL ~ V01WOMADLL + V01WOMSTFL + I(V01WOM...
# 25        cubic  V01WOMKPL ~ V01WOMADLL + I(V01WOMSTFL**2) + I(...
# 26        cubic                      V01WOMSTFL ~ I(V01WOMADLL**3)
# 27        cubic  V01WOMSTFL ~ V01WOMADLL + I(V01WOMADLL**2) + I...
# 28        cubic  V01WOMSTFL ~ V01WOMADLL + V01WOMKPL + I(V01WOM...
# 29        cubic  V01WOMSTFL ~ V01WOMADLL + I(V01WOMKPL**2) + I(...
# 30  interaction                  V01WOMADLL ~ V01WOMKPL:V01WOMSTFL
# 31  interaction                  V01WOMADLL ~ V01WOMKPL*V01WOMSTFL
# 32  interaction            V01WOMADLL ~ V01WOMKPL*I(V01WOMSTFL**2)
# 33  interaction            V01WOMADLL ~ V01WOMKPL*I(V01WOMSTFL**3)
# 34  interaction                  V01WOMKPL ~ V01WOMADLL:V01WOMSTFL
# 35  interaction                  V01WOMKPL ~ V01WOMADLL*V01WOMSTFL
# 36  interaction            V01WOMKPL ~ V01WOMADLL*I(V01WOMSTFL**2)
# 37  interaction            V01WOMKPL ~ V01WOMADLL*I(V01WOMSTFL**3)
# 38  interaction                  V01WOMSTFL ~ V01WOMADLL:V01WOMKPL
# 39  interaction                  V01WOMSTFL ~ V01WOMADLL*V01WOMKPL
# 40  interaction            V01WOMSTFL ~ V01WOMADLL*I(V01WOMKPL**2)
# 41  interaction            V01WOMSTFL ~ V01WOMADLL*I(V01WOMKPL**3)
#
#                                                params  \
# 0   Intercept    0.010524
# V01WOMKPL    2.906406
# dt...
# 1   Intercept    -0.009648
# V01WOMKPL     2.600128
# ...
# 2   Intercept     0.003753
# V01WOMADLL    0.263313
# ...
# 3   Intercept     0.000934
# V01WOMADLL    0.252286
# ...
# 4   Intercept     0.027322
# V01WOMADLL    0.154057
# ...
# 5   Intercept     0.019632
# V01WOMADLL    0.110692
# ...
# 6   Intercept            0.055629
# I(V01WOMKPL ** 2...
# 7   Intercept            0.013971
# V01WOMKPL       ...
# 8   Intercept            -0.003255
# V01WOMKPL      ...
# 9   Intercept            -0.000855
# V01WOMKPL      ...
# 10  Intercept             0.016808
# I(V01WOMADLL **...
# 11  Intercept             0.004838
# V01WOMADLL     ...
# 12  Intercept             0.002803
# V01WOMADLL     ...
# 13  Intercept             0.001447
# V01WOMADLL     ...
# 14  Intercept             0.038720
# I(V01WOMADLL **...
# 15  Intercept             0.024078
# V01WOMADLL     ...
# 16  Intercept             0.017983
# V01WOMADLL     ...
# 17  Intercept            0.019939
# V01WOMADLL      ...
# 18  Intercept            0.072910
# I(V01WOMKPL ** 3...
# 19  Intercept            0.017318
# V01WOMKPL       ...
# 20  Intercept            -0.000183
# V01WOMKPL      ...
# 21  Intercept            -0.004184
# V01WOMKPL      ...
# 22  Intercept             0.021876
# I(V01WOMADLL **...
# 23  Intercept             0.005056
# V01WOMADLL     ...
# 24  Intercept             0.003182
# V01WOMADLL     ...
# 25  Intercept             0.001804
# V01WOMADLL     ...
# 26  Intercept             0.043097
# I(V01WOMADLL **...
# 27  Intercept             0.022574
# V01WOMADLL     ...
# 28  Intercept             0.017107
# V01WOMADLL     ...
# 29  Intercept            0.019870
# V01WOMADLL      ...
# 30  Intercept               0.054502
# V01WOMKPL:V01...
# 31  Intercept              -0.004267
# V01WOMKPL    ...
# 32  Intercept                      -0.002714
# V01WO...
# 33  Intercept                       0.002968
# V01WO...
# 34  Intercept                0.033449
# V01WOMADLL:V...
# 35  Intercept                0.002189
# V01WOMADLL  ...
# 36  Intercept                        0.001768
# V01W...
# 37  Intercept                        0.002448
# V01W...
# 38  Intercept               0.071696
# V01WOMADLL:V0...
# 39  Intercept               0.017961
# V01WOMADLL   ...
# 40  Intercept                       0.019436
# V01WO...
# 41  Intercept                       0.019730
# V01WO...
#
#                                              p_values  r_squared
# 0   Intercept    0.277492
# V01WOMKPL    0.000000
# dt...   0.765293
# 1   Intercept     2.482569e-01
# V01WOMKPL     0.000...   0.804189
# 2   Intercept     0.19818
# V01WOMADLL    0.00000
# dt...   0.765293
# 3   Intercept     7.198573e-01
# V01WOMADLL    0.000...   0.788855
# 4   Intercept     3.500138e-12
# V01WOMADLL    0.000...   0.485809
# 5   Intercept     6.050916e-10
# V01WOMADLL    5.528...   0.438130
# 6   Intercept            0.000007
# I(V01WOMKPL ** 2...   0.613664
# 7   Intercept            1.481139e-01
# V01WOMKPL   ...   0.767766
# 8   Intercept              6.913196e-01
# V01WOMKPL ...   0.812476
# 9   Intercept             9.163314e-01
# V01WOMKPL  ...   0.812125
# 10  Intercept             0.000004
# I(V01WOMADLL **...   0.633072
# 11  Intercept              9.631563e-02
# V01WOMADLL...   0.767648
# 12  Intercept              2.719578e-01
# V01WOMADLL...   0.798174
# 13  Intercept             5.686380e-01
# V01WOMADLL ...   0.796895
# 14  Intercept              1.637273e-17
# I(V01WOMAD...   0.309418
# 15  Intercept              4.138104e-10
# V01WOMADLL...   0.507191
# 16  Intercept             7.597200e-09
# V01WOMADLL ...   0.460502
# 17  Intercept             4.237900e-10
# V01WOMADLL ...   0.430995
# 18  Intercept            0.000002
# I(V01WOMKPL ** 3...   0.421406
# 19  Intercept             7.016070e-02
# V01WOMKPL  ...   0.772933
# 20  Intercept             9.820006e-01
# V01WOMKPL  ...   0.816370
# 21  Intercept             6.071866e-01
# V01WOMKPL  ...   0.813626
# 22  Intercept             0.000001
# I(V01WOMADLL **...   0.445045
# 23  Intercept              8.268831e-02
# V01WOMADLL...   0.767779
# 24  Intercept             2.116546e-01
# V01WOMADLL ...   0.799288
# 25  Intercept             0.478819
# V01WOMADLL     ...   0.797086
# 26  Intercept              2.375208e-18
# I(V01WOMAD...   0.186361
# 27  Intercept              3.926637e-09
# V01WOMADLL...   0.513672
# 28  Intercept             3.168805e-08
# V01WOMADLL ...   0.468776
# 29  Intercept             4.292734e-10
# V01WOMADLL ...   0.434749
# 30  Intercept               1.277417e-07
# V01WOMKPL...   0.617623
# 31  Intercept                6.035774e-01
# V01WOMKP...   0.811392
# 32  Intercept                       7.390154e-01
# V...   0.812831
# 33  Intercept                       7.187168e-01
# V...   0.807555
# 34  Intercept                2.058794e-14
# V01WOMAD...   0.419247
# 35  Intercept                 3.943721e-01
# V01WOMA...   0.794882
# 36  Intercept                        4.869856e-01
# ...   0.797141
# 37  Intercept                        3.350278e-01
# ...   0.796932
# 38  Intercept               1.792973e-34
# V01WOMADL...   0.090799
# 39  Intercept               9.151497e-09
# V01WOMADL...   0.455658
# 40  Intercept                        7.330670e-10
# ...   0.444386
# 41  Intercept                        5.017377e-10
# ...   0.438289
#                                  V01WOMADLL     V01WOMKPL     V01WOMSTFL
# V01WOMADLL                              NaN  0.000000e+00  3.446485e-138
# V01WOMKPL                      0.000000e+00           NaN   3.677302e-03
# V01WOMSTFL                     1.642119e-02  7.968827e-08            NaN
# I(V01WOMADLL ** 2)                      NaN  6.804214e-03   2.609027e-20
# I(V01WOMADLL ** 3)                      NaN  2.218336e-01   3.568683e-10
# I(V01WOMKPL ** 2)              4.471956e-09           NaN   2.917340e-02
# I(V01WOMKPL ** 3)              1.990051e-16           NaN   1.238271e-05
# I(V01WOMSTFL ** 2)             4.749923e-43  4.784704e-21            NaN
# I(V01WOMSTFL ** 3)             1.052845e-06  5.851510e-05            NaN
# V01WOMADLL:I(V01WOMKPL ** 2)            NaN           NaN   2.688345e-17
# V01WOMADLL:I(V01WOMKPL ** 3)            NaN           NaN   5.082353e-09
# V01WOMADLL:I(V01WOMSTFL ** 2)           NaN  6.793391e-02            NaN
# V01WOMADLL:I(V01WOMSTFL ** 3)           NaN  2.992748e-05            NaN
# V01WOMADLL:V01WOMKPL                    NaN           NaN   7.517343e-23
# V01WOMADLL:V01WOMSTFL                   NaN  4.814745e-21            NaN
# V01WOMKPL:I(V01WOMSTFL ** 2)   9.023159e-04           NaN            NaN
# V01WOMKPL:I(V01WOMSTFL ** 3)   1.361413e-21           NaN            NaN
# V01WOMKPL:V01WOMSTFL           1.021393e-26           NaN            NaN

# %% [markdown]
# ## 24-Month WOMAC Left Knee Variables Regression on Median Dataset

# %%
from scripts.womac.womac_relationships import v03_womac_left_median_regression_summary, v03_womac_left_median_p_matrix

display(v03_womac_left_median_regression_summary)
display(v03_womac_left_median_p_matrix)
# Out:
#            type                                            formula  \
# 0        linear                             V03WOMADLL ~ V03WOMKPL
# 1        linear                V03WOMADLL ~ V03WOMKPL + V03WOMSTFL
# 2        linear                             V03WOMKPL ~ V03WOMADLL
# 3        linear                V03WOMKPL ~ V03WOMADLL + V03WOMSTFL
# 4        linear                            V03WOMSTFL ~ V03WOMADLL
# 5        linear                V03WOMSTFL ~ V03WOMADLL + V03WOMKPL
# 6     quadratic                       V03WOMADLL ~ I(V03WOMKPL**2)
# 7     quadratic           V03WOMADLL ~ V03WOMKPL + I(V03WOMKPL**2)
# 8     quadratic  V03WOMADLL ~ V03WOMKPL + V03WOMSTFL + I(V03WOM...
# 9     quadratic          V03WOMADLL ~ V03WOMKPL + I(V03WOMSTFL**2)
# 10    quadratic                       V03WOMKPL ~ I(V03WOMADLL**2)
# 11    quadratic          V03WOMKPL ~ V03WOMADLL + I(V03WOMADLL**2)
# 12    quadratic  V03WOMKPL ~ V03WOMADLL + V03WOMSTFL + I(V03WOM...
# 13    quadratic          V03WOMKPL ~ V03WOMADLL + I(V03WOMSTFL**2)
# 14    quadratic                      V03WOMSTFL ~ I(V03WOMADLL**2)
# 15    quadratic         V03WOMSTFL ~ V03WOMADLL + I(V03WOMADLL**2)
# 16    quadratic  V03WOMSTFL ~ V03WOMADLL + V03WOMKPL + I(V03WOM...
# 17    quadratic          V03WOMSTFL ~ V03WOMADLL + I(V03WOMKPL**2)
# 18        cubic                       V03WOMADLL ~ I(V03WOMKPL**3)
# 19        cubic  V03WOMADLL ~ V03WOMKPL + I(V03WOMKPL**2) + I(V...
# 20        cubic  V03WOMADLL ~ V03WOMKPL + V03WOMSTFL + I(V03WOM...
# 21        cubic  V03WOMADLL ~ V03WOMKPL + I(V03WOMSTFL**2) + I(...
# 22        cubic                       V03WOMKPL ~ I(V03WOMADLL**3)
# 23        cubic  V03WOMKPL ~ V03WOMADLL + I(V03WOMADLL**2) + I(...
# 24        cubic  V03WOMKPL ~ V03WOMADLL + V03WOMSTFL + I(V03WOM...
# 25        cubic  V03WOMKPL ~ V03WOMADLL + I(V03WOMSTFL**2) + I(...
# 26        cubic                      V03WOMSTFL ~ I(V03WOMADLL**3)
# 27        cubic  V03WOMSTFL ~ V03WOMADLL + I(V03WOMADLL**2) + I...
# 28        cubic  V03WOMSTFL ~ V03WOMADLL + V03WOMKPL + I(V03WOM...
# 29        cubic  V03WOMSTFL ~ V03WOMADLL + I(V03WOMKPL**2) + I(...
# 30  interaction                  V03WOMADLL ~ V03WOMKPL:V03WOMSTFL
# 31  interaction                  V03WOMADLL ~ V03WOMKPL*V03WOMSTFL
# 32  interaction            V03WOMADLL ~ V03WOMKPL*I(V03WOMSTFL**2)
# 33  interaction            V03WOMADLL ~ V03WOMKPL*I(V03WOMSTFL**3)
# 34  interaction                  V03WOMKPL ~ V03WOMADLL:V03WOMSTFL
# 35  interaction                  V03WOMKPL ~ V03WOMADLL*V03WOMSTFL
# 36  interaction            V03WOMKPL ~ V03WOMADLL*I(V03WOMSTFL**2)
# 37  interaction            V03WOMKPL ~ V03WOMADLL*I(V03WOMSTFL**3)
# 38  interaction                  V03WOMSTFL ~ V03WOMADLL:V03WOMKPL
# 39  interaction                  V03WOMSTFL ~ V03WOMADLL*V03WOMKPL
# 40  interaction            V03WOMSTFL ~ V03WOMADLL*I(V03WOMKPL**2)
# 41  interaction            V03WOMSTFL ~ V03WOMADLL*I(V03WOMKPL**3)
#
#                                                params  \
# 0   Intercept   -0.003555
# V03WOMKPL    2.634636
# dt...
# 1   Intercept    -0.015948
# V03WOMKPL     2.445408
# ...
# 2   Intercept     0.009947
# V03WOMADLL    0.289742
# ...
# 3   Intercept     0.003921
# V03WOMADLL    0.272529
# ...
# 4   Intercept     0.031183
# V03WOMADLL    0.155262
# ...
# 5   Intercept     0.020468
# V03WOMADLL    0.082498
# ...
# 6   Intercept            0.060931
# I(V03WOMKPL ** 2...
# 7   Intercept            0.003848
# V03WOMKPL       ...
# 8   Intercept            -0.004557
# V03WOMKPL      ...
# 9   Intercept            -0.009827
# V03WOMKPL      ...
# 10  Intercept             0.02778
# I(V03WOMADLL ** ...
# 11  Intercept             0.009035
# V03WOMADLL     ...
# 12  Intercept             0.003670
# V03WOMADLL     ...
# 13  Intercept             0.007088
# V03WOMADLL     ...
# 14  Intercept             0.044643
# I(V03WOMADLL **...
# 15  Intercept             0.027097
# V03WOMADLL     ...
# 16  Intercept             0.016646
# V03WOMADLL     ...
# 17  Intercept            0.021557
# V03WOMADLL      ...
# 18  Intercept            0.080348
# I(V03WOMKPL ** 3...
# 19  Intercept            0.008045
# V03WOMKPL       ...
# 20  Intercept            -0.001669
# V03WOMKPL      ...
# 21  Intercept            -0.010048
# V03WOMKPL      ...
# 22  Intercept             0.032969
# I(V03WOMADLL **...
# 23  Intercept             0.007793
# V03WOMADLL     ...
# 24  Intercept             0.002845
# V03WOMADLL     ...
# 25  Intercept             0.005890
# V03WOMADLL     ...
# 26  Intercept             0.049001
# I(V03WOMADLL **...
# 27  Intercept             0.023686
# V03WOMADLL     ...
# 28  Intercept             0.014577
# V03WOMADLL     ...
# 29  Intercept            0.021544
# V03WOMADLL      ...
# 30  Intercept               0.052308
# V03WOMKPL:V03...
# 31  Intercept              -0.005593
# V03WOMKPL    ...
# 32  Intercept                      -0.009027
# V03WO...
# 33  Intercept                      -0.005517
# V03WO...
# 34  Intercept                0.043569
# V03WOMADLL:V...
# 35  Intercept                0.003400
# V03WOMADLL  ...
# 36  Intercept                        0.005404
# V03W...
# 37  Intercept                        0.007013
# V03W...
# 38  Intercept               0.058491
# V03WOMADLL:V0...
# 39  Intercept               0.016934
# V03WOMADLL   ...
# 40  Intercept                       0.021114
# V03WO...
# 41  Intercept                       0.021548
# V03WO...
#
#                                              p_values  r_squared
# 0   Intercept    0.694746
# V03WOMKPL    0.000000
# dt...   0.763364
# 1   Intercept     4.106067e-02
# V03WOMKPL     0.000...   0.812515
# 2   Intercept     0.000919
# V03WOMADLL    0.000000
# ...   0.763364
# 3   Intercept     1.324649e-01
# V03WOMADLL    0.000...   0.812790
# 4   Intercept     4.896823e-15
# V03WOMADLL    0.000...   0.450749
# 5   Intercept     7.366348e-11
# V03WOMADLL    2.445...   0.462166
# 6   Intercept            2.374273e-07
# I(V03WOMKPL ...   0.596639
# 7   Intercept            6.675308e-01
# V03WOMKPL   ...   0.770319
# 8   Intercept              5.331883e-01
# V03WOMKPL ...   0.836408
# 9   Intercept              1.771625e-01
# V03WOMKPL ...   0.834832
# 10  Intercept             2.629178e-11
# I(V03WOMADL...   0.543010
# 11  Intercept             0.002633
# V03WOMADLL     ...   0.764457
# 12  Intercept             1.586727e-01
# V03WOMADLL ...   0.814097
# 13  Intercept             6.938351e-03
# V03WOMADLL ...   0.807417
# 14  Intercept              4.334830e-22
# I(V03WOMAD...   0.258308
# 15  Intercept              3.637431e-12
# V03WOMADLL...   0.476628
# 16  Intercept             3.782084e-08
# V03WOMADLL ...   0.503798
# 17  Intercept             1.369685e-11
# V03WOMADLL ...   0.446056
# 18  Intercept            3.148727e-08
# I(V03WOMKPL ...   0.387783
# 19  Intercept             3.646834e-01
# V03WOMKPL  ...   0.775410
# 20  Intercept              8.170099e-01
# V03WOMKPL ...   0.841218
# 21  Intercept             1.693680e-01
# V03WOMKPL  ...   0.834838
# 22  Intercept              3.302659e-11
# I(V03WOMAD...   0.349103
# 23  Intercept              9.267467e-03
# V03WOMADLL...   0.767076
# 24  Intercept              2.706325e-01
# V03WOMADLL...   0.817542
# 25  Intercept             2.494522e-02
# V03WOMADLL ...   0.808900
# 26  Intercept              6.242224e-23
# I(V03WOMAD...   0.140745
# 27  Intercept              6.353161e-10
# V03WOMADLL...   0.496959
# 28  Intercept             8.525028e-07
# V03WOMADLL ...   0.526459
# 29  Intercept             1.360118e-11
# V03WOMADLL ...   0.447066
# 30  Intercept               2.054724e-07
# V03WOMKPL...   0.620495
# 31  Intercept                4.467611e-01
# V03WOMKP...   0.834484
# 32  Intercept                       2.167422e-01
# V...   0.834918
# 33  Intercept                       4.518545e-01
# V...   0.832804
# 34  Intercept                 2.463572e-17
# V03WOMA...   0.344690
# 35  Intercept                1.918803e-01
# V03WOMAD...   0.813591
# 36  Intercept                        3.830454e-02
# ...   0.811140
# 37  Intercept                        7.326076e-03
# ...   0.809129
# 38  Intercept               4.601763e-28
# V03WOMADL...   0.099943
# 39  Intercept               2.294380e-08
# V03WOMADL...   0.501988
# 40  Intercept                        2.628886e-11
# ...   0.453617
# 41  Intercept                        1.297607e-11
# ...   0.447904
#                                  V03WOMADLL     V03WOMKPL     V03WOMSTFL
# V03WOMADLL                              NaN  0.000000e+00  1.096713e-187
# V03WOMKPL                      0.000000e+00           NaN   3.483710e-31
# V03WOMSTFL                     1.669805e-10  5.091366e-09            NaN
# I(V03WOMADLL ** 2)                      NaN  2.938749e-07   1.178061e-33
# I(V03WOMADLL ** 3)                      NaN  7.212599e-09   6.678278e-28
# I(V03WOMKPL ** 2)              2.217947e-21           NaN   2.899221e-05
# I(V03WOMKPL ** 3)              2.178442e-16           NaN   2.157850e-02
# I(V03WOMSTFL ** 2)             9.269226e-62  5.904059e-12            NaN
# I(V03WOMSTFL ** 3)             3.864701e-10  1.557925e-06            NaN
# V03WOMADLL:I(V03WOMKPL ** 2)            NaN           NaN   1.327362e-10
# V03WOMADLL:I(V03WOMKPL ** 3)            NaN           NaN   3.660759e-02
# V03WOMADLL:I(V03WOMSTFL ** 2)           NaN  1.862435e-14            NaN
# V03WOMADLL:I(V03WOMSTFL ** 3)           NaN  2.580115e-15            NaN
# V03WOMADLL:V03WOMKPL                    NaN           NaN   4.008355e-53
# V03WOMADLL:V03WOMSTFL                   NaN  1.842535e-04            NaN
# V03WOMKPL:I(V03WOMSTFL ** 2)   2.240474e-01           NaN            NaN
# V03WOMKPL:I(V03WOMSTFL ** 3)   8.393658e-23           NaN            NaN
# V03WOMKPL:V03WOMSTFL           5.380050e-85           NaN            NaN

# %% [markdown]
# ## 12-Month WOMAC Right Knee Variables Regression on Median Dataset

# %%
from scripts.womac.womac_relationships import v01_womac_right_median_regression_summary, v01_womac_right_median_p_matrix

display(v01_womac_right_median_regression_summary)
display(v01_womac_right_median_p_matrix)
# Out:
#            type                                            formula  \
# 0        linear                             V01WOMADLR ~ V01WOMKPR
# 1        linear                V01WOMADLR ~ V01WOMKPR + V01WOMSTFR
# 2        linear                             V01WOMKPR ~ V01WOMADLR
# 3        linear                V01WOMKPR ~ V01WOMADLR + V01WOMSTFR
# 4        linear                            V01WOMSTFR ~ V01WOMADLR
# 5        linear                V01WOMSTFR ~ V01WOMADLR + V01WOMKPR
# 6     quadratic                       V01WOMADLR ~ I(V01WOMKPR**2)
# 7     quadratic           V01WOMADLR ~ V01WOMKPR + I(V01WOMKPR**2)
# 8     quadratic  V01WOMADLR ~ V01WOMKPR + V01WOMSTFR + I(V01WOM...
# 9     quadratic          V01WOMADLR ~ V01WOMKPR + I(V01WOMSTFR**2)
# 10    quadratic                       V01WOMKPR ~ I(V01WOMADLR**2)
# 11    quadratic          V01WOMKPR ~ V01WOMADLR + I(V01WOMADLR**2)
# 12    quadratic  V01WOMKPR ~ V01WOMADLR + V01WOMSTFR + I(V01WOM...
# 13    quadratic          V01WOMKPR ~ V01WOMADLR + I(V01WOMSTFR**2)
# 14    quadratic                      V01WOMSTFR ~ I(V01WOMADLR**2)
# 15    quadratic         V01WOMSTFR ~ V01WOMADLR + I(V01WOMADLR**2)
# 16    quadratic  V01WOMSTFR ~ V01WOMADLR + V01WOMKPR + I(V01WOM...
# 17    quadratic          V01WOMSTFR ~ V01WOMADLR + I(V01WOMKPR**2)
# 18        cubic                       V01WOMADLR ~ I(V01WOMKPR**3)
# 19        cubic  V01WOMADLR ~ V01WOMKPR + I(V01WOMKPR**2) + I(V...
# 20        cubic  V01WOMADLR ~ V01WOMKPR + V01WOMSTFR + I(V01WOM...
# 21        cubic  V01WOMADLR ~ V01WOMKPR + I(V01WOMSTFR**2) + I(...
# 22        cubic                       V01WOMKPR ~ I(V01WOMADLR**3)
# 23        cubic  V01WOMKPR ~ V01WOMADLR + I(V01WOMADLR**2) + I(...
# 24        cubic  V01WOMKPR ~ V01WOMADLR + V01WOMSTFR + I(V01WOM...
# 25        cubic  V01WOMKPR ~ V01WOMADLR + I(V01WOMSTFR**2) + I(...
# 26        cubic                      V01WOMSTFR ~ I(V01WOMADLR**3)
# 27        cubic  V01WOMSTFR ~ V01WOMADLR + I(V01WOMADLR**2) + I...
# 28        cubic  V01WOMSTFR ~ V01WOMADLR + V01WOMKPR + I(V01WOM...
# 29        cubic  V01WOMSTFR ~ V01WOMADLR + I(V01WOMKPR**2) + I(...
# 30  interaction                  V01WOMADLR ~ V01WOMKPR:V01WOMSTFR
# 31  interaction                  V01WOMADLR ~ V01WOMKPR*V01WOMSTFR
# 32  interaction            V01WOMADLR ~ V01WOMKPR*I(V01WOMSTFR**2)
# 33  interaction            V01WOMADLR ~ V01WOMKPR*I(V01WOMSTFR**3)
# 34  interaction                  V01WOMKPR ~ V01WOMADLR:V01WOMSTFR
# 35  interaction                  V01WOMKPR ~ V01WOMADLR*V01WOMSTFR
# 36  interaction            V01WOMKPR ~ V01WOMADLR*I(V01WOMSTFR**2)
# 37  interaction            V01WOMKPR ~ V01WOMADLR*I(V01WOMSTFR**3)
# 38  interaction                  V01WOMSTFR ~ V01WOMADLR:V01WOMKPR
# 39  interaction                  V01WOMSTFR ~ V01WOMADLR*V01WOMKPR
# 40  interaction            V01WOMSTFR ~ V01WOMADLR*I(V01WOMKPR**2)
# 41  interaction            V01WOMSTFR ~ V01WOMADLR*I(V01WOMKPR**3)
#
#                                                params  \
# 0   Intercept   -0.001294
# V01WOMKPR    2.333890
# dt...
# 1   Intercept    -0.031187
# V01WOMKPR     2.226042
# ...
# 2   Intercept     0.016213
# V01WOMADLR    0.277562
# ...
# 3   Intercept     0.007977
# V01WOMADLR    0.263696
# ...
# 4   Intercept     0.062052
# V01WOMADLR    0.167576
# ...
# 5   Intercept     0.041295
# V01WOMADLR    0.119273
# ...
# 6   Intercept            0.055611
# I(V01WOMKPR ** 2...
# 7   Intercept            0.013031
# V01WOMKPR       ...
# 8   Intercept            -0.008323
# V01WOMKPR      ...
# 9   Intercept            -0.023268
# V01WOMKPR      ...
# 10  Intercept             0.032768
# I(V01WOMADLR **...
# 11  Intercept             0.015804
# V01WOMADLR     ...
# 12  Intercept             0.008591
# V01WOMADLR     ...
# 13  Intercept             0.009750
# V01WOMADLR     ...
# 14  Intercept             0.077295
# I(V01WOMADLR **...
# 15  Intercept             0.057393
# V01WOMADLR     ...
# 16  Intercept             0.039134
# V01WOMADLR     ...
# 17  Intercept            0.042779
# V01WOMADLR      ...
# 18  Intercept            0.079944
# I(V01WOMKPR ** 3...
# 19  Intercept            0.017250
# V01WOMKPR       ...
# 20  Intercept            -0.003230
# V01WOMKPR      ...
# 21  Intercept            -0.018562
# V01WOMKPR      ...
# 22  Intercept             0.039577
# I(V01WOMADLR **...
# 23  Intercept             0.016065
# V01WOMADLR     ...
# 24  Intercept             0.008729
# V01WOMADLR     ...
# 25  Intercept             0.008548
# V01WOMADLR     ...
# 26  Intercept             0.08370
# I(V01WOMADLR ** ...
# 27  Intercept             0.054700
# V01WOMADLR     ...
# 28  Intercept             0.037928
# V01WOMADLR     ...
# 29  Intercept            0.041999
# V01WOMADLR      ...
# 30  Intercept               0.055335
# V01WOMKPR:V01...
# 31  Intercept              -0.009424
# V01WOMKPR    ...
# 32  Intercept                      -0.015458
# V01WO...
# 33  Intercept                      -0.008675
# V01WO...
# 34  Intercept                0.064436
# V01WOMADLR:V...
# 35  Intercept                0.007896
# V01WOMADLR  ...
# 36  Intercept                        0.008429
# V01W...
# 37  Intercept                        0.010113
# V01W...
# 38  Intercept               0.137260
# V01WOMADLR:V0...
# 39  Intercept               0.038722
# V01WOMADLR   ...
# 40  Intercept                       0.041537
# V01WO...
# 41  Intercept                       0.042245
# V01WO...
#
#                                              p_values  r_squared
# 0   Intercept    0.915313
# V01WOMKPR    0.000000
# dt...   0.647800
# 1   Intercept     4.772993e-03
# V01WOMKPR     0.000...   0.719714
# 2   Intercept     0.00011
# V01WOMADLR    0.00000
# dt...   0.647800
# 3   Intercept     3.602954e-02
# V01WOMADLR    0.000...   0.699273
# 4   Intercept      4.578193e-27
# V01WOMADLR    7.89...   0.370907
# 5   Intercept     1.014536e-18
# V01WOMADLR    1.146...   0.329087
# 6   Intercept            0.000022
# I(V01WOMKPR ** 2...   0.588108
# 7   Intercept             2.692638e-01
# V01WOMKPR  ...   0.671629
# 8   Intercept              4.148804e-01
# V01WOMKPR ...   0.762902
# 9   Intercept              2.310508e-02
# V01WOMKPR ...   0.754711
# 10  Intercept             1.248617e-10
# I(V01WOMADL...   0.479100
# 11  Intercept              1.689680e-04
# V01WOMADLR...   0.648027
# 12  Intercept              2.396813e-02
# V01WOMADLR...   0.701045
# 13  Intercept             9.655109e-03
# V01WOMADLR ...   0.699372
# 14  Intercept              1.390947e-33
# I(V01WOMAD...   0.220549
# 15  Intercept              4.291648e-24
# V01WOMADLR...   0.393187
# 16  Intercept             2.551503e-17
# V01WOMADLR ...   0.346756
# 17  Intercept             8.302073e-20
# V01WOMADLR ...   0.321499
# 18  Intercept            2.834370e-07
# I(V01WOMKPR ...   0.419062
# 19  Intercept            1.407437e-01
# V01WOMKPR   ...   0.677261
# 20  Intercept             7.500635e-01
# V01WOMKPR  ...   0.767285
# 21  Intercept             7.086838e-02
# V01WOMKPR  ...   0.756090
# 22  Intercept              4.001854e-11
# I(V01WOMAD...   0.278216
# 23  Intercept              1.353262e-04
# V01WOMADLR...   0.648152
# 24  Intercept             2.199205e-02
# V01WOMADLR ...   0.701180
# 25  Intercept             2.391507e-02
# V01WOMADLR ...   0.700194
# 26  Intercept             1.311221e-34
# I(V01WOMADL...   0.113116
# 27  Intercept              2.696845e-22
# V01WOMADLR...   0.403030
# 28  Intercept             1.439017e-16
# V01WOMADLR ...   0.357643
# 29  Intercept            2.566075e-19
# V01WOMADLR  ...   0.328530
# 30  Intercept               1.846645e-07
# V01WOMKPR...   0.608649
# 31  Intercept                3.530325e-01
# V01WOMKP...   0.765309
# 32  Intercept                       1.291418e-01
# V...   0.759632
# 33  Intercept                       4.007786e-01
# V...   0.750434
# 34  Intercept                 1.302404e-24
# V01WOMA...   0.276838
# 35  Intercept                 3.827498e-02
# V01WOMA...   0.699288
# 36  Intercept                        2.533697e-02
# ...   0.701132
# 37  Intercept                        7.014571e-03
# ...   0.700990
# 38  Intercept               4.598585e-58
# V01WOMADL...   0.056054
# 39  Intercept               5.300266e-17
# V01WOMADL...   0.346390
# 40  Intercept                        4.442205e-19
# ...   0.334391
# 41  Intercept                        1.640011e-19
# ...   0.327852
#                                   V01WOMADLR     V01WOMKPR     V01WOMSTFR
# V01WOMADLR                               NaN  0.000000e+00  7.740362e-117
# V01WOMKPR                       0.000000e+00           NaN   5.486602e-05
# V01WOMSTFR                      5.323406e-11  2.666219e-01            NaN
# I(V01WOMADLR ** 2)                       NaN  1.116320e-01   1.766342e-23
# I(V01WOMADLR ** 3)                       NaN  3.270656e-01   2.519091e-12
# I(V01WOMKPR ** 2)               3.074799e-28           NaN   4.331945e-01
# I(V01WOMKPR ** 3)               5.891188e-13           NaN   5.876994e-03
# I(V01WOMSTFR ** 2)              2.838140e-67  2.942231e-08            NaN
# I(V01WOMSTFR ** 3)              4.477022e-05  4.912642e-03            NaN
# V01WOMADLR:I(V01WOMKPR ** 2)             NaN           NaN   3.184553e-14
# V01WOMADLR:I(V01WOMKPR ** 3)             NaN           NaN   4.731064e-06
# V01WOMADLR:I(V01WOMSTFR ** 2)            NaN  3.146894e-05            NaN
# V01WOMADLR:I(V01WOMSTFR ** 3)            NaN  4.747318e-10            NaN
# V01WOMADLR:V01WOMKPR                     NaN           NaN   3.616626e-19
# V01WOMADLR:V01WOMSTFR                    NaN  3.502393e-01            NaN
# V01WOMKPR:I(V01WOMSTFR ** 2)    5.949825e-15           NaN            NaN
# V01WOMKPR:I(V01WOMSTFR ** 3)    1.178183e-04           NaN            NaN
# V01WOMKPR:V01WOMSTFR           2.850661e-120           NaN            NaN

# %% [markdown]
# ## 24-Month WOMAC Right Knee Variables Regression on Median Dataset

# %%
from scripts.womac.womac_relationships import v03_womac_right_median_regression_summary, v03_womac_right_median_p_matrix

display(v03_womac_right_median_regression_summary)
display(v03_womac_right_median_p_matrix)
# Out:
#            type                                            formula  \
# 0        linear                             V03WOMADLR ~ V03WOMKPR
# 1        linear                V03WOMADLR ~ V03WOMKPR + V03WOMSTFR
# 2        linear                             V03WOMKPR ~ V03WOMADLR
# 3        linear                V03WOMKPR ~ V03WOMADLR + V03WOMSTFR
# 4        linear                            V03WOMSTFR ~ V03WOMADLR
# 5        linear                V03WOMSTFR ~ V03WOMADLR + V03WOMKPR
# 6     quadratic                       V03WOMADLR ~ I(V03WOMKPR**2)
# 7     quadratic           V03WOMADLR ~ V03WOMKPR + I(V03WOMKPR**2)
# 8     quadratic  V03WOMADLR ~ V03WOMKPR + V03WOMSTFR + I(V03WOM...
# 9     quadratic          V03WOMADLR ~ V03WOMKPR + I(V03WOMSTFR**2)
# 10    quadratic                       V03WOMKPR ~ I(V03WOMADLR**2)
# 11    quadratic          V03WOMKPR ~ V03WOMADLR + I(V03WOMADLR**2)
# 12    quadratic  V03WOMKPR ~ V03WOMADLR + V03WOMSTFR + I(V03WOM...
# 13    quadratic          V03WOMKPR ~ V03WOMADLR + I(V03WOMSTFR**2)
# 14    quadratic                      V03WOMSTFR ~ I(V03WOMADLR**2)
# 15    quadratic         V03WOMSTFR ~ V03WOMADLR + I(V03WOMADLR**2)
# 16    quadratic  V03WOMSTFR ~ V03WOMADLR + V03WOMKPR + I(V03WOM...
# 17    quadratic          V03WOMSTFR ~ V03WOMADLR + I(V03WOMKPR**2)
# 18        cubic                       V03WOMADLR ~ I(V03WOMKPR**3)
# 19        cubic  V03WOMADLR ~ V03WOMKPR + I(V03WOMKPR**2) + I(V...
# 20        cubic  V03WOMADLR ~ V03WOMKPR + V03WOMSTFR + I(V03WOM...
# 21        cubic  V03WOMADLR ~ V03WOMKPR + I(V03WOMSTFR**2) + I(...
# 22        cubic                       V03WOMKPR ~ I(V03WOMADLR**3)
# 23        cubic  V03WOMKPR ~ V03WOMADLR + I(V03WOMADLR**2) + I(...
# 24        cubic  V03WOMKPR ~ V03WOMADLR + V03WOMSTFR + I(V03WOM...
# 25        cubic  V03WOMKPR ~ V03WOMADLR + I(V03WOMSTFR**2) + I(...
# 26        cubic                      V03WOMSTFR ~ I(V03WOMADLR**3)
# 27        cubic  V03WOMSTFR ~ V03WOMADLR + I(V03WOMADLR**2) + I...
# 28        cubic  V03WOMSTFR ~ V03WOMADLR + V03WOMKPR + I(V03WOM...
# 29        cubic  V03WOMSTFR ~ V03WOMADLR + I(V03WOMKPR**2) + I(...
# 30  interaction                  V03WOMADLR ~ V03WOMKPR:V03WOMSTFR
# 31  interaction                  V03WOMADLR ~ V03WOMKPR*V03WOMSTFR
# 32  interaction            V03WOMADLR ~ V03WOMKPR*I(V03WOMSTFR**2)
# 33  interaction            V03WOMADLR ~ V03WOMKPR*I(V03WOMSTFR**3)
# 34  interaction                  V03WOMKPR ~ V03WOMADLR:V03WOMSTFR
# 35  interaction                  V03WOMKPR ~ V03WOMADLR*V03WOMSTFR
# 36  interaction            V03WOMKPR ~ V03WOMADLR*I(V03WOMSTFR**2)
# 37  interaction            V03WOMKPR ~ V03WOMADLR*I(V03WOMSTFR**3)
# 38  interaction                  V03WOMSTFR ~ V03WOMADLR:V03WOMKPR
# 39  interaction                  V03WOMSTFR ~ V03WOMADLR*V03WOMKPR
# 40  interaction            V03WOMSTFR ~ V03WOMADLR*I(V03WOMKPR**2)
# 41  interaction            V03WOMSTFR ~ V03WOMADLR*I(V03WOMKPR**3)
#
#                                                params  \
# 0   Intercept    0.004710
# V03WOMKPR    2.413838
# dt...
# 1   Intercept    -0.022017
# V03WOMKPR     2.343037
# ...
# 2   Intercept     0.015801
# V03WOMADLR    0.279737
# ...
# 3   Intercept     0.003886
# V03WOMADLR    0.248126
# ...
# 4   Intercept     0.067850
# V03WOMADLR    0.168921
# ...
# 5   Intercept     0.036239
# V03WOMADLR    0.084956
# ...
# 6   Intercept            0.079663
# I(V03WOMKPR ** 2...
# 7   Intercept            0.016465
# V03WOMKPR       ...
# 8   Intercept            -0.003149
# V03WOMKPR      ...
# 9   Intercept            -0.011442
# V03WOMKPR      ...
# 10  Intercept             0.039485
# I(V03WOMADLR **...
# 11  Intercept             0.013238
# V03WOMADLR     ...
# 12  Intercept             0.004779
# V03WOMADLR     ...
# 13  Intercept             0.009630
# V03WOMADLR     ...
# 14  Intercept             0.089810
# I(V03WOMADLR **...
# 15  Intercept             0.059889
# V03WOMADLR     ...
# 16  Intercept             0.031516
# V03WOMADLR     ...
# 17  Intercept            0.039464
# V03WOMADLR      ...
# 18  Intercept            0.111237
# I(V03WOMKPR ** 3...
# 19  Intercept            0.021570
# V03WOMKPR       ...
# 20  Intercept             0.000191
# V03WOMKPR      ...
# 21  Intercept            -0.011035
# V03WOMKPR      ...
# 22  Intercept             0.046489
# I(V03WOMADLR **...
# 23  Intercept             0.011234
# V03WOMADLR     ...
# 24  Intercept             0.003183
# V03WOMADLR     ...
# 25  Intercept             0.007842
# V03WOMADLR     ...
# 26  Intercept             0.096242
# I(V03WOMADLR **...
# 27  Intercept             0.054903
# V03WOMADLR     ...
# 28  Intercept             0.028205
# V03WOMADLR     ...
# 29  Intercept            0.039313
# V03WOMADLR      ...
# 30  Intercept               0.079702
# V03WOMKPR:V03...
# 31  Intercept              -0.007098
# V03WOMKPR    ...
# 32  Intercept                      -0.010952
# V03WO...
# 33  Intercept                      -0.002320
# V03WO...
# 34  Intercept                0.066153
# V03WOMADLR:V...
# 35  Intercept                0.004098
# V03WOMADLR  ...
# 36  Intercept                        0.007478
# V03W...
# 37  Intercept                        0.010949
# V03W...
# 38  Intercept               0.140615
# V03WOMADLR:V0...
# 39  Intercept               0.032044
# V03WOMADLR   ...
# 40  Intercept                       0.038487
# V03WO...
# 41  Intercept                       0.039231
# V03WO...
#
#                                              p_values  r_squared
# 0   Intercept    0.704564
# V03WOMKPR    0.000000
# dt...   0.675241
# 1   Intercept     4.283102e-02
# V03WOMKPR     0.000...   0.752655
# 2   Intercept     0.000183
# V03WOMADLR    0.000000
# ...   0.675241
# 3   Intercept     2.721064e-01
# V03WOMADLR    0.000...   0.755584
# 4   Intercept     2.217647e-30
# V03WOMADLR    0.000...   0.386399
# 5   Intercept     1.020572e-17
# V03WOMADLR    3.594...   0.443703
# 6   Intercept            3.802342e-08
# I(V03WOMKPR ...   0.554766
# 7   Intercept             1.781150e-01
# V03WOMKPR  ...   0.687846
# 8   Intercept              7.581452e-01
# V03WOMKPR ...   0.782853
# 9   Intercept              2.584164e-01
# V03WOMKPR ...   0.780801
# 10  Intercept             4.092251e-13
# I(V03WOMADL...   0.458576
# 11  Intercept             1.675035e-03
# V03WOMADLR ...   0.679681
# 12  Intercept              1.709600e-01
# V03WOMADLR...   0.763910
# 13  Intercept             6.371582e-03
# V03WOMADLR ...   0.751093
# 14  Intercept              9.644029e-41
# I(V03WOMAD...   0.205936
# 15  Intercept              4.029444e-25
# V03WOMADLR...   0.419221
# 16  Intercept             1.748792e-14
# V03WOMADLR ...   0.477294
# 17  Intercept             1.251683e-19
# V03WOMADLR ...   0.409572
# 18  Intercept             3.636734e-10
# I(V03WOMKPR...   0.331129
# 19  Intercept            7.585599e-02
# V03WOMKPR   ...   0.692985
# 20  Intercept             9.849810e-01
# V03WOMKPR  ...   0.787274
# 21  Intercept             2.789824e-01
# V03WOMKPR  ...   0.780810
# 22  Intercept              9.668640e-14
# I(V03WOMAD...   0.287124
# 23  Intercept              7.436462e-03
# V03WOMADLR...   0.683819
# 24  Intercept              3.536360e-01
# V03WOMADLR...   0.772516
# 25  Intercept             2.692475e-02
# V03WOMADLR ...   0.752571
# 26  Intercept             5.736405e-42
# I(V03WOMADL...   0.114526
# 27  Intercept              6.172866e-22
# V03WOMADLR...   0.438423
# 28  Intercept             2.324017e-12
# V03WOMADLR ...   0.501505
# 29  Intercept             1.489235e-19
# V03WOMADLR ...   0.411861
# 30  Intercept               1.365488e-10
# V03WOMKPR...   0.575431
# 31  Intercept                4.936125e-01
# V03WOMKP...   0.776334
# 32  Intercept                       2.819222e-01
# V...   0.780817
# 33  Intercept                       8.191065e-01
# V...   0.780216
# 34  Intercept                 1.077736e-21
# V03WOMA...   0.269368
# 35  Intercept                 2.478121e-01
# V03WOMA...   0.755651
# 36  Intercept                        3.400517e-02
# ...   0.753995
# 37  Intercept                        1.994799e-03
# ...   0.749485
# 38  Intercept               1.581026e-63
# V03WOMADL...   0.074581
# 39  Intercept               9.278206e-15
# V03WOMADL...   0.470372
# 40  Intercept                        4.879597e-19
# ...   0.419926
# 41  Intercept                        1.672050e-19
# ...   0.412634
#                                  V03WOMADLR     V03WOMKPR     V03WOMSTFR
# V03WOMADLR                              NaN  0.000000e+00  5.311371e-174
# V03WOMKPR                      0.000000e+00           NaN   4.019473e-19
# V03WOMSTFR                     7.498202e-08  8.695641e-03            NaN
# I(V03WOMADLR ** 2)                      NaN  5.624497e-23   3.325758e-38
# I(V03WOMADLR ** 3)                      NaN  1.164676e-10   6.130260e-24
# I(V03WOMKPR ** 2)              1.828305e-24           NaN   1.346373e-02
# I(V03WOMKPR ** 3)              1.493782e-12           NaN   6.711991e-02
# I(V03WOMSTFR ** 2)             2.381192e-67  9.818580e-22            NaN
# I(V03WOMSTFR ** 3)             7.798752e-02  2.592943e-05            NaN
# V03WOMADLR:I(V03WOMKPR ** 2)            NaN           NaN   2.757849e-13
# V03WOMADLR:I(V03WOMKPR ** 3)            NaN           NaN   1.064114e-03
# V03WOMADLR:I(V03WOMSTFR ** 2)           NaN  2.862028e-09            NaN
# V03WOMADLR:I(V03WOMSTFR ** 3)           NaN  1.962862e-13            NaN
# V03WOMADLR:V03WOMKPR                    NaN           NaN   1.388223e-34
# V03WOMADLR:V03WOMSTFR                   NaN  1.886233e-01            NaN
# V03WOMKPR:I(V03WOMSTFR ** 2)   6.583288e-01           NaN            NaN
# V03WOMKPR:I(V03WOMSTFR ** 3)   3.590854e-28           NaN            NaN
# V03WOMKPR:V03WOMSTFR           5.884149e-69           NaN            NaN
