# %%
from IPython.display import display
from scripts.mbm.womac_oriented.womac_mbm_xgBoost import v00_v01_moaks_womac_left_metrics, v00_v01_moaks_womac_left_coefs_df

display(v00_v01_moaks_womac_left_coefs_df.sort_values(by=['GainImportance'], ascending=False))
display(v00_v01_moaks_womac_left_metrics)
# Out:
# ...
#        Feature  GainImportance      Target  PermImportance  PermImportance_std
# 45  V00MBMPTMP        0.063578  V01WOMSTFL        0.012126            0.009313
# 0   V00MBMNFMA        0.051423  V01WOMADLL       -0.010135            0.017132
# 46  V00MBMNFLA        0.039065  V01WOMSTFL        0.056564            0.028826
# 1   V00MBMPTMA        0.037485  V01WOMADLL        0.016546            0.012617
# 2   V00MBMPFMA        0.035028  V01WOMADLL        0.008645            0.029002
# ..         ...             ...         ...             ...                 ...
# 88  V00MBMNTMC        0.003137  V01WOMSTFL       -0.001440            0.003235
# 42  V00MBMSTLA        0.002580  V01WOMADLL       -0.000180            0.000330
# 43  V00MBMPTLA        0.000000  V01WOMADLL       -0.000070            0.000118
# 44  V00MBMNTLA        0.000000  V01WOMADLL        0.000000            0.000000
# 89  V00MBMNTLA        0.000000  V01WOMSTFL        0.000000            0.000000
#
# [90 rows x 5 columns]
# ...

# %%
from scripts.mbm.womac_oriented.womac_mbm_xgBoost import v00_v01_moaks_womac_left_lasso_metrics, v00_v01_moaks_womac_left_lasso_coefs_df

display(v00_v01_moaks_womac_left_lasso_coefs_df.sort_values(by=['GainImportance'], ascending=False))
display(v00_v01_moaks_womac_left_lasso_metrics)
# Out:
#        Feature  GainImportance      Target  PermImportance  PermImportance_std
# 0    V00MBMSPL        0.149012  V01WOMADLL        0.119933            0.160238
# 1    V00MBMNPM        0.135901  V01WOMADLL        0.095908            0.067000
# 2   V00MBMNFLA        0.133074  V01WOMADLL        0.021728            0.031922
# 3   V00MBMPFMA        0.132793  V01WOMADLL       -0.068828            0.091607
# 4   V00MBMPFLA        0.114093  V01WOMADLL        0.010535            0.022356
# 5    V00MBMPPM        0.113665  V01WOMADLL        0.037672            0.072892
# 6   V00MBMSTMA        0.112601  V01WOMADLL        0.111380            0.028950
# 7    V00MBMNSS        0.108859  V01WOMADLL       -0.000626            0.095892
# 8   V00MBMPFMA        0.057865  V01WOMSTFL       -0.068828            0.091607
# 9    V00MBMPPM        0.056571  V01WOMSTFL        0.037672            0.072892
# 10  V00MBMPFLA        0.050107  V01WOMSTFL        0.010535            0.022356
# ...
